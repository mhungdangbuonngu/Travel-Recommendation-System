# %% [markdown]
# ### Set up

# %% [markdown]
# Library

# %%
from langchain_core.prompts import ChatPromptTemplate
from sentence_transformers import SentenceTransformer
from langchain_google_genai import ChatGoogleGenerativeAI
import re
import json
import subprocess
import time
import threading
import psycopg2
import pandas as pd
import numpy as np
import getpass
import os
from sklearn.preprocessing import MultiLabelBinarizer
from sklearn.metrics.pairwise import cosine_similarity
from sklearn.preprocessing import MinMaxScaler
# Out:
# e:\NhiAri\Code\GroupProject2024\groupproject2024\Lib\site-packages\sentence_transformers\cross_encoder\CrossEncoder.py:11: TqdmExperimentalWarning: Using `tqdm.autonotebook.tqdm` in notebook mode. Use `tqdm.tqdm` instead to force console mode (e.g. in jupyter console)
#   from tqdm.autonotebook import tqdm, trange

# %% [markdown]
# #### postgresSQL

# %%
postgres_url = getpass.getpass("Enter your postgresql url: ")

# %%
model = SentenceTransformer('bkai-foundation-models/vietnamese-bi-encoder')

# %% [markdown]
# #### Gemini

# %%
os.environ["GOOGLE_API_KEY"] = getpass.getpass("Enter your Google AI API key: ")

# %%
llm = ChatGoogleGenerativeAI(
    model="gemini-1.5-flash",
    temperature=0,
    max_tokens=None,
    timeout=None,
    max_retries=2,
)

# %% [markdown]
# ### Query

# %% [markdown]
# #### Get features

# %% [markdown]
# ##### Hotels

# %%
# amenities
conn = psycopg2.connect(postgres_url)
cur = conn.cursor()

cur.execute("SET search_path TO travel_database, public;")

cur.execute("""
    SELECT DISTINCT unnest(amenities) AS unique_amenities
    FROM hotel;
""")

rows = cur.fetchall()

cur.close()
conn.close()

amenities_list = [row[0] for row in rows]
amenities_list_str = "\n    ".join(f'"{amenities_type}"' for amenities_type in amenities_list)
print(amenities_list_str)
# Out:
# "WiFi tại khu vực chung"
#     "Money changer"
#     "Bathtub"
#     "Tiện nghi cho trẻ"
#     "Quầy bar bên hồ bơi"
#     "Heater"
#     "Dù (ô) che nắng"
#     "Đưa đón đến khu trượt tuyết (thu phí)"
#     "Tiện nghi hội họp"
#     "Sân quần vợt ngoài trời"
#     "Trung tâm chăm sóc trẻ em"
#     "Roll-in shower"
#     "Vegetarian meal"
#     "Hồ bơi"
#     "Tủ lạnh (dùng chung)"
#     "Máy photocopy"
#     "Giữ trẻ"
#     "Porter"
#     "Bicycle storage"
#     "Dịch vụ cho thuê xe đạp"
#     "Conference room"
#     "Dịch vụ trông trẻ có người giám hộ"
#     "Grocery"
#     "Giặt ủi"
#     "Dịch vụ phòng 24 giờ"
#     "Lò vi sóng"
#     "Express check-out"
#     "Đưa đón sân bay"
#     "AC"
#     "Dịch vụ phòng (có giới hạn thời gian)"
#     "Bóng quần"
#     "TV lounge"
#     "A la carte lunch"
#     "Bồn tắm nước nóng"
#     "Gói cầu hôn lãng mạn"
#     "Safety deposit box"
#     "Vườn thú bán hoang dã"
#     "Hồ bơi trẻ em"
#     "Ghế dài tắm nắng"
#     "Đưa đón đến trạm xe buýt (thu phí)"
#     "Wifi (miễn phí)"
#     "Thẩm mỹ viện"
#     "Bữa trưa món tự chọn"
#     "Đồ chơi"
#     "Phòng tắm vòi sen"
#     "Khu thể thao dưới nước"
#     "Nhà hàng có trình diễn nấu ăn"
#     "Breakfast and lunch"
#     "Bàn tập golf"
#     "Bóng ném"
#     "Lò sưởi tại sảnh"
#     "Beauty salon"
#     "Airport transfer"
#     "Ghế cho trẻ em"
#     "Phòng hội nghị"
#     "Cửa hàng quà tặng"
#     "Quầy lễ tân"
#     "Tiệm cà phê"
#     "Nhà hàng phục vụ bữa sáng"
#     "Buffet breakfast"
#     "Các tiện nghi văn phòng"
#     "Nhật báo tại sảnh"
#     "Dịch vụ lưu trữ/bảo quản hành lý"
#     "Connecting rooms"
#     "Tủ lạnh"
#     "Sân golf"
#     "Câu cá"
#     "Shower"
#     "Trò chơi trẻ em"
#     "Sân tennis"
#     "Máy sưởi"
#     "Phòng tắm phù hợp với xe lăn"
#     "Snack bar"
#     "Trung tâm thể dục thể hình"
#     "Bãi đậu xe"
#     "Bóng chuyền"
#     "Nhận phòng sớm"
#     "Winery"
#     "Ghế dài tắm nắng hồ bơi"
#     "Barbecue"
#     "Bữa sáng"
#     "Bar"
#     "Sân thượng/Sân hiên"
#     "Garage"
#     "Cloakroom"
#     "Chương trình giải trí cho trẻ em"
#     "Bữa sáng phục vụ món nóng"
#     "Minibar"
#     "Đưa đón đến công viên chủ đề"
#     "Tiệc liên hoan"
#     "Nhà máy rượu vang"
#     "Trượt tuyết"
#     "Điểm truy cập Internet"
#     "Microwave"
#     "Bãi gửi xe (thu phí)"
#     "Đưa đón trong khu vực"
#     "Xe đưa đón bến phà (thu phí)"
#     "Trả phòng muộn"
#     "Nhà bếp mini"
#     "Thuyền buồm hai thân"
#     "Room service"
#     "Nhà hàng phục vụ bữa trưa"
#     "Sân thượng/sân hiên"
#     "Lướt ván buồm"
#     "Máy sấy quần áo"
#     "Mát-xa"
#     "Khu vui chơi trẻ em"
#     "Lướt sóng"
#     "Lễ tân 24h"
#     "Mạng Internet cục bộ"
#     "A la carte breakfast"
#     "Access friendly"
#     "Xông hơi ướt"
#     "Breakfast restaurant"
#     "TV"
#     "Cho phép vật nuôi lớn"
#     "Early check-in"
#     "Set menu lunch"
#     "Dịch vụ spa"
#     "Phòng giải trí"
#     "ATM/Banking"
#     "Đường trượt nước"
#     "Dịch vụ giặt ủi"
#     "Parking with surcharge"
#     "Dịch vụ trả phòng cấp tốc"
#     "Khu vực không hút thuốc"
#     "Coffee/tea in lobby"
#     "Thực đơn ăn kiêng"
#     "Đường chơi bowling"
#     "Bảng chỉ dẫn nổi hoặc chữ nổi"
#     "Phòng xông hơi"
#     "Bữa ăn không chứa gluten"
#     "Mô-tô nước"
#     "Late check-out"
#     "Smoking area"
#     "Phòng trò chơi"
#     "Computer station"
#     "Clothes dryer"
#     "Câu lạc bộ đêm"
#     "Lunch restaurant"
#     "Hội trường đa chức năng"
#     "Bãi đậu xe (thu phí)"
#     "Restaurant"
#     "Phục vụ bữa sáng/trưa/tối không kèm thức uống"
#     "Sự kiện giới thiệu rượu"
#     "Spa"
#     "24-hour Receptionist"
#     "Đưa đón sân bay (thu phí)"
#     "Business center"
#     "Két an toàn trong phòng"
#     "Bữa tối với thực đơn gọi món"
#     "Bóng rổ"
#     "Máy chiếu"
#     "Lò vi sóng (dùng chung)"
#     "Breakfast"
#     "Đưa đón đến công viên chủ đề (thu phí)"
#     "Massage"
#     "LAN Internet"
#     "Limited hours room service"
#     "Cho phép vật nuôi"
#     "Front desk"
#     "Separate shower and tub"
#     "Parasol"
#     "Khu vực dã ngoại"
#     "24-hour security"
#     "Khu vực hút thuốc"
#     "Các môn thể thao dưới nước"
#     "Train station pickup"
#     "Wifi (thu phí)"
#     "Nhân viên xách hành lý"
#     "Tủ khoá"
#     "24-hour room service"
#     "Người gác cửa"
#     "WiFi in public area with surcharge"
#     "Hồ nước nóng Jacuzzi"
#     "Câu lạc bộ golf"
#     "Braille or raised signage"
#     "Cửa hàng"
#     "In-room safe"
#     "Concierge"
#     "Xe đưa đón sòng bạc (thu phí)"
#     "Cưỡi ngựa"
#     "Luggage storage"
#     "Máy ATM/Ngân hàng"
#     "Phòng xem TV"
#     "Giữ & chăm sóc trẻ (thu phí)"
#     "Quầy phục vụ đồ ăn nhẹ"
#     "Shops"
#     "Ferry terminal shuttle with surcharge"
#     "Máy tính"
#     "Truyền hình cáp"
#     "In-room accessibility"
#     "Ghế dài tắm nắng bãi biển"
#     "Bồn tắm"
#     "Terrace on rooftop"
#     "Siêu thị"
#     "Lặn biển"
#     "Phòng tắm đứng và bồn tắm riêng"
#     "Cho thuê xe hơi"
#     "Doorman"
#     "Hồ bơi trong nhà"
#     "Multilingual staff"
#     "Newspaper"
#     "Bàn ủi"
#     "Xông hơi khô/ướt"
#     "Sân thể thao"
#     "Đưa đón bãi biển"
#     "Quầy bar cạnh hồ bơi"
#     "Wedding service"
#     "Family room"
#     "Bãi gửi xe máy"
#     "Hair salon"
#     "Đội ngũ nhân viên đa ngôn ngữ"
#     "Đón khách tại ga tàu"
#     "Babysitting"
#     "Kitchenette"
#     "Thuyền buồm"
#     "Đồ ăn nhẹ"
#     "Bữa tối với thực đơn chọn sẵn"
#     "Lều trên bãi biển"
#     "Dịch vụ hỗ trợ đặt Tour"
#     "Điện thoại gọi quốc tế"
#     "Phòng được trang bị phù hợp cho người khuyết tật"
#     "Đưa đón bến phà"
#     "Desk"
#     "Nhà lều bên hồ bơi"
#     "Sân golf mini"
#     "Dinner restaurant"
#     "Thang máy"
#     "Quần vợt lồng"
#     "Library"
#     "Bi gỗ"
#     "Fitness center"
#     "Phục vụ bữa sáng cho người dậy muộn"
#     "Hồ bơi nước nóng ngoài trời"
#     "Nhà hàng có máy lạnh"
#     "Dining area"
#     "Dịch vụ giữ trẻ (thu phí)"
#     "Câu lạc bộ thiếu nhi (thu phí)"
#     "Xe đưa đón bến du thuyền"
#     "Bắn cung"
#     "Sân quần vợt trong nhà"
#     "Welcoming drinks"
#     "Phục vụ bữa sáng/tối không kèm đồ uống"
#     "Cafe"
#     "Nhà hát"
#     "Sân tập golf"
#     "Smoke free"
#     "Dịch vụ thu đổi ngoại tệ"
#     "Babysitting with surcharge"
#     "Thư viện"
#     "Điện thoại di động"
#     "Chèo thuyền"
#     "Chương trình giải trí cho người lớn"
#     "Hiệu làm tóc"
#     "Non-smoking room"
#     "Lướt ván nước"
#     "Nhà hàng"
#     "Thuận tiện cho người khuyết tật"
#     "Bãi đậu xe buýt/xe tải"
#     "Phòng gia đình"
#     "OTHER"
#     "Airport transfer with surcharge"
#     "Fitness"
#     "Phòng họp"
#     "Elevator"
#     "Tiệc nướng ngoài trời"
#     "Bicycle rental"
#     "Free WiFi"
#     "Bãi biển riêng"
#     "Đưa đón đến khu trượt tuyết"
#     "Trung tâm thể dục thể hình (giá ưu đãi)"
#     "Accessible bathroom"
#     "Sảnh lễ tân"
#     "Express check-in"
#     "Thuyền đạp nước"
#     "Nơi bảo quản dụng cụ trượt tuyết"
#     "Phao chuối"
#     "Khu ẩm thực"
#     "Nhật báo"
#     "Vườn hoa"
#     "Công viên nước (thu phí vào cổng)"
#     "Early Check-in"
#     "Breakfast served to the table"
#     "Dịch vụ nhận phòng cấp tốc"
#     "Hairdryer"
#     "Xe đưa đón sòng bạc"
#     "Dịch vụ văn phòng"
#     "Đưa đón trong khu vực (thu phí)"
#     "Phục vụ bữa sáng/trưa/tối kèm thức uống"
#     "Quần vợt"
#     "Hồ bơi nước nóng trong nhà"
#     "Bãi gửi xe"
#     "Dịch vụ tiệc cưới"
#     "PRINTER"
#     "Trang bị phòng phù hợp với người khuyết tật"
#     "Đầu đĩa DVD"
#     "Cà phê/trà tại sảnh"
#     "Breakfast and dinner"
#     "Khăn tắm biển"
#     "Tours"
#     "Máy lạnh"
#     "Photocopier"
#     "Bữa sáng cho người dậy sớm"
#     "Bãi đậu xe có người phục vụ"
#     "Quầy bar"
#     "Parking"
#     "Bữa sáng và bữa trưa"
#     "Dịch vụ chăm sóc y tế"
#     "Tiệc chiêu đãi"
#     "Bữa sáng món tự chọn"
#     "Phù hợp cho xe lăn"
#     "Nhà hàng phục vụ bữa tối"
#     "Bãi đậu xe hạn chế"
#     "Medical service"
#     "Area shuttle with surcharge"
#     "Giữ xe đạp"
#     "Bàn bi-da"
#     "Máy sấy tóc"
#     "Các tiện nghi ngoài trời"
#     "Accessible path of travel"
#     "Câu lạc bộ thiếu nhi"
#     "Car rental"
#     "Nhà tắm kiểu Thổ"
#     "Cruise shuttle with surcharge"
#     "Refrigerator"
#     "Đưa đón đến trung tâm mua sắm (thu phí)"
#     "Phòng liên thông"
#     "Đưa đón đến trung tâm thương mại"
#     "Cable TV"
#     "Laundry service"
#     "Bữa sáng (thu phí)"
#     "Câu lạc bộ sức khoẻ"
#     "Restaurant with AC"
#     "Phòng giữ đồ"
#     "Dịch vụ trả phòng muộn"
#     "WiFi in public area"
#     "Lễ tân hội nghị"
#     "Buồng tắm nắng"
#     "Wheelchair accessible"
#     "Valet parking"
#     "Internet point"
#     "Khu sinh hoạt cộng đồng"
#     "Trung tâm Hội nghị"
#     "Áo choàng tắm"
#     "Xe đạp địa hình"
#     "Early bird breakfast"
#     "Không khói thuốc"
#     "A la carte dinner"
#     "Secure parking"
#     "Bữa sáng và bữa tối"
#     "Bữa sáng phục vụ tại bàn"
#     "Dịch vụ concierge/hỗ trợ khách"
#     "Bữa tối món tự chọn"
#     "Du ngoạn trên thuyền máy"
#     "Golf"
#     "Xe đưa đón bến du thuyền (thu phí)"
#     "Két an toàn"
#     "Trung tâm dịch vụ hành chánh/văn phòng"
#     "Phi tiêu"
#     "Phòng tắm phù hợp cho người khuyết tật"
#     "Mobile"
#     "Supermarket"
#     "Bữa trưa với thực đơn chọn sẵn"
#     "Đưa đón đến ga xe lửa (thu phí)"
#     "Xe golf"
#     "Bữa trưa với thực đơn gọi món"
#     "Limo or town car service"
#     "Gửi xe có người phục vụ (thu phí)"
#     "EARLY_CHECK_IN"
#     "Phục vụ bữa sáng/tối kèm đồ uống không cồn"
#     "Newspaper in lobby"
#     "Cho phép vật nuôi nhỏ"
#     "Karaoke"
#     "Bóng chuyền bãi biển"
#     "Nhà chứa xe"
#     "Phục vụ bữa sáng/trưa/tối kèm thức uống không cồn"
#     "Laundry"
#     "Dù (ô) trên bãi biển"
#     "Bãi đậu xe an ninh"
#     "Cửa hàng thực phẩm"
#     "Business facilities"
#     "Bathrobe"
#     "Bữa sáng muộn"
#     "Bữa sáng miễn phí"
#     "Bóng bàn"
#     "Thức uống chào mừng miễn phí"
#     "Sòng bạc"
#     "Mạng Internet cục bộ (thu phí)"
#     "Nhân viên gác cổng"
#     "Lối đi lại cho người khuyết tật"
#     "Snacks"
#     "Bữa sáng kiểu Âu"
#     "Không phục vụ đồ uống có cồn"
#     "Show cooking restaurant"
#     "Hồ bơi ngoài trời"
#     "Set menu dinner"
#     "Coffee shop"
#     "Bellhop"
#     "Bảo vệ 24 giờ"
#     "Phòng không hút thuốc"
#     "Fireplace in lobby"
#     "Chỗ đậu xe cho người khuyết tật"
#     "Công viên nước"
#     "Phục vụ món chay"
#     "Highchairs"
#     "WiFi tại khu vực chung (thu phí)"
#     "Breakfast with surcharge"
#     "Bữa sáng với thực đơn gọi món"
#     "Trung tâm thể dục thẩm mỹ"
#     "Bàn làm việc"
#     "Gala dinner"
#     "Terrace"
#     "Dịch vụ dọn phòng"
#     "CRIBS"
#     "Accessible parking"
#     "Dịch vụ xe limo/xe đưa đón hạng sang"
#     "Fullboard with drinks"
#     "Máy in"
#     "Motor boat ride"
#     "Gift shop"
#     "Cầu lông"
#     "Cửa hàng lưu niệm"

# %%
# style
conn = psycopg2.connect(postgres_url)
cur = conn.cursor()

cur.execute("SET search_path TO travel_database, public;")

cur.execute("""
    SELECT DISTINCT style
    FROM hotel
    WHERE style IS NOT NULL;
""")

rows = cur.fetchall()

cur.close()
conn.close()
style_list = [row[0] for row in rows]
style_list_str = "\n    ".join(f'"{style}"' for style in style_list)
print(style_list_str)
# Out:
# "Business
# "
#     "Adventure
# "
#     "Romantic
# "
#     "Eco-friendly
# "
#     "Business
# "
#     "Wellness
# "
#     "Family-friendly
# "
#     "Cultural
# "
#     "Romantic
# "
#     "Beachfront
# "
#     "Luxury
# "
#     "Boutique
# "
#     "Eco-friendly
# "
#     "Adventure
# "
#     "Family-friendly
# "
#     "Boutique
# "
#     "Cultural
# "
#     "Wellness
# "
#     "Luxury
# "

# %% [markdown]
# ##### Attractions

# %%
# types
conn = psycopg2.connect(postgres_url)
cur = conn.cursor()

cur.execute("SET search_path TO travel_database, public;")

cur.execute("""
    SELECT DISTINCT unnest(attraction_type) AS unique_attraction_type
    FROM touristattraction;
""")

rows = cur.fetchall()

cur.close()
conn.close()

att_type_list = [row[0] for row in rows]
att_type_list_str = "\n    ".join(f'"{att_type}"' for att_type in att_type_list)
print(att_type_list_str)
# Out:
# "Nhà hát và biểu diễn"
#     "Viện bảo tàng lịch sử"
#     "Thủy cung"
#     "Khu vực đi dạo tham quan di tích lịch sử"
#     "Trường đại học và trường học"
#     "Quán bar và câu lạc bộ"
#     "Khu vực đi dạo ngắm cảnh"
#     "Viện bảo tàng nghệ thuật"
#     "Vườn"
#     "Di tích cổ"
#     "Nhà thờ và nhà thờ lớn"
#     "ATV và xe địa hình"
#     "Đài kỷ niệm và tượng"
#     "Cầu"
#     "Chuyến tham quan văn hóa"
#     "Xưởng vẽ và làm đồ gốm"
#     "Núi"
#     "Địa điểm giáo dục"
#     "Khu liên hợp thể thao"
#     "Buổi học và hội thảo"
#     "Cửa hàng đồ cổ"
#     "Sân gôn"
#     "Triển lãm"
#     "Đấu trường và sân vận động"
#     "Phòng trưng bày nghệ thuật"
#     "Điểm thu hút khách tham quan và thắng cảnh"
#     "Địa điểm tâm linh"
#     "Chợ hoa"
#     "Cửa hàng của nhà máy"
#     "Trung tâm nghệ thuật"
#     "Quán bar rượu vang"
#     "Căn cứ và doanh trại quân đội"
#     "Địa điểm lịch sử"
#     "Công viên nước"
#     "Chuyến tham quan cà phê và trà"
#     "Nhà hát"
#     "Trung tâm trò chơi và giải trí"
#     "Bảo tàng dành cho trẻ em"
#     "Viện bảo tàng quân đội"
#     "Bãi biển"
#     "Chuyến tham quan mua sắm"
#     "Địa điểm tôn giáo"
#     "Trò chơi giải thoát"
#     "Đường đua ô tô"
#     "Chuyến tham quan tư nhân"
#     "Trung tâm hành chính"
#     "Sự kiện văn hóa"
#     "Cửa hàng đặc sản"
#     "Địa điểm tôn giáo"
#     "Đài và tháp quan sát"
#     "Hình thái địa chất"
#     "Chợ trời"
#     "Cửa hàng đồ cổ"
#     "Sở thú"
#     "Vùng nước"
#     "Đài tháp quan sát"
#     "Viện bảo tàng nghệ thuật"
#     "Viện bảo tàng khoa học"
#     "Địa điểm lịch sử"
#     "Khu du lịch"
#     "Trung tâm mua sắm"
#     "Quầy bar xì gà"
#     "Nông trại"
#     "Công viên"
#     "Lớp học nấu ăn"
#     "Làng nghề truyền thống"
#     "Sân chơi"
#     "Tòa nhà chính phủ"
#     "Rạp hát"
#     "Sân golf mini"
#     "Di tích cổ"
#     "Viện bảo tàng chuyên ngành"
#     "Chuyến tham quan cưỡi ngựa"
#     "Công viên quốc gia"
#     "Spa nước nóng"
#     "Hệ thống giao thông công cộng"
#     "Rạp hát Nhà hát và biểu diễn"
#     "Lớp nấu ăn"
#     "Cửa hàng bách hóa"
#     "Chợ nông sản"
#     "Khu phố cổ"
#     "Trung tâm và trại thể thao"

# %% [markdown]
# ##### Restaurant

# %%
# Type
# Establish the connection
conn = psycopg2.connect(postgres_url)
cur = conn.cursor()

# Set the search path to use the correct schema
cur.execute("SET search_path TO travel_database, public;")

# Query to extract distinct districts from the address composite type
cur.execute("""
    SELECT DISTINCT unnest(restaurant_type) AS unique_res_type
    FROM restaurant;
""")

# Fetch all rows
rows = cur.fetchall()

# Close the cursor and connection
cur.close()
conn.close()

# Convert the rows into a list and format the output
res_type_list = [row[0] for row in rows]
res_type_list_str = "\n    ".join(f'"{res_type}"' for res_type in res_type_list)
print(res_type_list_str)
# Out:
# "Karaoke"
#     "Café/Dessert"
#     "Buffet"
#     "Ăn vặt/vỉa hè"
#     "Tiệc cưới/Hội nghị"
#     "Quán ăn"
#     "Tiệm bánh"
#     "Ăn chay"
#     "Nhà hàng"

# %%
# Suitable for
# Establish the connection
conn = psycopg2.connect(postgres_url)
cur = conn.cursor()

# Set the search path to use the correct schema
cur.execute("SET search_path TO travel_database, public;")

# Query to extract distinct districts from the address composite type
cur.execute("""
    SELECT DISTINCT unnest(suitable_for) AS unique_res_suit
    FROM restaurant;
""")

# Fetch all rows
rows = cur.fetchall()

# Close the cursor and connection
cur.close()
conn.close()

# Convert the rows into a list and format the output
res_suit_list = [row[0] for row in rows]
res_suit_list_str = "\n    ".join(f'"{res_suit}"' for res_suit in res_suit_list)
print(res_suit_list_str)
# Out:
# "Uống bia - Nhậu"
#     "Ăn gia đình"
#     "Ăn chay"
#     "Ăn Fastfood"
#     "Đãi tiệc"
#     "Tiếp khách"
#     "Takeaway - Mang về"
#     "Họp nhóm"
#     "Ăn vặt"
#     "Nghe nhạc"
#     "Du lịch"
#     "Ngắm cảnh"
#     "Chụp hình - Quay phim"
#     "BBQ - Món Nướng"
#     "Tiệc ngoài trời"
#     "Thư giãn"
#     "Hẹn hò"
#     "Buffet"

# %% [markdown]
# #### Prompt

# %% [markdown]
# thêm district

# %% [markdown]
# Dựa vào câu prompt này để lấy ra các thông tin yêu cầu về hotel, restaurant, TouristAttraction

# %% [markdown]
# ##### Extract first JSON

# %%
travel_type_list = ["Nghỉ dưỡng", "Khám phá"]
companion_list = ["friends", "family", "colleagues"]
transport_list = ["self-drive car", "motorbike", "bicycle", "public transport"]
city_list = ["Hà Nội"]
district_list = ["Ba Đình", "Hoàn Kiếm", "Tây Hồ", "Long Biên", "Cầu Giấy", "Đống Đa", "Hai Bà Trưng", "Hoàng Mai", "Thanh Xuân", "Nam Từ Liêm", "Bắc Từ Liêm", "Hà Đông", "Sơn Tây"]

# %%
# template = """
# You are an AI travel suggestion chatbot. Analyze the following travel request:

# Request: "{travel_request}"

# Extract general and specific requirements for Hotels, Restaurants, and Tourist Attractions, even if some are not explicitly mentioned. For each type, provide the following information:

# **General Requirements:**
# - Type: Only assign "Nghỉ dưỡng" or "Khám phá" when the request EXPLICITLY mentions the purpose:
#   * "Nghỉ dưỡng" - ONLY if request contains clear relaxation keywords:
#     Examples that should return "Nghỉ dưỡng":
#     - "Muốn đi nghỉ dưỡng ở resort"
#     - "Tìm chỗ thư giãn cuối tuần"
#     - "Cần resort để nghỉ ngơi"
    
#   * "Khám phá" - ONLY if request contains clear exploration keywords:
#     Examples that should return "Khám phá":
#     - "Muốn đi khám phá văn hóa địa phương"
#     - "Tìm địa điểm để tham quan và trải nghiệm"
#     - "Lên lịch đi phượt và khám phá"
    
#   * Return null for:
#     - General requests like "Gợi ý lịch trình du lịch"
#     - Questions about specific facilities only
#     - When purpose is not explicitly stated
#     - Mixed or unclear purposes
# - Number_of_people: Extract the number of people or return null if not specified.
# - Companions: Extract the companions mentioned in the request and translated it if it needed, must be one from this list: {companion_list} or return null if not specified.
# - Transportation: Identify the transportation method mentioned in the request and translated, convert it if it needed, transportation must be one from this list: {transport_list} or return null if not specified.
# - Time: Any specific dates or time ranges mentioned or return null if not specified.
# - City: The mentioned city (without "city" or "province").
# - District: The mentioned district (without "district") and must be one frin this list: {district_list} or else return null.
# - Price_range: Specify as "low", "medium", or "high" based on the request.

# **For Hotels, also identify:**
# - Requirements: A summary text of specific requirements or preferences mentioned.
# - Amenities: IMPORTANT - ONLY include amenities from {amenities_list} if EXPLICITLY mentioned in the request. 
#   Examples:
#   - If request says "need hotel with pool and gym" → include ["Pool", "Gym"]
#   - If request doesn't mention any amenities → return null
#   - Do NOT assume or add amenities that weren't specifically mentioned
# - Style: Only include styles from this list if explicitly mentioned in the request: {style_list} or else return null

# **For Restaurants, also identify:**
# - Requirements: A summary text of specific requirements or preferences mentioned.
# - Restaurant_Type: From this list: {restaurant_type_list}
# - Suitable_For: From this list: {suitable_for_list}

# **For Tourist Attractions, also identify:**
# - Requirements: A list of specific requirements or preferences mentioned.
# - Attraction_Type: From this list: {attraction_type_list}

# Return the result using the following JSON format:

# ```json
# {{
#   "General": {{
#     "Type": "...",
#     "Number_of_people": "...",
#     "Companion": "...",
#     "Transportation": "...",
#     "Time": "...",
#     "City": "...",
#     "District": "...",
#     "Price_range": "...",
#     "
#   }},
#   "Hotel": {{
#     "Requirements": ...,
#     "Amenities": [...],
#     "Style": [...]
#   }},
#   "Restaurant": {{
#     "Requirements": ...,
#     "Restaurant_Type": "...",
#     "Suitable_For": "..."
#   }},
#   "TouristAttraction": {{
#     "Attraction_Type": "..."
#   }}
# }}

# ```
# IMPORTANT RULES:
# 1. For lists (Amenities, Style), RETURN null if none are EXPLICITLY mentioned. Do NOT make assumptions or add information that isn't clearly stated or mentioned
# 2. Keep output strictly aligned with the provided lists

# Ensure the JSON is valid. Use null for any unspecified information.
# After the JSON output, add a note in Vietnamese:

# "Nếu bạn cần thay đổi hoặc bổ sung bất kỳ thông tin nào, vui lòng cho tôi biết."
# """

# %%
template = """
You are an AI travel suggestion chatbot. Analyze the following travel request:

Request: "{travel_request}"

Extract general and specific requirements for Hotels, Restaurants, and Tourist Attractions, even if some are not explicitly mentioned. For each type, provide the following information:

**General Requirements:**
- Type:
  - If the request explicitly mentions "nghỉ dưỡng", "thư giãn", "resort", or similar keywords, and the overall tone is relaxed or leisure-oriented or have leisure activities, relaxation-focused activities(clear relaxation keywords), assign "Nghỉ dưỡng".
  - If the request explicitly mentions "khám phá", "văn hóa", "ẩm thực", or similar keywords, and the overall tone is exploratory or adventurous or exploration or have activity-focused activities (clear exploration keywords), assign "Khám phá".
  - For general requests or requests with mixed intentions, return `null`.
- Number_of_people: Extract the number of people or return null if not specified.
- Companions: Extract the companions mentioned in the request and translated it if it needed, must be one from this list: {companion_list} or return null if not specified.
- Transportation: Identify the transportation method mentioned in the request and translated, convert it if it needed, transportation must be one from this list: {transport_list} or return null if not specified.
- Time:
  - Extract specific dates or time ranges mentioned in the request.
  - If no specific dates are mentioned, check for keywords like "ngày", "tuần", "tháng" and their corresponding numbers.
  - Return null if there's no date or time ranges in the request.
  - For example, "3 ngày" should be extracted as "3 days".
- City: The mentioned city (without "city" or "province").
- District: The mentioned district (without "district") and must be one frin this list: {district_list} or else return null.
- Price_range: Specify as "low", "medium", or "high" based on the request.

**For Hotels, also identify:**
- Requirements: A summary text of specific requirements or preferences mentioned.
- Amenities: IMPORTANT - ONLY include amenities from {amenities_list} if EXPLICITLY mentioned in the request. 
  Examples:
  - If request says "need hotel with pool and gym" → include ["Pool", "Gym"]
  - If request doesn't mention any amenities → return null
  - Do NOT assume or add amenities that weren't specifically mentioned
- Style: Only include styles from this list if explicitly mentioned in the request: {style_list} or else return null

**For Restaurants, also identify:**
- Requirements: A summary text of specific requirements or preferences mentioned.
- Restaurant_Type: From this list: {restaurant_type_list}
- Suitable_For: From this list: {suitable_for_list}

**For Tourist Attractions, also identify:**
- Requirements: A list of specific requirements or preferences mentioned.
- Attraction_Type: From this list: {attraction_type_list}

Return the result using the following JSON format:

```json
{{
  "General": {{
    "Type": "...",
    "Number_of_people": "...",
    "Companion": "...",
    "Transportation": "...",
    "Time": "...",
    "City": "...",
    "District": "...",
    "Price_range": "...",
    "
  }},
  "Hotel": {{
    "Requirements": ...,
    "Amenities": [...],
    "Style": [...]
  }},
  "Restaurant": {{
    "Requirements": ...,
    "Restaurant_Type": "...",
    "Suitable_For": "..."
  }},
  "TouristAttraction": {{
    "Attraction_Type": "..."
  }}
}}

```
IMPORTANT RULES:
1. For lists (Amenities, Style), RETURN null if none are EXPLICITLY mentioned. Do NOT make assumptions or add information that isn't clearly stated or mentioned
2. Keep output strictly aligned with the provided lists

Ensure the JSON is valid. Use null for any unspecified information.
After the JSON output, add a note in Vietnamese:

"Nếu bạn cần thay đổi hoặc bổ sung bất kỳ thông tin nào, vui lòng cho tôi biết."
"""

# %% [markdown]
# <!-- 1. Use null for ANY field where information is not EXPLICITLY mentioned
# 2. Do NOT make assumptions or add information that isn't clearly stated
# 3. When in doubt, return null -->

# %%
prompt = ChatPromptTemplate.from_template(template)
chain = prompt | llm

# %% [markdown]
# ##### Ask again if there's missing infor

# %% [markdown]
# ưu tiên hỏi time

# %%
# ask_template = """
# You are an AI travel suggestion chatbot. Analyze the following travel request:

# Request: "{travel_output_json}"

# ### **Core Rules:**
# 1. ONLY generate questions for fields that meet ALL of the following conditions:
#    - Field value is STRICTLY `null` in the JSON.
#    - Field is marked with *must ask question if this field is null, else not*.

# 2. STRICTLY DO NOT generate questions for:
#    - Fields with any NON-NULL value, even if they are marked with *must ask question if this field is null, else not*.
#    - Fields without *must ask question if this field is null, else not* marking, even if null.

# 3. Special Case for City Validation:
#    - If `"City"` has a value but is not in the `{city_list}`, ask if the user wants to change the city.

# 4. If ALL fields in the `General` section are NON-NULL:
#    - Ask the user if they want to add additional requirements for hotels, restaurants, or tourist attractions.

# 5. Questions about `"Time"` and `"Type"` must be asked first if these fields are null
# ---

# ### **Verification Process:**
# 1. For the `General` section:
#    - **Type**: *must ask question if this field is null, else not* Generate question ONLY if `Type` is `null`.
#    - **Number_of_people**: *must ask question if this field is null, else not* Generate question ONLY if `Number_of_people` is `null`
#    - **Companion**: *must ask question if this field is null, else not* Generate question ONLY if `Companion` is `null`.
#    - **Transportation**: *must ask question if this field is null, else not* Generate question ONLY if `Transportation` is `null`.
#    - **Time**: *must ask question if this field is null, else not* Generate question ONLY if `Time` is `null`.
#    - **Price_range**: *must ask question if this field is null, else not* Generate question ONLY if `Price_range` is `null`.

# 2. For City validation:
#    - If `"City"` is not in `{city_list}` but has a value, ask if the user wants to change it.

# 3. Additional Question (when General is fully completed):
#    - If ALL `General` fields have NON-NULL values, ask:
#      **"Bạn có muốn bổ sung thêm yêu cầu gì cho khách sạn, nhà hàng, hoặc địa điểm tham quan không?"**

# 4. STRICTLY SKIP any field with a non-`null` value.

# ---

# ### **Question Templates (ONLY use if field is NULL AND marked with *must ask question if this field is null, else not*):**
# 1. If `"Type"` is null, ask:  
#    **"Bạn muốn tìm loại hình du lịch nào? (Ví dụ: Food Tour, Văn hóa, Thư giãn, hoặc Trải nghiệm)"**
#    Ignore the question about Type if only ask for one of Hotels, Restaurants, or Tourist Attractions.
   
# 2. If `"Number_of_people"` is null, ask:  
#    **"Bạn đi bao nhiêu người? (Ví dụ: 1, 2, hoặc nhóm lớn hơn)"**

# 3. If `"Companion"` is null, ask:  
#    **"Bạn đi cùng ai? (Bạn bè, Gia đình, hoặc Đồng nghiệp)"**

# 4. If `"Transportation"` is null, ask:  
#    **"Bạn sẽ di chuyển bằng phương tiện gì? (Ví dụ: xe hơi tự lái, xe máy, hoặc phương tiện công cộng)"**

# 5. If `"Time"` is null, ask:  
#    **"Bạn có kế hoạch đi vào thời gian nào không? (Ngày cụ thể hoặc khoảng thời gian)"**

# 6. If `"Price_range"` is null, ask:  
#    **"Bạn muốn ngân sách cho chuyến đi này là bao nhiêu (thấp, trung bình, cao)?"**

# 7. Additional Question (when General is complete):
#    **"Bạn có muốn bổ sung thêm yêu cầu gì cho khách sạn, nhà hàng, hoặc địa điểm tham quan không?"**

# ### **Special Case - City Validation:**
# If City has a value but not in {city_list}:
# **"Hiện tại chúng tôi chưa cung cấp dịch vụ cho thành phố này mà chỉ có tại {city_list}, liệu bạn có muốn thay đổi thành phố không?"**

# ---

# ### **Output Format:**
# 1. Output questions ONLY for fields marked as *must ask question if this field is null, else not* and STRICTLY null.
# 2. Add city validation question if needed.
# 3. If ALL `General` fields are NON-NULL, add the question about additional requirements for hotels, restaurants, or attractions.
# 4. End with: **"Nếu bạn cần thay đổi hoặc bổ sung bất kỳ thông tin nào, vui lòng cho tôi biết."**

# ---

# ### **Example Output:**
# If the JSON input has:
# - `"Transportation"`: `null`
# - `"Time"`: `null`
# - `"City"`: `"Đà Nẵng"` (not in `{city_list}`),
  
# The output will be:

# ```plaintext
# Bạn sẽ di chuyển bằng phương tiện gì? (Ví dụ: xe hơi tự lái, xe máy, hoặc phương tiện công cộng)

# Bạn có kế hoạch đi vào thời gian nào không? (Ngày cụ thể hoặc khoảng thời gian)

# Hiện tại chúng tôi chưa cung cấp dịch vụ cho thành phố này mà chỉ có tại ['Hà Nội'], liệu bạn có muốn thay đổi thành phố không?

# Nếu bạn cần thay đổi hoặc bổ sung bất kỳ thông tin nào, vui lòng cho tôi biết.
# """

# %%
ask_template = """
You are an AI travel assistant chatbot. Analyze the following travel request:

Request: "{travel_output_json}"

### **Core Rules:**

1. **Identify Required Fields:**
    - Identify fields that are marked as "required" in the prompt.
    - If a required field is **null**, generate a question to clarify the user's preference. 

2. **STRICTLY DO NOT** generate questions for:
    - Fields with any **NON-NULL** value.
    - Fields without "required" marking in the prompt.

3. **City Validation:**
    - If the "City" field has a value but is not in the `{city_list}`, ask the user if they want to change the city.

4. **Additional Questions:**
    - Only ask additional questions about hotels, restaurants, or tourist attractions if all required fields in the "General" section have non-null values.

5. Questions about `"Time"` and `"Type"` MUST be ASKED FIRST ONLY if these fields are NULL
---

### **Verification Process:**
1. For the `General` section:
   - **Type** (required): Generate question ONLY if `Type` is `null`.
   - **Number_of_people** (required): Generate question ONLY if `Number_of_people` is `null`
   - **Companion** (required): Generate question ONLY if `Companion` is `null`.
   - **Transportation** (required):Generate question ONLY if `Transportation` is `null`.
   - **Time** (required): Generate question ONLY if `Time` is `null`.
   - **Price_range** (required): Generate question ONLY if `Price_range` is `null`.

2. For City validation:
   - If `"City"` is not in `{city_list}` but has a value, ask if the user wants to change it.

3. Additional Question (when General is fully completed):
   - If ALL required `General` fields have NON-NULL values, ask:
     **"Bạn có muốn bổ sung thêm yêu cầu gì cho khách sạn, nhà hàng, hoặc địa điểm tham quan không?"**

4. STRICTLY SKIP any field with a non-`null` value.

---

### **Question Templates (ONLY use if field is NULL AND marked with *must ask question if this field is null, else not*):**
1. If `"Type"` is null, ask:  
   **"Bạn muốn tìm loại hình du lịch nào? (Ví dụ: Food Tour, Văn hóa, Thư giãn, hoặc Trải nghiệm)"**
   Ignore the question about Type if only ask for one of Hotels, Restaurants, or Tourist Attractions.
   
2. If `"Number_of_people"` is null, ask:  
   **"Bạn đi bao nhiêu người? (Ví dụ: 1, 2, hoặc nhóm lớn hơn)"**

3. If `"Companion"` is null, ask:  
   **"Bạn đi cùng ai? (Bạn bè, Gia đình, hoặc Đồng nghiệp)"**

4. If `"Transportation"` is null, ask:  
   **"Bạn sẽ di chuyển bằng phương tiện gì? (Ví dụ: xe hơi tự lái, xe máy, hoặc phương tiện công cộng)"**

5. If `"Time"` is null, ask:  
   **"Bạn có kế hoạch đi vào thời gian nào không? (Ngày cụ thể hoặc khoảng thời gian)"**

6. If `"Price_range"` is null, ask:  
   **"Bạn muốn ngân sách cho chuyến đi này là bao nhiêu (thấp, trung bình, cao)?"**

7. Additional Question (when General is complete):
   **"Bạn có muốn bổ sung thêm yêu cầu gì cho khách sạn, nhà hàng, hoặc địa điểm tham quan không?"**

### **Special Case - City Validation:**
If City has a value but not in {city_list}:
**"Hiện tại chúng tôi chưa cung cấp dịch vụ cho thành phố này mà chỉ có tại {city_list}, liệu bạn có muốn thay đổi thành phố không?"**

---

### **Output Format:**
1. Output questions ONLY for fields marked as `required` in the prompt and STRICTLY null.
2. Add city validation question if needed.
3. If ALL required `General` fields are NON-NULL, add the question about additional requirements for hotels, restaurants, or attractions.
4. End with: **"Nếu bạn cần thay đổi hoặc bổ sung bất kỳ thông tin nào, vui lòng cho tôi biết."**

---

### **Example Output:**
If the JSON input has:
- `"Transportation"`: `null`
- `"Time"`: `null`
- `"City"`: `"Đà Nẵng"` (not in `{city_list}`),
  
The output will be:

```plaintext
Bạn sẽ di chuyển bằng phương tiện gì? (Ví dụ: xe hơi tự lái, xe máy, hoặc phương tiện công cộng)

Bạn có kế hoạch đi vào thời gian nào không? (Ngày cụ thể hoặc khoảng thời gian)

Hiện tại chúng tôi chưa cung cấp dịch vụ cho thành phố này mà chỉ có tại ['Hà Nội'], liệu bạn có muốn thay đổi thành phố không?

Nếu bạn cần thay đổi hoặc bổ sung bất kỳ thông tin nào, vui lòng cho tôi biết.
"""

# %% [markdown]
# <!-- -**Ask only if specific fields are both strictly `null` and marked as *must ask question if this field is null, else not*. Strictly skip the question for any field that has a non-null value, regardless of whether it is marked with *must ask question if this field is null, else not*.**
# -**If a field has a value different from `null`, skip the question.**
# ---
#
# Analyze the JSON to find the fields that have null value. **Only ask questions for fields explicitly marked as *must ask question if this field is null, else not* and set to `null`.** If a populated field is not in the required list, ask if the user would like to change it to a valid option.
#
# **Generate questions for null values in *must ask question if this field is null, else not* fields and if necessary, verify if the City needs adjustment:**
# **Skip the question for any field that has a non-null value, regardless of whether it is marked with *must ask question if this field is null, else not*.**
#  -->

# %%
ask_prompt = ChatPromptTemplate.from_template(ask_template)
ask_chain = ask_prompt | llm

# %% [markdown]
# ##### prompt to update requirement json

# %%
updated_query = """
You are an AI travel suggestion chatbot. Analyze the following travel request:

Update request: "{update_travel_request}"

Extract general requirements from request while following these rules:
1. IMPORTANT: Preserve ALL non-null values from the initial request JSON
2. Only update fields that are null in the initial request OR if the city is explicitly changed
3. For new information, extract the following:

**General Requirements:**
- Type: ONLY CLASSIFY INTO TWO TYPES from {travel_type_list}. Analyze the response and map to:
  "Nghỉ dưỡng" if response mentions/implies relaxation-focused activities:
    Keywords to check:
    - "nghỉ mát", "nghỉ dưỡng", "thư giãn"
    - "resort", "spa", "biển"
    - "nghỉ ngơi", "thư thái"
    - "resort", "khách sạn sang trọng"
    Examples:
    - Response: "food tour" -> classify as: "Khám phá"
    - Response: "nghỉ dưỡng" -> classify as: "Nghỉ dưỡng"
    
  "Khám phá" if response mentions/implies exploration and activity-focused activities:
    Keywords to check:
    - "khám phá", "tham quan", "trải nghiệm"
    - "du lịch", "phượt", "tour"
    - "văn hóa", "ẩm thực", "food tour"
    - "địa điểm", "danh lam thắng cảnh"
    Examples:
    - Response: "trải nghiệm văn hóa" -> classify as: "Khám phá"
    - Response: "địa điểm tham quan" -> classify as: "Khám phá"
- Number_of_people: Extract the number of people.
- Companions: Extract the companions mentioned in the request and translated it if it needed, must be one from this list: {companion_list}.
- Transportation: Identify the transportation method mentioned in the request and translated, convert it if it needed, transportation must be one from this list: {transport_list}.
- Time: Any specific dates or time ranges mentioned.
- City: The mentioned city (without "city" or "province") and must be one from this list: {city_list}.
- Price_range: Specify as "low", "medium", or "high" based on the request.

**For Hotels, also identify:**
- Requirements: A summary text of specific requirements or preferences mentioned.
- Amenities: IMPORTANT - ONLY include amenities from {amenities_list} if EXPLICITLY mentioned in the request. 
  Examples:
  - If request says "need hotel with pool and gym" → include ["Pool", "Gym"]
  - If request doesn't mention any amenities → return null
  - Do NOT assume or add amenities that weren't specifically mentioned
- Style: Only include styles from this list if explicitly mentioned in the request: {style_list} or else return null

**For Restaurants, also identify:**
- Requirements: A summary text of specific requirements or preferences mentioned.
- Restaurant_Type: From this list: {restaurant_type_list}
- Suitable_For: From this list: {suitable_for_list}

**For Tourist Attractions, also identify:**
- Requirements: A list of specific requirements or preferences mentioned.
- Attraction_Type: From this list: {attraction_type_list}

Initial request: "{travel_output_json}"

Merge the initial request with any updates, prioritizing:
1. Keeping all non-null values from initial request
2. Only updating null fields or explicitly changed city
3. Using the following JSON format:

```json
{{
  "General": {{
    "Type": "...",
    "Number_of_people": "...",
    "Companion": "...",
    "Transportation": "...",
    "Time": "...",
    "City": "...",
    "District": "...",
    "Price_range": "...",
    "
  }},
  "Hotel": {{
    "Requirements": ...,
    "Amenities": [...],
    "Style": [...]
  }},
  "Restaurant": {{
    "Requirements": ...,
    "Restaurant_Type": "...",
    "Suitable_For": "..."
  }},
  "TouristAttraction": {{
    "Attraction_Type": "..."
  }}
}}

```

IMPORTANT VERIFICATION STEPS:
1. Before outputting, for all other fields, verify that all non-null values from the initial request are preserved unless explicitly changed in the update request.
2. Check if the update is a response to the Type question. If yes, analyze the response using the keyword mapping above
3. Classify into either "Nghỉ dưỡng" or "Khám phá"

Ensure the JSON is valid. Use null for any unspecified information.
After the JSON output, add a note in Vietnamese:

"Nếu bạn cần thay đổi hoặc bổ sung bất kỳ thông tin nào, vui lòng cho tôi biết."
"""

# %% [markdown]
# <!-- **For Hotels:**
# - Amenities: If in Transportation they give information about "car", add "Bãi đậu xe" to the Amenities. -->

# %%
update_prompt = ChatPromptTemplate.from_template(updated_query)
update_chain = update_prompt | llm

# %% [markdown]
# #### Query from user requests

# %% [markdown]
# ##### User requirement

# %% [markdown]
# different user input query situation

# %%
# user input query has specific request for hotel, restaurant and attraction
user_query = """
Gợi ý cho tôi một lộ trình du lịch tại Hà Nội với khách sạn sang trọng, có Bồn tắm, bể bơi và Mát-xa toàn thân, nhà hàng phục vụ món ăn truyền thống và một điểm tham quan nổi tiếng phù hợp cho trẻ em về đề tài lịch sử.
Tôi muốn biết thêm về các tiện nghi của khách sạn và phong cách của nhà hàng.
Chúng tôi đi 4 người.
"""

# %%
# user input query has very few info
user_query = """
Gợi ý cho tôi một lộ trình du lịch tại Đà Nẵng với khách sạn sang trọng.
Gia đình tôi đi 4 người.
"""

# %%
# user input query has enough info about general
user_query = """
Gợi ý cho tôi một chuyến đi nghỉ dưỡng tại Hà Nội trong 3 ngày với chí phí hợp lý. Chúng tôi đi máy bay tới, không có xe cá nhân.
Gia đình tôi đi 4 người.
"""

# %% [markdown]
# first response

# %%
def user_requires(chain, query, travel_type_list, companion_list, transport_list, city_list, district_list, 
                  amenities_list_str, style_list_str, res_type_list_str, res_suit_list_str, att_type_list_str):
    response = chain.invoke({
        "travel_request": query,
        "travel_type_list": travel_type_list,
        "companion_list": companion_list,
        "transport_list": transport_list,
        "city_list": city_list,
        "district_list": district_list,
        "amenities_list": amenities_list_str,
        "style_list": style_list_str,
        "restaurant_type_list": res_type_list_str,
        "suitable_for_list": res_suit_list_str,
        "attraction_type_list": att_type_list_str
    })

    # Extract and parse the JSON response
    try:
        json_match = re.search(r'\{.*\}', response.content, re.DOTALL)
        if json_match:
            result_dict = json.loads(json_match.group(0))
            
            # Print the JSON result
            print("Extracted JSON Result:")
            print(json.dumps(result_dict, indent=2, ensure_ascii=False))
            return result_dict
        else:
            print("No JSON object found in the response.")
            return None
    except json.JSONDecodeError as e:
        print("Failed to decode JSON:", e)
        print("Raw response:", response.content)
        return None

# %%
user_requires_respond = user_requires(chain, user_query, travel_type_list, companion_list, transport_list, city_list, district_list, amenities_list_str, style_list_str, res_type_list_str, res_suit_list_str, att_type_list_str)
# Out:
# Extracted JSON Result:
# {
#   "General": {
#     "Type": "Nghỉ dưỡng",
#     "Number_of_people": 4,
#     "Companion": "family",
#     "Transportation": "public transport",
#     "Time": "3 days",
#     "City": "Hà Nội",
#     "District": null,
#     "Price_range": "low"
#   },
#   "Hotel": {
#     "Requirements": "Chí phí hợp lý",
#     "Amenities": null,
#     "Style": null
#   },
#   "Restaurant": {
#     "Requirements": null,
#     "Restaurant_Type": null,
#     "Suitable_For": "Ăn gia đình"
#   },
#   "TouristAttraction": {
#     "Requirements": null,
#     "Attraction_Type": null
#   }
# }

# %% [markdown]
# ask again if missing values

# %%
def ask_user(ask_chain, response, travel_type_list, companion_list, transport_list, city_list, district_list, 
                  amenities_list_str, style_list_str, res_type_list_str, res_suit_list_str, att_type_list_str):
    response1 = ask_chain.invoke({
        "travel_output_json": response,
        "travel_type_list": travel_type_list,
        "companion_list": companion_list,
        "transport_list": transport_list,
        "city_list": city_list,
        "district_list": district_list,
        "amenities_list": amenities_list_str,
        "style_list": style_list_str,
        "restaurant_type_list": res_type_list_str,
        "suitable_for_list": res_suit_list_str,
        "attraction_type_list": att_type_list_str
    })

    print("Cảm ơn bạn đã cung cấp thông tin! Tuy nhiên, tôi cần thêm một số thông tin để giúp bạn tốt hơn:")
    # print(response1.content)
    user_responses = {}

    # Process each line in the response content as a separate question
    questions = response1.content.splitlines()
    for question in questions:
        # Remove "plaintext:" prefix if it exists and trim whitespace
        question = question.replace("```plaintext", "").replace("```", "").strip()
        
        # Skip empty lines and avoid re-asking filled fields
        if not question or "Nếu bạn cần thay đổi hoặc bổ sung bất kỳ thông tin nào" in question:
            print(question)  # Print closing statement without asking for input
            continue
        
        # Ask the user for input and store the response
        user_input = input(f"{question} ")
        user_responses[question] = f"[{user_input.strip()}]"
        
    # Print the responses collected for review
    print("\nCollected User Responses:")
    for field, answer in user_responses.items():
        print(f"{field}: {answer}")
    
    print("Nếu bạn cần thay đổi hoặc bổ sung bất kỳ thông tin nào, vui lòng cho tôi biết.")
    return user_responses

# %%
response1 = ask_chain.invoke({
        "travel_output_json": user_requires_respond,
        "travel_type_list": travel_type_list,
        "companion_list": companion_list,
        "transport_list": transport_list,
        "city_list": city_list,
        "district_list": district_list,
        "amenities_list": amenities_list_str,
        "style_list": style_list_str,
        "restaurant_type_list": res_type_list_str,
        "suitable_for_list": res_suit_list_str,
        "attraction_type_list": att_type_list_str
})

print(response1.content)
# Out:
# ```plaintext
# Bạn có muốn bổ sung thêm yêu cầu gì cho khách sạn, nhà hàng, hoặc địa điểm tham quan không?
#
# Nếu bạn cần thay đổi hoặc bổ sung bất kỳ thông tin nào, vui lòng cho tôi biết.
# ```

# %%
ask_again_respond = ask_user(ask_chain, user_requires_respond, travel_type_list, companion_list, transport_list, city_list, district_list, amenities_list_str, style_list_str, res_type_list_str, res_suit_list_str, att_type_list_str)
# Out:
# Cảm ơn bạn đã cung cấp thông tin! Tuy nhiên, tôi cần thêm một số thông tin để giúp bạn tốt hơn:
#
#
# Nếu bạn cần thay đổi hoặc bổ sung bất kỳ thông tin nào, vui lòng cho tôi biết.
#
#
# Collected User Responses:
# Bạn có muốn bổ sung thêm yêu cầu gì cho khách sạn, nhà hàng, hoặc địa điểm tham quan không?: [khách sạn và chỗ ăn cho gia đình, khách sạn có bể bơi, và khu vui chơi liên quan đến lịch sử]
# Nếu bạn cần thay đổi hoặc bổ sung bất kỳ thông tin nào, vui lòng cho tôi biết.

# %% [markdown]
# update requirement json

# %%
def update_requires(update_chain, first_respond, travel_type_list, companion_list, transport_list, city_list, update_respond,
                    amenities_list_str, style_list_str, res_type_list_str, res_suit_list_str, att_type_list_str):
    response = update_chain.invoke({
        "update_travel_request": update_respond,
        "travel_type_list": travel_type_list,
        "companion_list": companion_list,
        "transport_list": transport_list,
        "city_list": city_list,
        "travel_output_json": first_respond,
        "amenities_list": amenities_list_str,
        "style_list": style_list_str,
        "restaurant_type_list": res_type_list_str,
        "suitable_for_list": res_suit_list_str,
        "attraction_type_list": att_type_list_str
    })

    # Extract and parse the JSON response
    try:
        json_match = re.search(r'\{.*\}', response.content, re.DOTALL)
        if json_match:
            result_dict = json.loads(json_match.group(0))
            
            # Print the JSON result
            print("Extracted JSON Result:")
            print(json.dumps(result_dict, indent=2, ensure_ascii=False))
            return result_dict
        else:
            print("No JSON object found in the response.")
            return None
    except json.JSONDecodeError as e:
        print("Failed to decode JSON:", e)
        print("Raw response:", response.content)
        return None

# %%
update_requires_respond = update_requires(update_chain, user_requires_respond, travel_type_list, companion_list, transport_list, city_list, ask_again_respond,amenities_list_str, style_list_str, res_type_list_str, res_suit_list_str, att_type_list_str)
# Out:
# Extracted JSON Result:
# {
#   "General": {
#     "Type": "Khám phá",
#     "Number_of_people": 4,
#     "Companion": "family",
#     "Transportation": "public transport",
#     "Time": "3 days",
#     "City": "Hà Nội",
#     "District": null,
#     "Price_range": "low"
#   },
#   "Hotel": {
#     "Requirements": "Chí phí hợp lý, khách sạn có bể bơi",
#     "Amenities": [
#       "Hồ bơi"
#     ],
#     "Style": [
#       "Family-friendly"
#     ]
#   },
#   "Restaurant": {
#     "Requirements": "khách sạn và chỗ ăn cho gia đình",
#     "Restaurant_Type": null,
#     "Suitable_For": "Ăn gia đình"
#   },
#   "TouristAttraction": {
#     "Requirements": "khu vui chơi liên quan đến lịch sử",
#     "Attraction_Type": [
#       "Khu vực đi dạo tham quan di tích lịch sử",
#       "Địa điểm lịch sử"
#     ]
#   }
# }

# %% [markdown]
# ##### query from database

# %%
def build_sql_query_individual(table, requirements, general_requirements, schema="travel_database"):
    conditions = []
    joins = ""
    
    # Define the ID column based on the table
    id_column = "id"
    if table == "hotel":
        id_column = "hotel_id"
    elif table == "restaurant":
        id_column = "res_id"
    elif table == "touristattraction":
        id_column = "attraction_id"
    
    # Handle Price_range for each table with join and conditions
    if general_requirements.get("Price_range"):
        price_range = general_requirements["Price_range"]
        if table == "hotel":
            joins += f" JOIN {schema}.hotelprice ON {schema}.hotel.hotel_id = {schema}.hotelprice.hotel_id"
            if price_range == "low":
                conditions.append(f"{schema}.hotelprice.price < 500000")
            elif price_range == "medium":
                conditions.append(f"{schema}.hotelprice.price <= 2000000")
            elif price_range == "high":
                conditions.append(f"{schema}.hotelprice.price > 2000000")
        elif table == "restaurant":
            if price_range == "low":
                conditions.append(f"CAST({schema}.restaurant.price_range->>'max_price' AS INTEGER) < 200000")
            elif price_range == "medium":
                conditions.append(f"CAST({schema}.restaurant.price_range->>'max_price' AS INTEGER) <= 600000")
            elif price_range == "high":
                conditions.append(f"CAST({schema}.restaurant.price_range->>'min_price' AS INTEGER) >= 0")
        elif table == "touristattraction":
            joins += f" JOIN {schema}.attractionprice ON {schema}.touristattraction.attraction_id = {schema}.attractionprice.attraction_id"
            if price_range == "low":
                conditions.append(f"{schema}.attractionprice.price < 500000")
            elif price_range == "medium":
                conditions.append(f"{schema}.attractionprice.price < 1500000")
            elif price_range == "high":
                conditions.append(f"{schema}.attractionprice.price >= 0")
    
    if general_requirements.get("Transportation"):
        if general_requirements["Transportation"] == "self-drive car":
            if table == "restaurant":
                conditions.append(f"{schema}.restaurant.parking_available = TRUE")
            elif table == "hotel":
                conditions.append(f"('Bãi đậu xe' = ANY({schema}.hotel.amenities) OR 'Garage' = ANY({schema}.hotel.amenities))")

    if general_requirements.get("District"):
        district = general_requirements["District"]
        if table == "hotel":
            conditions.append(f"unaccent(lower(({schema}.hotel.address).district)) ILIKE unaccent('%{district}%')")
        elif table == "restaurant":
            conditions.append(f"unaccent(lower(({schema}.restaurant.address).district)) ILIKE unaccent('%{district}%')")
        elif table == "touristattraction":
            conditions.append(f"unaccent(lower(({schema}.touristattraction.address).district)) ILIKE unaccent('%{district}%')")
    # Process specific requirements for each table
    if table == "hotel":
        if requirements.get("Amenities"):
            amenities_condition = (" AND ".join([f"'{amenity}' = ANY({schema}.hotel.amenities)" for amenity in requirements["Amenities"]]))
            conditions.append(f"({amenities_condition})")
        if requirements.get("Style"):
            styles_condition = (" OR ".join([f"{schema}.hotel.style LIKE '{style}%'" for style in requirements["Style"]]))
            conditions.append(f"({styles_condition})")
    elif table == "restaurant":
        if requirements.get("Restaurant_Type"):
            conditions.append(f"'{requirements['Restaurant_Type']}' = ANY({schema}.restaurant.restaurant_type)")
        if requirements.get("Suitable_For"):
            conditions.append(f"'{requirements['Suitable_For']}' = ANY({schema}.restaurant.suitable_for)")
    elif table == "touristattraction":
        if requirements.get("Attraction_Type"):
            conditions.append(f"'{requirements['Attraction_Type']}' = ANY({schema}.touristattraction.attraction_type)")

    # Build the WHERE clause and complete query
    where_clause = " AND ".join(conditions)
    query = (
        f"SELECT DISTINCT {schema}.{table}.{id_column}, {schema}.{table}.name "
        f"FROM {schema}.{table} {joins} WHERE {where_clause};"
        if conditions else
        f"SELECT {schema}.{table}.{id_column}, {schema}.{table}.name FROM {schema}.{table};"
    )

    return query

# %%
def fetch_locations(query):
    conn = psycopg2.connect(postgres_url)
    cur = conn.cursor()

    cur.execute("CREATE EXTENSION IF NOT EXISTS unaccent;")
    # Thiết lập search_path
    cur.execute("""SET search_path TO travel_database, public;""")
    
    cur.execute(query)

    # Lấy tất cả các kết quả
    results = cur.fetchall()

    return results

    # Đóng kết nối
    cur.close()
    conn.close()

# %%
general_requirements = update_requires_respond.get("General", {})
hotel_requirements = update_requires_respond.get("Hotel", {})
restaurant_requirements = update_requires_respond.get("Restaurant", {})
attraction_requirements = update_requires_respond.get("TouristAttraction", {})

# Build SQL queries
hotel_query_indi = build_sql_query_individual("hotel", hotel_requirements, general_requirements)
restaurant_query_indi = build_sql_query_individual("restaurant", restaurant_requirements, general_requirements)
attraction_query_indi = build_sql_query_individual("touristattraction", attraction_requirements, general_requirements)

print("Hotel Query:", hotel_query_indi)
print("\nRestaurant Query:", restaurant_query_indi)
print("\nAttraction Query:", attraction_query_indi)
# Out:
# Hotel Query: SELECT DISTINCT travel_database.hotel.hotel_id, travel_database.hotel.name FROM travel_database.hotel  JOIN travel_database.hotelprice ON travel_database.hotel.hotel_id = travel_database.hotelprice.hotel_id WHERE travel_database.hotelprice.price > 2000000 AND ('Bãi đậu xe' = ANY(travel_database.hotel.amenities) OR 'Garage' = ANY(travel_database.hotel.amenities)) AND (travel_database.hotel.style LIKE 'Luxury%');
#
# Restaurant Query: SELECT DISTINCT travel_database.restaurant.res_id, travel_database.restaurant.name FROM travel_database.restaurant  WHERE CAST(travel_database.restaurant.price_range->>'min_price' AS INTEGER) >= 0 AND travel_database.restaurant.parking_available = TRUE;
#
# Attraction Query: SELECT DISTINCT travel_database.touristattraction.attraction_id, travel_database.touristattraction.name FROM travel_database.touristattraction  JOIN travel_database.attractionprice ON travel_database.touristattraction.attraction_id = travel_database.attractionprice.attraction_id WHERE travel_database.attractionprice.price >= 0;

# %%
general_requirements = update_requires_respond.get("General", {})
hotel_requirements = update_requires_respond.get("Hotel", {})
restaurant_requirements = update_requires_respond.get("Restaurant", {})
attraction_requirements = update_requires_respond.get("TouristAttraction", {})

# Build SQL queries
hotel_query_indi = build_sql_query_individual("hotel", hotel_requirements, general_requirements)
restaurant_query_indi = build_sql_query_individual("restaurant", restaurant_requirements, general_requirements)
attraction_query_indi = build_sql_query_individual("touristattraction", attraction_requirements, general_requirements)

hotel_locations = fetch_locations(hotel_query_indi)
restaurant_locations = fetch_locations(restaurant_query_indi)
attraction_locations = fetch_locations(attraction_query_indi)

# In ra danh sách các địa điểm để kiểm tra
# Print Hotel Locations
print("Hotel Locations:")
for location in hotel_locations:
    print(f"    id: {location[0]}, name: {location[1]}")

# Print Restaurant Locations
print("\nRestaurant Locations:")
for location in restaurant_locations:
    print(f"    id: {location[0]}, name: {location[1]}")

# Print Tourist Attraction Locations
print("\nTourist Attraction Locations:")
for location in attraction_locations:
    print(f"    id: {location[0]}, name: {location[1]}")
# Out:
# Hotel Locations:
#     id: 7, name: Khách sạn Melia Hà Nội
#     id: 8, name: Grand K Hotel Suites Hanoi
#     id: 9, name: Muong Thanh Hanoi Centre Hotel
#     id: 10, name: Lotte Hotel Hanoi
#     id: 17, name: Super Hotel Candle
#     id: 27, name: L7 West Lake Hanoi By Lotte
#     id: 44, name: Army Hotel
#     id: 47, name: InterContinental Hotels HANOI LANDMARK72, an IHG Hotel
#     id: 51, name: Khách sạn Grand Plaza Hà Nội
#     id: 63, name: Pan Pacific Hanoi
#     id: 80, name: Grandiose Hotel & Spa
#     id: 83, name: Hotel de l'Opera Hanoi - Mgallery
#     id: 90, name: Somerset Hoa Binh Hanoi
#     id: 109, name: Novotel Hanoi Thai Ha
#     id: 123, name: Sen Grand Hotel & Spa
#     id: 134, name: Khách sạn Elegant Suites Westlake
#     id: 150, name: Fraser Residence Hanoi
#     id: 205, name: Hôtel du Parc Hanoï
#     id: 238, name: Khách sạn Hồng Ngọc Dynastie
#     id: 245, name: WEST LAKE 254D HOTEL & RESIDENCE
#     id: 257, name: Khách sạn Fraser Suites Hà Nội
#     id: 312, name: Roygent Parks Hanoi
#     id: 333, name: Wyndham Sky Lake Resort & Villas
#     id: 334, name: InterContinental Hotels HANOI WESTLAKE, an IHG Hotel
#     id: 453, name: Khách sạn Grand Mercure
#     id: 500, name: FTE Ba Dinh Hotel
#     id: 542, name: La Sinfonia del Rey Hotel and Spa
#     id: 594, name: Hi.Home - Vinhomes Metropolis
#     id: 596, name: NCC Garden Villas
#     id: 609, name: Khách sạn Pullman Hà Nội
#     id: 615, name: Property Plus Luxury Apartment - Vinhomes Metropolis
#     id: 619, name: Hanoi La Selva Central Hotel
#     id: 626, name: Le Jardin Hotel Haute Couture Hanoi
#     id: 948, name: Somerset West Point Hanoi
#     id: 1139, name: Au Co Art Classic Hotel & Spa
#     id: 1353, name: The Five Suites Lilas
#     id: 1414, name: Daeha Serviced Apartment
#     id: 1438, name: Asahi Japan - Royal City Apartment
#     id: 1934, name: Garco Dragon Hotel 2
#     id: 2026, name: Paradise Soc Son Resort
#     id: 2054, name: Hovi Dai Loi
#     id: 2178, name: Khách sạn Hilton Hà Nội
#     id: 2240, name: Glory Resort
#     id: 2707, name: Dolphin Plaza
#
# Restaurant Locations:
#     id: 232, name: S&L's Diner - Ẩm Thực Mỹ - Bảo Khánh
#     id: 364, name: Ưu Đàm Chay
#     id: 85, name: Gà Rán KFC - Bạch Mai
#     id: 122, name: Yakimono - Nướng Nhật Bản - Nguyên Hồng
#     id: 312, name: Vua Chả Cá - Mai Hắc Đế
#     id: 377, name: Bồ Đề Chay - Quán Sứ
#     id: 276, name: Le Club Bar - Sofitel Legend Metropole Hanoi
#     id: 130, name: Nhà Hàng Hương Sen - Buffet Hải Sản Cao Cấp
#     id: 91, name: Gà Rán KFC - Hoàn Kiếm
#     id: 302, name: San Hô - Hải Sản Tươi Sống
#     id: 33, name: Lotteria - Kim Mã
#     id: 309, name: Mirai - Sushi & Sake
#     id: 203, name: Thái Pattaya - Phố Nướng Lẩu Thái Lan
#     id: 117, name: Namaste Hanoi - Ẩm Thực Ấn Độ
#     id: 397, name: Highlands Coffee - Trà, Cà Phê & Bánh - Somerset Hòa Bình
#     id: 410, name: Highlands Coffee - Trà, Cà Phê & Bánh - Fivimart Hà Đông
#     id: 178, name: New York Sport Bar - Món Ăn Âu & Á - Bà Triệu
#     id: 399, name: Highlands Coffee - Trà, Cà Phê & Bánh - Cột Cờ
#     id: 148, name: Al Fresco's - Pizza, Mỳ Ý, Sườn, Steak Bò Bít Tết - Trần Thái Tông
#     id: 553, name: Gia Bảo Bakery - Nguyễn Trãi
#     id: 315, name: Nhà Hàng Ngon - Trần Hưng Đạo
#     id: 77, name: Moo Beef Steak II
#     id: 304, name: Gimbap Shochu - Ẩm Thực Hàn Quốc
#     id: 258, name: Nhà Hàng Chay Aummee - Đồ Ăn Chay - Châu Long
#     id: 168, name: Phở 10 Lý Quốc Sư
#     id: 225, name: Tomato - Hải Sản Tươi Sống - Nguyễn Thị Định
#     id: 84, name: Khazaana 1992 - Ẩm Thực Ấn Độ
#     id: 290, name: Nhà Hàng Chay Aummee - Đồ Ăn Chay - Châu Long
#     id: 310, name: Vua Chả Cá - Nguyễn Thị Định
#     id: 6, name: Maison Vie - Nhà Hàng Kiểu Pháp
#     id: 102, name: Paris Deli - Phan Chu Trinh
#     id: 231, name: The Vin Steak - Xuân Diệu
#     id: 272, name: Le Club Bar - Sofitel Legend Metropole Hanoi
#     id: 31, name: Lotteria - Cầu Giấy
#     id: 586, name: Tiến Đạt Bakery - Bánh Ngọt Pháp
#     id: 94, name: Gà Rán KFC - Tây Sơn
#     id: 416, name: Highlands Coffee - Trà, Cà Phê & Bánh - Machinco
#     id: 375, name: Chay Tâm Đức
#     id: 198, name: Seoul Garden - Buffet Lẩu & Nướng Trần Hưng Đạo
#     id: 292, name: X-Men Karaoke Restaurant
#     id: 466, name: O Hiền - Bún Bò Huế & Lẩu Đuôi Bò - Trung Kính
#     id: 282, name: Highway4 - Trần Thái Tông
#     id: 149, name: Al Fresco's - Pizza, Mỳ Ý, Sườn, Steak Bò Bít Tết - Hoàng Ngân
#     id: 140, name: Gumiho - Quán Nhậu Cho Các Nàng
#     id: 11, name: Sumo BBQ - Nhà Hàng Thịt Nướng Nhật Bản - Huỳnh Thúc Kháng
#     id: 467, name: Sồi Đỏ - Pizza & Pasta - Phó Đức Chính
#     id: 8, name: Jacksons Steakhouse Hanoi
#     id: 293, name: MiShaGi - Lẩu Nướng Nhật Bản
#     id: 43, name: Daikon Foods - Restaurant & Café
#     id: 299, name: Shamoji Robata Yaki - Xuân Diệu
#     id: 517, name: Mochi Sweets - Nguyễn Trãi
#     id: 138, name: Manwah Taiwanese Hotpot - Thái Hà
#     id: 47, name: Bánh Mỳ Bít Tết Cutisun - Long Biên
#     id: 229, name: Khana Khazana - India Restaurant
#     id: 105, name: Pizza Hut - Xuân Thủy
#     id: 184, name: Hutong - Hot Pot Paradise - Trần Duy Hưng
#     id: 204, name: Thái Pattaya - Phố Nướng Lẩu Thái Lan
#     id: 326, name: De Chang Kưm - Ẩm thực Hàn Quốc
#     id: 131, name: Chả Cá Hà Thành - Nguyễn Văn Huyên
#     id: 351, name: Smile Tea & Coffee
#     id: 57, name: Spaghetti Box - Lê Ngọc Hân
#     id: 109, name: Pizza Hut - Xuân La
#     id: 49, name: Habit BBQ - Lẩu Nướng Không Khói
#     id: 157, name: Gà Rán & Burger McDonald's - Hoàng Đạo Thúy
#     id: 153, name: Nét Huế - Trần Duy Hưng
#     id: 227, name: Lương Sơn Quán - Quan Nhân
#     id: 409, name: Highlands Coffee - Trà, Cà Phê & Bánh - Rose Garden
#     id: 401, name: Highlands Coffee - Trà, Cà Phê & Bánh - Nhà Hát Lớn
#     id: 243, name: Nhà Sàn 141 - Lẩu, Đồ Nướng & Nhậu
#     id: 123, name: Yakimono - Nướng Nhật Bản - Lê Trọng Tấn
#     id: 44, name: Essence Cafe & Restaurant
#     id: 20, name: Domino's Pizza - AEON Mall Long Biên
#     id: 23, name: Sio Sushi - Lê Đại Hành
#     id: 214, name: La Cheminée Restaurant - Pullman Hanoi Hotel
#     id: 295, name: Góc Hà Nội - Ẩm Thực Hà Thành
#     id: 82, name: Nhà Hàng 123 - Kim Mã
#     id: 311, name: Vua Chả Cá - Trần Hưng Đạo
#     id: 234, name: Joma Bakery Cafe - Liễu Giai
#     id: 189, name: Món Ngon Sài Thành - Huỳnh Thúc Kháng
#     id: 13, name: Sumo BBQ - Nhà Hàng Thịt Nướng Nhật Bản - Tô Hiến Thành
#     id: 15, name: Jacksons Steakhouse Hanoi
#     id: 28, name: KOMBO - Cơm Niêu Singapore - Nguyễn Phong Sắc
#     id: 14, name: Salmonoid - Món Âu - Cao Bá Quát
#     id: 478, name: New Style Coffee - Cafe Phở Gà Cơm Văn Phòng - Tô Hiệu
#     id: 266, name: Highway4 - Trần Thái Tông
#     id: 506, name: Anh Hòa Bakery & Coffee - Kim Đồng
#     id: 113, name: Skyline Hanoi - Gia Ngư
#     id: 169, name: Eureka Coffee & Fastfood
#     id: 104, name: Pizza Hut - Kim Mã
#     id: 16, name: Grille6 - Salad, Steak & Pasta - Hào Nam
#     id: 215, name: Voyage - Hotel Du Parc Hanoi
#     id: 226, name: Tomato - Hải Sản Tươi Sống - Lê Văn Hưu
#     id: 370, name: Nhà Hàng Chay Aummee - Đồ Ăn Chay - Châu Long
#     id: 195, name: Luk Chew - Ẩm Thực HongKong
#     id: 398, name: Highlands Coffee - Trà, Cà Phê & Bánh - Syrena
#     id: 316, name: Paku Paku - Japanese Restaurant
#     id: 411, name: Highlands Coffee - Trà, Cà Phê & Bánh - Fivimart Mỹ Đình
#     id: 79, name: Yu Tang - Trà Sữa & Mỳ Đài Loan - Thái Phiên
#     id: 275, name: Chops - Hops, Wheat & Meat - Quảng An
#     id: 192, name: Nhà hàng 1946 - Cửa Bắc
#     id: 32, name: Lotteria - Trần Duy Hưng
#     id: 528, name: Poeme - Hoàng Văn Thái
#     id: 26, name: KOMBO - Cơm Niêu Singapore - Lê Văn Thiêm
#     id: 213, name: Nướng Nhà Mắm - Lẩu & Nướng
#     id: 207, name: Măm Măm Steak - Giảng Võ
#     id: 400, name: Highlands Coffee - Trà, Cà Phê & Bánh - Big C Hà Nội
#     id: 136, name: Hoa Viên Brauhaus - Tăng Bạt Hổ
#     id: 118, name: Sushi Nhật Bản Aozora
#     id: 514, name: Mochi Sweets - Bùi Thị Xuân
#     id: 223, name: Nhà Hàng Hải Sản Lã Vọng
#     id: 520, name: Joma Bakery Cafe - Liễu Giai
#     id: 221, name: Meat Plus - No.1 Korea Bbq - Trung Yên
#     id: 125, name: Nhà 9NKC Fusion Restaurant & Cafeteria
#     id: 58, name: Don Chicken - Chicken & Pub - Hàng Bông
#     id: 76, name: Gogi House - Nướng Hàn Quốc - Tô Hiệu
#     id: 93, name: Gà Rán KFC - Yên Phụ
#     id: 129, name: Angelina Restaurant & Lounge - Sofitel Legend Metropole Hanoi
#     id: 7, name: Essence Cafe & Restaurant
#     id: 128, name: Maison Vie - Nhà Hàng Kiểu Pháp
#     id: 132, name: Bánh Tôm Hồ Tây
#     id: 70, name: GoGi House - Nướng Hàn Quốc - Trung Hòa
#     id: 317, name: Buffet Việt - Tăng Bạt Hổ
#     id: 402, name: Highlands Coffee - Trà, Cà Phê & Bánh - VTV Outside
#     id: 265, name: Takumi-Ya Hanoi - Ẩm Thực Nhật Bản
#     id: 208, name: La Salsa - Món Âu - Xuân Diệu
#     id: 349, name: Cafe 555 - Hà Đông
#     id: 348, name: Bastet's Home - Trà Sữa & Ăn Vặt - Hà Đông
#     id: 86, name: Gà Rán KFC - BigC Hà Nội
#     id: 2, name: Buffet Sen - Khu Văn Hoá Ẩm Thực Sen Tây Hồ
#     id: 135, name: La Badiane - Nam Ngư
#     id: 92, name: Gà Rán KFC - Nguyễn Văn Cừ
#     id: 88, name: Gà Rán KFC - Nguyễn Thái Học - VMQ
#     id: 222, name: Meat Plus - No.1 Korea Bbq - Hồ Tây
#     id: 194, name: Season BBQ - Bà Triệu
#     id: 242, name: Nhà Sàn 141 - Lẩu, Đồ Nướng & Nhậu
#     id: 12, name: Sumo BBQ - Nhà Hàng Thịt Nướng Nhật Bản - BigC
#
# Tourist Attraction Locations:
#     id: 192, name: Làng lụa Vạn Phúc
#     id: 173, name: Chùa Bà Đá
#     id: 102, name: Công Viên Hòa Bình
#     id: 70, name: Líu Lô Arts & Craft
#     id: 347, name: COBRA MuayThai Training Camp
#     id: 238, name: Tượng đài Bắc Sơn
#     id: 157, name: Tượng đài Lenin
#     id: 166, name: Cầu Nhật Tân
#     id: 69, name: Bat Trang Conservation
#     id: 439, name: Duong Ha Natural Gemstones & Jade
#     id: 419, name: Kang Fruits - Đặc Sản Vùng Miền
#     id: 454, name: Silver Soul Studio - Trang Sức Bạc Thủ Công Việt Nam
#     id: 436, name: Cửa hàng Silk Ngọc Diệp
#     id: 329, name: Dream Games Royal City
#     id: 396, name: Viettime Craft
#     id: 318, name: Ginkgo T-Shirts Store Hang Gai
#     id: 249, name: The Keep
#     id: 94, name: Hồ Trúc Bạch
#     id: 83, name: Jw Art Gallery
#     id: 58, name: Minh Hiền Art Gallery
#     id: 183, name: Nhà Lưu niệm Hồ Chí Minh
#     id: 378, name: Anne's Maison
#     id: 523, name: Ngoc Anh Fashion
#     id: 254, name: The Oola Lab
#     id: 227, name: VietHarvest Journey
#     id: 418, name: Jump Arena
#     id: 261, name: Thiên Mộc Hương - Agarwood Jewelry
#     id: 153, name: Chùa Quán Sứ
#     id: 198, name: Hầm D67
#     id: 473, name: Đức Minh Tailor
#     id: 494, name: Quảng Phú Cầu ( Incense Village )
#     id: 222, name: Ha Noi Super Karting
#     id: 147, name: Đền Hàng Bạc
#     id: 148, name: Di tích Cửa Bắc
#     id: 4, name: Bảo tàng Lịch sử Quân sự Việt Nam
#     id: 263, name: Nhà hát Múa rối Việt Nam
#     id: 18, name: D&C Art Gallery
#     id: 431, name: Duong Jewelry
#     id: 399, name: TiredCity 03 Hàng Bông
#     id: 264, name: Thơ - Vietnam handmade & Embroidery
#     id: 91, name: Công Viên Lý Thái Tổ
#     id: 528, name: Nhà Hát Cải Lương Hà Nội
#     id: 282, name: Huong Sen shop
#     id: 273, name: Dandy Bespoke
#     id: 38, name: M Space Gallery
#     id: 137, name: Việt Phủ Thành Chương
#     id: 115, name: Bamboo Village Shop
#     id: 84, name: Kuy Son Propaganda Art
#     id: 531, name: Dome
#     id: 391, name: Văn Tribal Heritage
#     id: 506, name: Hien Van Ceramics
#     id: 208, name: Chùa Hà
#     id: 423, name: Virgo Handmade Leather
#     id: 288, name: Humanity Hanoi
#     id: 421, name: Hanoia Metropole
#     id: 335, name: Ipa-Nima
#     id: 223, name: Chùa Trung Kính Thượng
#     id: 65, name: V-Art Space
#     id: 384, name: Pony Club Hanoi
#     id: 46, name: Hanoi Studio Gallery
#     id: 370, name: Nhà Hát Lớn Hà Nội
#     id: 332, name: Jinzo Escape
#     id: 500, name: Tailor Đức Nhân
#     id: 484, name: Sân Golf Long Biên
#     id: 107, name: Vườn hoa Quốc Tử Giám
#     id: 476, name: Chùa Phúc Khánh
#     id: 140, name: Phố Hàng Dầu
#     id: 390, name: Xéo Xọ Hà Nội
#     id: 339, name: Ajisai
#     id: 522, name: Ngo Minh Tailor
#     id: 402, name: TiredCity 100 Hàng Đào
#     id: 485, name: Sen Hong
#     id: 245, name: Chùa Tiên Tích
#     id: 163, name: Bat Trang Ceramics Village
#     id: 16, name: Vincom Center for Contemporary Art (VCCA)
#     id: 353, name: Chùa Bộc
#     id: 225, name: Đền Voi Phục
#     id: 27, name: Bảo Tàng Đường Hồ Chí Minh
#     id: 309, name: Gentlemen Bespoke
#     id: 383, name: Ra Riêng Store
#     id: 513, name: Delicious Ceramics
#     id: 236, name: Điện Kính Thiên
#     id: 122, name: Đường Tàu
#     id: 12, name: Nguyen Art Gallery in Hanoi
#     id: 302, name: IndochinaSilk
#     id: 169, name: Làng nón Chuông
#     id: 117, name: Dirt Town Academy: Off-road Motorbike Lessons
#     id: 82, name: Đá Quý Mỹ Nghệ Long Châu Bảo Ngọc
#     id: 379, name: Áo Dài La Sen Vũ
#     id: 74, name: 54 Traditions Gallery
#     id: 430, name: Ehi Food
#     id: 224, name: Chùa Trung Kính Hạ
#     id: 275, name: Khu Du Lịch Thác Đa
#     id: 170, name: Đền Quan Đế
#     id: 501, name: Bảo tàng Công Binh
#     id: 336, name: AEON MALL Ha Dong
#     id: 51, name: HITR
#     id: 109, name: Núi Nùng
#     id: 298, name: Chula fashion house
#     id: 364, name: Stark Suits
#     id: 72, name: Bảo tàng gốm Bát Tràng
#     id: 527, name: Ngoc Silk & Handicraft
#     id: 134, name: Chùa Hương
#     id: 129, name: Cầu Long Biên
#     id: 492, name: Star Lotus
#     id: 481, name: Momoknit
#     id: 87, name: Hồ Hoàn Kiếm
#     id: 81, name: Area 75 - Art & Auction
#     id: 220, name: Viễn Sơn Tự
#     id: 471, name: Max Coffee Organic
#     id: 48, name: Blue Gallery
#     id: 207, name: Đền Bia Bà
#     id: 184, name: Viện Goethe Hà Nội
#     id: 479, name: Mjnhon Store- Happy Clothing Shop
#     id: 424, name: Art tutor Hanoi
#     id: 305, name: Miss Terry - Escape Rooms 3
#     id: 292, name: Danva Bespoke
#     id: 429, name: Trà Việt - Tea Gift Shop
#     id: 324, name: Thuy Design House - Ha Noi
#     id: 22, name: Bảo tàng Nguyễn Văn Huyên
#     id: 400, name: TiredCity 05 Nhà Thờ
#     id: 113, name: Indira Gandhi Park Thành Công
#     id: 296, name: Đền Hỏa Thần
#     id: 271, name: 1st Football Store
#     id: 417, name: With Love From The Mountains
#     id: 179, name: Go Kart Vietnam
#     id: 312, name: Gifthaus Ngôi Nhà Quà Tặng
#     id: 257, name: The Root Board Game Cafe
#     id: 496, name: Sweet Sandy - Souvenir, Crafts, Art
#     id: 445, name: Quartzaholic - Handmade Jewelry & Gems
#     id: 303, name: Mountain's Color- H’mong Textiles Art
#     id: 294, name: Khu du lịch Ao Vua
#     id: 128, name: Hoàng Thành Thăng Long
#     id: 458, name: Kịch "Tứ Phủ"
#     id: 230, name: Chùa Thiên Phúc
#     id: 142, name: Cầu Thê Húc
#     id: 482, name: Silver Soul Vietnam
#     id: 211, name: Chùa Phương Trạch
#     id: 135, name: Con đường Gốm sứ
#     id: 395, name: Vietnam's Delights (Souvenir & Gift Shop)
#     id: 283, name: House of Karma
#     id: 214, name: Chùa Diên Hựu
#     id: 355, name: TINH TAN Healing Gemstones
#     id: 425, name: ArtBook
#     id: 409, name: TiredCity 92 Hàng Gai
#     id: 322, name: Thu Huong Lacquer Arts
#     id: 311, name: Giáo Phường Ca Trù Kim Đức
#     id: 165, name: Hồ Văn - Văn Miếu
#     id: 404, name: Tiredcity 19 Nhà Thờ
#     id: 182, name: Bưu Điện Hà Nội
#     id: 180, name: Di tích Thành Cổ Loa
#     id: 218, name: Nhà Thờ Giáo Xứ Hàng Bột
#     id: 89, name: Vườn Quốc Gia Ba Vì
#     id: 428, name: EnVogue Home
#     id: 244, name: Hanoi Rock City
#     id: 151, name: Tượng Đài Vua Lê Thái Tổ
#     id: 504, name: Phuc Loi Shop
#     id: 199, name: Chùa Lý Triều Quốc Sư
#     id: 444, name: Penvus Handmade Leather
#     id: 277, name: The Bookworm Hanoi
#     id: 149, name: Quảng trường Ba Đình
#     id: 328, name: Pineapple Cooking Centre
#     id: 56, name: Batoni Bespoke
#     id: 440, name: Làng cổ Cự Đà
#     id: 156, name: Khu phố Pháp
#     id: 285, name: 54 Traditions Gallery
#     id: 233, name: Công viên Nghĩa Đô
#     id: 497, name: Taats&tie
#     id: 291, name: Seen Escape
#     id: 59, name: Hai Pottery
#     id: 161, name: Phủ Tây Hồ
#     id: 280, name: Chie Dupudupa
#     id: 363, name: Jade Tailor hanoi
#     id: 331, name: Tiệm may Đỏ
#     id: 95, name: Vườn bách thảo Hà Nội
#     id: 195, name: Trường Đại Học Bách Khoa Hà Nội
#     id: 293, name: Sân băng Vincom Royal City
#     id: 177, name: Cung Văn hoá Lao động Hữu nghị Việt Xô
#     id: 159, name: Tòa nhà Keangnam Hà Nội
#     id: 488, name: Sogood Tshirt
#     id: 260, name: The Warehouse
#     id: 158, name: Tháp Bút
#     id: 239, name: Chùa Tây Phương
#     id: 357, name: Chùa Liên Phái
#     id: 375, name: An handmade Hang Manh - Ethnic Craft Station
#     id: 393, name: Emporium Hanoi
#     id: 29, name: Hàng Da Thật shop
#     id: 502, name: Quà Tặng Thủ Công Mỹ Nghệ
#     id: 252, name: NOTE - THE SCENT LAB
#     id: 371, name: tiNiWorld
#     id: 310, name: GIANDON- Simple
#     id: 3, name: Bảo tàng Phụ nữ Việt Nam
#     id: 7, name: Bảo Tàng Hồ Chí Minh
#     id: 37, name: The Muse Art Space
#     id: 111, name: Phố Cổ Hà Nội
#     id: 132, name: Phố Đi Bộ Hồ Hoàn Kiếm
#     id: 351, name: OZ Design House
#     id: 348, name: Chùa Đậu
#     id: 281, name: Hoop Vibe
#     id: 411, name: Viện Nghiên Cứu Thảo Dược Việt Nam
#     id: 381, name: Hoa Fashion
#     id: 194, name: Đình Tân Khai
#     id: 521, name: Ngo Minh Tailor
#     id: 55, name: Hapu Swimming Pool
#     id: 420, name: Flanerie Multi-brand Retailer
#     id: 136, name: Hồ Hữu Tiệp và Hồ B52
#     id: 116, name: Hai Van Printing and Embroidery Shop
#     id: 53, name: Hi'De Maison
#     id: 15, name: Bảo tàng Phòng không - Không quân
#     id: 526, name: Ngọc Quyên Silk
#     id: 342, name: Cỏ Mềm
#     id: 361, name: tiNiWorld
#     id: 205, name: Làng cổ Đông Ngạc
#     id: 465, name: Duccio Tailor
#     id: 118, name: Văn Miếu Quốc Tử Giám
#     id: 360, name: tiNiWorld
#     id: 307, name: A&a Goods And Gifts
#     id: 489, name: Sonson Handicraft
#     id: 374, name: Gourmet Gift
#     id: 9, name: Bảo Tàng Lịch Sử Quốc Gia
#     id: 410, name: Tơ Vàng / Golden Silk
#     id: 323, name: Thuận Hóa - Hương Nhang - Trầm Hương - Dược Liệu Quý
#     id: 221, name: Chùa Mía
#     id: 189, name: Tháp Hòa Phong
#     id: 477, name: Miniwood Design
#     id: 325, name: Tiệm An Hà Nội
#     id: 320, name: GISY by Gijs & Yen Voogt
#     id: 256, name: Miss Terry - Escape Rooms 2
#     id: 433, name: Jump Arena
#     id: 206, name: Detrang Farm
#     id: 35, name: Bảo tàng Nhân học
#     id: 75, name: Ha Noi Informations & Exhibition Center
#     id: 68, name: Bát Tràng Gaia
#     id: 455, name: Múa rối nước Bông Sen
#     id: 52, name: La Ba Quan - Vietnamese Artist
#     id: 175, name: Sân vận động Mỹ Đình
#     id: 32, name: Bảo tàng Địa chất
#     id: 508, name: The Nafoods Shop
#     id: 398, name: The Craft House Nhà Chung
#     id: 112, name: Thung lũng hoa hồ Tây
#     id: 486, name: Sen Silk
#     id: 2, name: Bảo tàng Dân tộc học
#     id: 415, name: The Dreamers
#     id: 251, name: Sapa Shop
#     id: 187, name: Đền Hai Bà Trưng
#     id: 452, name: Dunnio Tailor
#     id: 219, name: Smiley Ville
#     id: 106, name: Núi Trầm
#     id: 45, name: Heritage Sapce
#     id: 435, name: Jump Arena
#     id: 437, name: Cửa hàng thời trang Makaw
#     id: 401, name: TiredCity 08 Hàng Bạc
#     id: 269, name: Hoa Floral Foliage
#     id: 101, name: Hồ Bảy Mẫu
#     id: 516, name: My Trang Silk Shop
#     id: 57, name: Bảo tàng Nhiếp ảnh Lai Xá
#     id: 499, name: Tailor Bros
#     id: 196, name: Chùa Cầu Đông
#     id: 442, name: Westlake Mini Golf
#     id: 202, name: Tượng Đài Quyết Tử
#     id: 456, name: Dunnio Tailor
#     id: 127, name: Nhà Thờ Lớn
#     id: 279, name: Chùa Tứ Liên
#     id: 121, name: Làng cổ Đường Lâm
#     id: 427, name: The North Face Factory Outlet
#     id: 450, name: Hanoi soul
#     id: 422, name: Arrow Helmet Shop
#     id: 313, name: Inception Escape Room
#     id: 278, name: Cheeky N Town
#     id: 144, name: Bia tưởng niệm John McCain
#     id: 514, name: The Golf Hub
#     id: 387, name: Đức Lan Bronze Handicrafts
#     id: 133, name: Phố Tạ Hiện
#     id: 201, name: Đền Bà Kiệu
#     id: 405, name: TiredCity 2D Lý Quốc Sư
#     id: 480, name: Hanoi Shouten - Souvenir & Gift Shop
#     id: 518, name: Nagu
#     id: 519, name: NGO GIA Tailor
#     id: 438, name: CuasoChoiboi
#     id: 326, name: Tiệm Gốm
#     id: 44, name: Zó Project
#     id: 386, name: Áo Dài Vinh Trạch
#     id: 321, name: Gốm Quang
#     id: 341, name: Clom's Closet
#     id: 172, name: Đình Kim Ngân
#     id: 241, name: Chùa Linh Ứng
#     id: 242, name: Nhà lưu niệm 90 Thợ Nhuộm
#     id: 60, name: Hanhsilk
#     id: 104, name: Khu Du Lịch Sinh Thái Thiên Phú Lâm
#     id: 21, name: Bảo tàng Cách mạng Việt Nam
#     id: 446, name: Trầm Hương An Bách - Agarwood Jewelry
#     id: 487, name: So Young
#     id: 171, name: Chùa Thiên Trù (Chùa Ngoài)
#     id: 460, name: Hanoia Mã Mây
#     id: 289, name: Đền Sóc
#     id: 376, name: Anh Village Silk
#     id: 352, name: Silky Việt Nam
#     id: 304, name: Gemmy Store - Pearl Jewelry
#     id: 185, name: Chùa Phổ Linh
#     id: 6, name: Đài Quan Sát Lotte
#     id: 530, name: Nhà may Cao
#     id: 120, name: Lăng Chủ Tịch Hồ Chí Minh
#     id: 228, name: Chùa Huyền Thiên Quán
#     id: 472, name: Maxcoffee 4-6 Hàng Gai
#     id: 92, name: Công viên Lenin
#     id: 155, name: Phố Bích Họa Phùng Hưng
#     id: 235, name: Khu du lịch Hồ Tiên Sa
#     id: 327, name: Tiệm May Cô Cải
#     id: 193, name: Ga Hà Nội
#     id: 369, name: Nhà Hát Tuồng Trung Ương
#     id: 495, name: Bảo tàng Văn học Việt Nam
#     id: 314, name: Three Sisters Silk
#     id: 103, name: Công viên Thống NhấtCông viên Thống Nhất
#     id: 110, name: Hồ Thiền Quang
#     id: 274, name: Chợ hoa Quảng Bá
#     id: 338, name: Đền Hương Tượng
#     id: 123, name: Chùa Trấn Quốc
#     id: 203, name: Chùa Non Nước
#     id: 76, name: JESMEE Jewelry Store
#     id: 406, name: Tiredcity 37 Hàng Hành
#     id: 250, name: Phù Đổng Green Park
#     id: 240, name: Đền Kim Liên
#     id: 459, name: Quán The Nest - Board Game Cafe
#     id: 181, name: Nhà thờ Cửa Bắc
#     id: 475, name: Mekong Quilts
#     id: 354, name: Mountain Allure
#     id: 509, name: Hanoi Shouten Shop - Goodies of Vietnam and Japan
#     id: 258, name: Mind Escape
#     id: 392, name: Namidori Luxury Handmade Shoes
#     id: 453, name: Winecellar
#     id: 61, name: Hanoi Art Gallery
#     id: 441, name: Washi Nà - Art Gifts & Stationery
#     id: 432, name: Trại Cá
#     id: 368, name: tiNiWorld
#     id: 204, name: Chùa Kim Liên
#     id: 507, name: Nhà May Nam
#     id: 215, name: Ống Khói Cũ
#     id: 349, name: Tinh Hoa Bắc Bộ
#     id: 388, name: Viet Jewelers
#     id: 28, name: Klimt Art Gallery
#     id: 520, name: Ngo Minh so 8 trang tien
#     id: 308, name: Muối Studio
#     id: 382, name: Vanloi Oriental Style
#     id: 284, name: Tháp nước Hàng Đậu
#     id: 474, name: Maya Kitchen
#     id: 85, name: Tiệm Len Poly
#     id: 62, name: Gemstone Painting Vietnam
#     id: 229, name: Thành cổ Sơn Tây
#     id: 272, name: FOLKSIGHT 216 HANG BONG
#     id: 86, name: Ao Art
#     id: 276, name: Nhà Hát Lớn Hà Nội
#     id: 412, name: Tohe Style
#     id: 31, name: Red Moon Gallery
#     id: 125, name: Đền Ngọc Sơn
#     id: 13, name: Cột cờ Hà Nội
#     id: 483, name: Ribbon Florist
#     id: 64, name: Cửa Hàng Huy Hùng Gallery
#     id: 33, name: Phòng Tranh Á Đông
#     id: 212, name: Chùa Tảo Sách
#     id: 344, name: Cỏ Mềm HomeLab
#     id: 372, name: Jesmee Jewelry
#     id: 287, name: Collective Memory - The House of Curios
#     id: 47, name: Bùi Mai Hiên Gallery
#     id: 234, name: Khu du lịch Thiên Sơn Suối Ngà
#     id: 50, name: Vụn Art
#     id: 36, name: Bảo tàng thiên nhiên Việt Nam
#     id: 217, name: Chùa Vạn Niên
#     id: 216, name: Đền thờ Phùng Hưng
#     id: 152, name: Manh's Farm Tour and Homestay cooking Class in Hanoi
#     id: 143, name: Đền Bạch Mã
#     id: 407, name: TiredCity 41C Lý Quốc Sư
#     id: 11, name: Bảo Tàng Công An Hà Nội
#     id: 174, name: Hadong Silk
#     id: 478, name: Miss Terry - Escape Rooms
#     id: 17, name: Hi'de Maison
#     id: 286, name: Pottery Hai Doan
#     id: 426, name: Virtual Park
#     id: 505, name: Tanmy Design
#     id: 200, name: Hội Thánh Tin Lành Hà Nội
#     id: 362, name: Chùa Phụng Thánh
#     id: 108, name: Công Viên Thiên Đường Bảo Sơn
#     id: 380, name: Áo dài Minh Đức - Vietnam Tradition Costume
#     id: 160, name: Quảng Trường Đông Kinh Nghĩa Thục
#     id: 366, name: Amare Onsen & Jjimjilbang
#     id: 186, name: Đền Hát Môn
#     id: 358, name: Chùa Vũ Thạch
#     id: 463, name: Truc Lam Handmade
#     id: 150, name: Thánh đường hồi giáo Al-Noor
#     id: 226, name: Đền Phù Đổng
#     id: 469, name: Duc Minh, Tailor made suit
#     id: 255, name: Lotte World Aquarium Hà Nội
#     id: 188, name: Trompe L’oeil Murals
#     id: 443, name: Dong Xuan Food Alley
#     id: 119, name: Di tích Nhà tù Hỏa Lò
#     id: 297, name: CHOI Workshop - Edu & Art
#     id: 88, name: Hồ Tây
#     id: 66, name: Henry Tailor
#     id: 178, name: Habanos Specialist
#     id: 78, name: Basil Cooking Club
#     id: 259, name: The Silkworm
#     id: 525, name: Ngoc Hien Silk
#     id: 447, name: Tràng Tiền Plaza
#     id: 25, name: Trung Tâm Giao Lưu Văn Hoá Phố Cổ
#     id: 80, name: Work Room Four
#     id: 529, name: Nhà hát Hồ Gươm
#     id: 414, name: Tonkin Handicraft
#     id: 243, name: Đền Phù Ủng
#     id: 23, name: D&C Art Gallery
#     id: 268, name: Chăn Con Công - Vintage Store
#     id: 237, name: Đình Nam Hương
#     id: 99, name: Chùa Láng
#     id: 19, name: Bảo Tàng Công An Nhân Dân Việt Nam
#     id: 39, name: Phòng Tranh Đông Phong
#     id: 337, name: Airashi Silk
#     id: 461, name: Pheva Chocolate - Hanoi
#     id: 397, name: Village Silk Tailor
#     id: 138, name: Tháp Rùa
#     id: 365, name: Amare
#     id: 367, name: Nhà Hát Múa Rối Nước Thăng Long
#     id: 213, name: Lăng và Đền thờ Ngô Quyền
#     id: 356, name: H’Elegant
#     id: 131, name: Chùa Một Cột
#     id: 466, name: Đức Nhật Tailor
#     id: 295, name: Khu Du Lịch Khoang Xanh Suối Tiên
#     id: 389, name: Juans Bespoke
#     id: 490, name: Sport1 Sports Shop
#     id: 90, name: VinKE & Aquarium Times City
#     id: 510, name: Thang Long Gallery
#     id: 359, name: Rạp Xiếc Trung Ương
#     id: 210, name: Bích Câu Đạo Quán
#     id: 49, name: D&C Art Gallery
#     id: 24, name: Phòng tranh Empty Wall
#     id: 34, name: Ha Noi Gallery
#     id: 231, name: Chùa Kim Cổ
#     id: 209, name: Khu Du lịch sinh thái Long Việt
#     id: 162, name: Phố Hàng Mã
#     id: 464, name: Tsnow Boutique
#     id: 232, name: Đình Chèm
#     id: 190, name: Đình Cổ Vũ
#     id: 511, name: Phap Phuc Dieu Lien Shop
#     id: 345, name: Cỏ Mềm HomeLab
#     id: 197, name: Phố đi bộ Trịnh Công Sơn
#     id: 167, name: Làng Văn hóa Du lịch các Dân tộc Việt Nam
#     id: 126, name: Công viên nước Hồ Tây
#     id: 343, name: Cỏ Mềm
#     id: 145, name: Ô Quan Chưởng
#     id: 63, name: The Today Gallery
#     id: 267, name: Chăn Con Công - Vintage Store
#     id: 434, name: Hanoinia
#     id: 408, name: TiredCity 67 Hàng Trống
#     id: 317, name: Ginkgo T-Shirts Store Hang Be
#     id: 105, name: Vườn Hoa Bãi Đá Sông Hồng
#     id: 512, name: The Bamboo Shop
#     id: 467, name: Maroon
#     id: 248, name: Chùa Hoằng Ân
#     id: 319, name: Timezone Vincom Metropolis
#     id: 491, name: Sportee Store
#     id: 124, name: Phố Hàng Gai
#     id: 266, name: Cerender ceramic shop
#     id: 350, name: ¥ La Perla
#     id: 262, name: Thien Y Art Gallery
#     id: 146, name: HANOI PEAK bespoke tailoring
#     id: 515, name: Mỹ Nghệ Thiên Lộc
#     id: 265, name: Cerender Ceramics
#     id: 462, name: DunkConcept - Modern Vietnamese Incense
#     id: 93, name: Biển Hồ Nước Mặn
#     id: 503, name: Authentic Bat Trang
#     id: 498, name: Bảo tàng Pháo binh
#     id: 385, name: Autumn.Deli - Home of Viet Goodies
#     id: 377, name: Rose Kitchen
#     id: 1, name: Vườn Thú Hà Nội
#     id: 290, name: Nhà hát Kịch Việt Nam
#     id: 299, name: Chuong Tailor
#     id: 77, name: The Airy Space
#     id: 416, name: Vincom Mega Mall Royal City
#     id: 470, name: MasterTan
#     id: 8, name: Phòng tranh Green Palm
#     id: 346, name: Cỏ Mềm Homelab
#     id: 270, name: 1950 by Đức Hạnh
#     id: 246, name: Đền Mẫu Phù Đổng
#     id: 315, name: Zebbie Studio
#     id: 40, name: Art Vietnam Gallery
#     id: 253, name: The Nafoods Shop
#     id: 247, name: Đền Gióng Phù Đổng
#     id: 451, name: Wine Cellar
#     id: 168, name: Phố Hàng Quạt
#     id: 20, name: GP Home Handicraft
#     id: 449, name: Genesis Escape
#     id: 448, name: Làng cổ Ước Lễ
#     id: 130, name: Nhà sàn Bác Hồ
#     id: 517, name: MyAnh Silk
#     id: 457, name: Gốm Sứ Kim Lan Hà Nội
#     id: 73, name: Vicas Art Studio
#     id: 100, name: Công Viên Cầu Giấy
#     id: 10, name: Ngôi Nhà Di Sản
#     id: 468, name: Andy Dr. Martens
#     id: 413, name: Tomato Handmade Store
#     id: 316, name: Ginkgo
#     id: 191, name: Tòa Nhà Quốc Hội Việt Nam
#     id: 141, name: Phố Hàng Bạc
#     id: 114, name: Bambou Silk
#     id: 301, name: Renew Jeans
#     id: 403, name: TiredCity 13 Hàng Gai
#     id: 98, name: Sông Hồng
#     id: 493, name: Startee
#     id: 340, name: CleverGent
#     id: 54, name: Hanoia House
#     id: 26, name: Thang Long Art Gallery
#     id: 96, name: Trang Trại Thảo Điền Vạn Lộc
#     id: 524, name: Ngoc Diep Souvenir
#     id: 306, name: Indochine House
#     id: 176, name: Đền Hai Bà Trưng
#     id: 5, name: Bảo tàng Mỹ thuật Việt Nam
#     id: 334, name: Chùa Pháp Vân
#     id: 41, name: Hathor Art Gallery
#     id: 333, name: Tiffany Studios
#     id: 139, name: Đền Quán Thánh
#     id: 300, name: Làng Ngũ Xã
#     id: 71, name: Bảo tàng Nghệ thuật Hồn Đất Việt Bát Tràng - Nghệ nhân Nhân dân Vũ Thắng
#     id: 67, name: MAI Gallery
#     id: 14, name: Bảo tàng Chiến thắng B-52
#     id: 97, name: Hồ Linh Đàm
#     id: 79, name: Atena Gallery
#     id: 42, name: Apricot Gallery
#     id: 43, name: Bảo tàng Hà Nội
#     id: 373, name: AN Handmade
#     id: 394, name: Nghê Shop
#     id: 164, name: Chùa Thầy
#     id: 154, name: Haha Hanoi Comedy
#     id: 330, name: Royal Silk

# %% [markdown]
# ### Other code (not related to the main query)

# %% [markdown]
# #### Test query

# %%
# import pandas as pd
# from sqlalchemy import create_engine, text

# # Connect to the PostgreSQL database
# engine = create_engine(postgres_url)
# connection = engine.connect()

# # Load the hotel data into a DataFrame
# df = pd.read_sql("SELECT hotel_id, style FROM travel_database.hotel", connection)

# # Clean the style column: remove extra spaces and standardize casing
# df['style'] = df['style'].str.strip().str.title()

# # Verify cleaning
# print(df['style'].unique())  # See unique values to confirm cleaning

# # Update the cleaned data back to the database
# for index, row in df.iterrows():
#     update_query = text(f"""
#         UPDATE travel_database.hotel
#         SET style = :style
#         WHERE hotel_id = :hotel_id
#     """)
#     connection.execute(update_query, {"style": row['style'], "hotel_id": row['hotel_id']})

# # Close the connection
# connection.close()

# %%
conn = psycopg2.connect(postgres_url)
cur = conn.cursor()

# Thiết lập search_path
cur.execute("""SET search_path TO travel_database, public;""")
cur.execute("CREATE EXTENSION IF NOT EXISTS unaccent;")

# Set the search_path
cur.execute("""SET search_path TO travel_database, public;""")

# Tạo câu truy vấn SQL
sql = """
    SELECT DISTINCT style
    FROM travel_database.hotel
;
"""

sql2= """
    SELECT DISTINCT travel_database.hotel.hotel_id, travel_database.hotel.name, travel_database.hotel.style, (travel_database.hotel.address).district, travel_database.hotel.amenities 
    FROM travel_database.hotel  
    JOIN travel_database.hotelprice 
    ON travel_database.hotel.hotel_id = travel_database.hotelprice.hotel_id 
    WHERE travel_database.hotelprice.price > 2000000 
        AND ('Bathtub' = ANY(travel_database.hotel.amenities) 
        OR 'Hồ bơi' = ANY(travel_database.hotel.amenities) 
        OR 'Mát-xa' = ANY(travel_database.hotel.amenities)) 
    AND travel_database.hotel.style LIKE 'Luxury%'
    AND unaccent(lower((travel_database.hotel.address).district)) ILIKE unaccent('%hai ba trung%');
"""

# Thực thi câu truy vấn
cur.execute(sql2)

# Lấy tất cả các kết quả
attractions = cur.fetchall()

# In ra tên các attraction
for attraction in attractions:
    print(f"id: {attraction[0]} - name: {attraction[1]} - style: {attraction[2]} - district: {attraction[3]} - amenities: {attraction[4]}\n")
    # print(f"{attraction[0]}")
# Đóng kết nối
cur.close()
conn.close()
# Out:
# id: 205 - name: Hôtel du Parc Hanoï - style: Luxury
#  - district: Hai Bà Trưng - amenities: ['Nhân viên xách hành lý', 'Thức uống chào mừng miễn phí', 'Dịch vụ concierge/hỗ trợ khách', 'Dịch vụ thu đổi ngoại tệ', 'Người gác cửa', 'EARLY_CHECK_IN', 'Dịch vụ nhận phòng cấp tốc', 'Dịch vụ trả phòng cấp tốc', 'Quầy lễ tân', 'Lễ tân 24h', 'Bảo vệ 24 giờ', 'Dịch vụ trả phòng muộn', 'Dịch vụ giặt ủi', 'Dịch vụ lưu trữ/bảo quản hành lý', 'Nhật báo tại sảnh', 'Dịch vụ hỗ trợ đặt Tour', 'Bữa sáng với thực đơn gọi món', 'Bữa tối với thực đơn gọi món', 'Bữa trưa với thực đơn gọi món', 'Nhà hàng có máy lạnh', 'Quầy bar', 'Bữa sáng', 'Bữa sáng và bữa tối', 'Bữa sáng và bữa trưa', 'Bữa sáng món tự chọn', 'Bữa sáng phục vụ tại bàn', 'Bữa sáng (thu phí)', 'Tiệm cà phê', 'Khu ẩm thực', 'Phục vụ món chay', 'Bãi đậu xe', 'Cà phê/trà tại sảnh', 'Tiệm cà phê', 'Nhận phòng sớm', 'Thang máy', 'Dịch vụ phòng 24 giờ', 'Trả phòng muộn', 'Nhà hàng', 'Nhà hàng phục vụ bữa sáng', 'Nhà hàng phục vụ bữa tối', 'Nhà hàng phục vụ bữa trưa', 'Dịch vụ dọn phòng', 'Két an toàn', 'WiFi tại khu vực chung', 'Áo choàng tắm', 'Bồn tắm', 'Truyền hình cáp', 'Bàn làm việc', 'Máy sấy tóc', 'Két an toàn trong phòng', 'Minibar', 'Phòng tắm đứng và bồn tắm riêng', 'Phòng tắm vòi sen', 'TV', 'Máy lạnh', 'Tiệc chiêu đãi', 'Phòng liên thông', 'Phòng gia đình', 'Phòng không hút thuốc', 'Hồ bơi', 'Khu vực hút thuốc', 'Trung tâm thể dục thể hình', 'Câu lạc bộ sức khoẻ', 'Mát-xa', 'Hồ bơi ngoài trời', 'Xông hơi ướt', 'Phòng được trang bị phù hợp cho người khuyết tật', 'Phòng tắm phù hợp cho người khuyết tật', 'Trang bị phòng phù hợp với người khuyết tật', 'Phù hợp cho xe lăn', 'Dịch vụ văn phòng', 'Phòng hội nghị', 'Tiện nghi hội họp', 'Máy chiếu', 'Máy ATM/Ngân hàng', 'Cửa hàng quà tặng', 'Cửa hàng', 'Điểm truy cập Internet', 'Mạng Internet cục bộ', 'Wifi (miễn phí)', 'Đưa đón sân bay (thu phí)', 'Đưa đón sân bay', 'Đưa đón sân bay', 'Trung tâm thể dục thể hình']

# %%
conn = psycopg2.connect(postgres_url)
cur = conn.cursor()

# Thiết lập search_path
cur.execute("""SET search_path TO travel_database, public;""")
cur.execute("CREATE EXTENSION IF NOT EXISTS unaccent;")

# Set the search_path
cur.execute("""SET search_path TO travel_database, public;""")

# Tạo câu truy vấn SQL
sql2= """
    SELECT DISTINCT travel_database.hotel.hotel_id, travel_database.hotel.name, travel_database.hotel.style, (travel_database.hotel.address).district, travel_database.hotel.amenities 
    FROM travel_database.hotel  
    JOIN travel_database.hotelprice 
    ON travel_database.hotel.hotel_id = travel_database.hotelprice.hotel_id 
    WHERE (travel_database.hotel.style LIKE 'Luxury%' OR travel_database.hotel.style LIKE 'Eco-friendly%');;
"""

# Thực thi câu truy vấn
cur.execute(sql2)

# Lấy tất cả các kết quả
attractions = cur.fetchall()

# In ra tên các attraction
for attraction in attractions:
    print(f"id: {attraction[0]} - name: {attraction[1]} - style: {attraction[2]} - district: {attraction[3]} - amenities: {attraction[4]}\n")
# Đóng kết nối
cur.close()
conn.close()
# Out:
# id: 51 - name: Khách sạn Grand Plaza Hà Nội - style: Luxury
#  - district: Cầu Giấy - amenities: ['Dịch vụ phòng 24 giờ', 'Dịch vụ dọn phòng', 'Bãi đậu xe', 'Két an toàn', 'WiFi tại khu vực chung', 'Nhà hàng', 'Thang máy', 'Lễ tân 24h']
#
# id: 2422 - name: HKG-Vinhomes Green Bay - Modem - Luxurious - style: Luxury
#  - district: Nam Từ Liêm - amenities: ['Cà phê/trà tại sảnh', 'Nhà hàng', 'Dịch vụ dọn phòng', 'Tiệm cà phê', 'Vườn hoa', 'Dịch vụ giặt ủi', 'Hiệu làm tóc']
#
# id: 2767 - name: Maison de Lux in Westlake Hanoi - style: Luxury
#  - district: Tây Hồ - amenities: ['Máy sấy tóc', 'Lò vi sóng', 'Minibar', 'Phòng tắm đứng và bồn tắm riêng', 'Phòng tắm vòi sen', 'TV', 'Máy lạnh', 'Máy sấy quần áo', 'Phòng không hút thuốc', 'Hiệu làm tóc', 'Cửa hàng', 'Siêu thị', 'Wifi (miễn phí)', 'Lễ tân 24h']
#
# id: 934 - name: Hanoi L'Heritage Diamond Hotel & Spa - style: Luxury
#  - district: Hoàn Kiếm - amenities: ['Áo choàng tắm', 'Bồn tắm', 'Bàn làm việc', 'Máy sấy tóc', 'Két an toàn trong phòng', 'Minibar', 'Tủ lạnh', 'Phòng tắm vòi sen', 'TV', 'Máy lạnh', 'Phòng liên thông', 'Phòng gia đình', 'Lò sưởi tại sảnh', 'Khu vực hút thuốc', 'Không khói thuốc', 'Sân thượng/sân hiên', 'Cà phê/trà tại sảnh', 'Thang máy', 'Nhà hàng', 'Dịch vụ dọn phòng', 'Két an toàn', 'WiFi tại khu vực chung', 'Quầy bar', 'Bữa sáng', 'Tiệm cà phê', 'Đồ ăn nhẹ', 'Lễ tân 24h', 'Dịch vụ giặt ủi', 'Dịch vụ lưu trữ/bảo quản hành lý', 'Dịch vụ spa', 'Wifi (miễn phí)', 'Đưa đón sân bay (thu phí)']
#
# id: 505 - name: A&D Luxury Hotel 2 - style: Luxury
#  - district: Cầu Giấy - amenities: ['Áo choàng tắm', 'Bồn tắm', 'Bàn làm việc', 'Máy sấy tóc', 'Minibar', 'Tủ lạnh', 'Phòng tắm vòi sen', 'TV', 'Dịch vụ thu đổi ngoại tệ', 'Quầy lễ tân', 'Lễ tân 24h', 'Bảo vệ 24 giờ', 'Dịch vụ giặt ủi', 'Dịch vụ lưu trữ/bảo quản hành lý', 'Nhận phòng sớm', 'Thang máy', 'Trả phòng muộn', 'Nhà hàng phục vụ bữa sáng', 'WiFi tại khu vực chung', 'Máy ATM/Ngân hàng', 'Hiệu làm tóc', 'Giặt ủi', 'Cửa hàng', 'Siêu thị', 'Bãi đậu xe hạn chế', 'Bãi đậu xe có người phục vụ', 'Máy lạnh', 'Phòng không hút thuốc', 'Bữa sáng (thu phí)', 'Wifi (miễn phí)', 'Máy in']
#
# id: 19 - name: The Five Residences Hanoi - style: Luxury
#  - district: Ba Đình - amenities: []
#
# id: 1017 - name: Royal City Luxury Apartment - style: Luxury
#  - district: Thanh Xuân - amenities: ['Khu vực hút thuốc', 'Sân thượng/sân hiên', 'Dịch vụ lưu trữ/bảo quản hành lý', 'Lễ tân 24h', 'Vườn hoa', 'OTHER']
#
# id: 2293 - name: Khách sạn Thế Kỷ Mới - style: Luxury
#  - district: Hai Bà Trưng - amenities: ['Truyền hình cáp', 'Bàn làm việc', 'Minibar', 'Phòng tắm vòi sen', 'TV', 'Bữa sáng', 'Tiệm cà phê', 'Quầy phục vụ đồ ăn nhẹ', 'Đồ ăn nhẹ', 'Đưa đón sân bay', 'Đưa đón trong khu vực', 'Dịch vụ cho thuê xe đạp', 'Cho thuê xe hơi', 'Máy lạnh', 'Phòng gia đình', 'Phòng không hút thuốc', 'Khu vực hút thuốc', 'Cà phê/trà tại sảnh', 'Dịch vụ dọn phòng', 'WiFi tại khu vực chung', 'Dịch vụ giặt ủi', 'Dịch vụ lưu trữ/bảo quản hành lý', 'Dịch vụ hỗ trợ đặt Tour', 'Điểm truy cập Internet', 'Wifi (miễn phí)', 'Đưa đón sân bay (thu phí)', 'Đưa đón sân bay', 'Dịch vụ văn phòng']
#
# id: 1086 - name: Khách sạn Hà Nội Amanda - style: Luxury
#  - district: Hoàn Kiếm - amenities: ['Dịch vụ giặt ủi', 'Dịch vụ nhận phòng cấp tốc', 'Nhật báo tại sảnh', 'Dịch vụ hỗ trợ đặt Tour', 'Dịch vụ lưu trữ/bảo quản hành lý', 'Dịch vụ trả phòng cấp tốc', 'Đội ngũ nhân viên đa ngôn ngữ', 'Lễ tân 24h', 'Dịch vụ concierge/hỗ trợ khách', 'OTHER', 'Nhà hàng', 'Két an toàn', 'Cà phê/trà tại sảnh', 'Thang máy', 'Quầy bar', 'Bữa sáng', 'Quầy phục vụ đồ ăn nhẹ', 'Dịch vụ giữ trẻ (thu phí)', 'Dịch vụ trông trẻ có người giám hộ', 'Mạng Internet cục bộ', 'Wifi (miễn phí)', 'Trang bị phòng phù hợp với người khuyết tật', 'Phòng tắm phù hợp cho người khuyết tật', 'Đưa đón đến ga xe lửa (thu phí)', 'Sân thượng/sân hiên', 'Đưa đón sân bay (thu phí)', 'TV', 'Máy ATM/Ngân hàng']
#
# id: 807 - name: King's Hotel My Dinh - style: Luxury
#  - district: Nam Từ Liêm - amenities: ['Bồn tắm', 'Truyền hình cáp', 'Bàn làm việc', 'Máy sấy tóc', 'Tủ lạnh', 'Phòng tắm đứng và bồn tắm riêng', 'Phòng tắm vòi sen', 'TV', 'Máy ATM/Ngân hàng', 'Cửa hàng thực phẩm', 'Hiệu làm tóc', 'Cửa hàng', 'Siêu thị', 'Nhà chứa xe', 'Bãi đậu xe an ninh', 'Máy lạnh', 'Sân thượng/sân hiên', 'Bãi đậu xe', 'WiFi tại khu vực chung', 'Dịch vụ giặt ủi', 'Lễ tân 24h', 'Tiệm cà phê', 'Vườn hoa', 'Wifi (miễn phí)']
#
# id: 1779 - name: Victoria Apartment Paradise Suites - style: Luxury
#  - district: Tây Hồ - amenities: ['Dịch vụ giặt ủi', 'Dịch vụ lưu trữ/bảo quản hành lý', 'Dịch vụ nhận phòng cấp tốc', 'Lễ tân 24h', 'Bãi gửi xe', 'Tủ khoá', 'Bãi đậu xe có người phục vụ', 'Wifi (miễn phí)', 'OTHER']
#
# id: 779 - name: Vinhomes Skylake - SunhouseLand - style: Luxury
#  - district: Nam Từ Liêm - amenities: ['Khu vực hút thuốc', 'Bãi gửi xe (thu phí)', 'OTHER', 'Thang máy', 'Hồ bơi ngoài trời', 'Đưa đón sân bay (thu phí)', 'Quầy lễ tân']
#
# id: 621 - name: Beryl Charm Hotel And Spa - style: Luxury
#  - district: Hoàn Kiếm - amenities: ['Nhân viên xách hành lý', 'Dịch vụ concierge/hỗ trợ khách', 'Dịch vụ thu đổi ngoại tệ', 'Người gác cửa', 'EARLY_CHECK_IN', 'Quầy lễ tân', 'Lễ tân 24h', 'Bảo vệ 24 giờ', 'Dịch vụ trả phòng muộn', 'Dịch vụ giặt ủi', 'Dịch vụ phòng (có giới hạn thời gian)', 'Dịch vụ lưu trữ/bảo quản hành lý', 'Đội ngũ nhân viên đa ngôn ngữ', 'Nhật báo', 'Nhân viên gác cổng', 'Dịch vụ hỗ trợ đặt Tour', 'Bữa tối với thực đơn gọi món', 'Bữa trưa với thực đơn gọi món', 'Nhà hàng có máy lạnh', 'Quầy bar', 'Bữa sáng', 'Bữa sáng món tự chọn', 'Bữa sáng phục vụ tại bàn', 'Tiệm cà phê', 'Khu ẩm thực', 'Bữa tối với thực đơn chọn sẵn', 'Bữa trưa với thực đơn chọn sẵn', 'Quầy phục vụ đồ ăn nhẹ', 'Đồ ăn nhẹ', 'Phục vụ món chay', 'Nhà máy rượu vang', 'Bãi đậu xe', 'Cà phê/trà tại sảnh', 'Tiệm cà phê', 'Nhận phòng sớm', 'Thang máy', 'Trả phòng muộn', 'Nhà hàng', 'Nhà hàng phục vụ bữa sáng', 'Nhà hàng phục vụ bữa tối', 'Nhà hàng phục vụ bữa trưa', 'Dịch vụ dọn phòng', 'Két an toàn', 'WiFi tại khu vực chung', 'Áo choàng tắm', 'Bồn tắm', 'Truyền hình cáp', 'Bàn làm việc', 'Máy sấy tóc', 'Két an toàn trong phòng', 'Minibar', 'Phòng tắm đứng và bồn tắm riêng', 'Phòng tắm vòi sen', 'TV', 'Máy ATM/Ngân hàng', 'Thẩm mỹ viện', 'Cửa hàng quà tặng', 'Cửa hàng thực phẩm', 'Hiệu làm tóc', 'Giặt ủi', 'Cửa hàng', 'Siêu thị', 'Máy lạnh', 'Phòng gia đình', 'Máy sưởi', 'Phòng không hút thuốc', 'Khu vực hút thuốc', 'Sân thượng/sân hiên', 'Đưa đón sân bay', 'Cho thuê xe hơi', 'Bãi đậu xe (thu phí)', 'Dịch vụ xe limo/xe đưa đón hạng sang', 'Bãi đậu xe an ninh', 'Tiệc nướng ngoài trời', 'Trung tâm thể dục thể hình', 'Mát-xa', 'Dịch vụ spa', 'Phòng xem TV', 'Đưa đón sân bay (thu phí)', 'Xe đưa đón bến du thuyền (thu phí)', 'Đón khách tại ga tàu', 'Đưa đón sân bay', 'Điểm truy cập Internet', 'Mạng Internet cục bộ', 'Wifi (miễn phí)', 'Dịch vụ văn phòng', 'Máy photocopy', 'Thuận tiện cho người khuyết tật', 'Trung tâm thể dục thể hình', 'Ghế cho trẻ em']
#
# id: 1374 - name: Hong Gia Tue Apartment - style: Luxury
#  - district: Ba Đình - amenities: ['Nhân viên xách hành lý', 'Thức uống chào mừng miễn phí', 'Dịch vụ concierge/hỗ trợ khách', 'Dịch vụ thu đổi ngoại tệ', 'Người gác cửa', 'EARLY_CHECK_IN', 'Dịch vụ nhận phòng cấp tốc', 'Dịch vụ trả phòng cấp tốc', 'Quầy lễ tân', 'Lễ tân 24h', 'Bảo vệ 24 giờ', 'Dịch vụ trả phòng muộn', 'Dịch vụ giặt ủi', 'Dịch vụ phòng (có giới hạn thời gian)', 'Nhân viên gác cổng', 'Dịch vụ hỗ trợ đặt Tour', 'Bồn tắm', 'Truyền hình cáp', 'Bàn làm việc', 'Máy sấy tóc', 'Két an toàn trong phòng', 'Nhà bếp mini', 'Lò vi sóng', 'Minibar', 'Tủ lạnh', 'Phòng tắm đứng và bồn tắm riêng', 'Phòng tắm vòi sen', 'TV', 'Máy ATM/Ngân hàng', 'Thẩm mỹ viện', 'Cửa hàng quà tặng', 'Cửa hàng thực phẩm', 'Hiệu làm tóc', 'Giặt ủi', 'Cửa hàng', 'Siêu thị', 'Nhận phòng sớm', 'Thang máy', 'Trả phòng muộn', 'Két an toàn', 'WiFi tại khu vực chung', 'Máy lạnh', 'Phòng không hút thuốc', 'Sân thượng/Sân hiên', 'Sân thượng/sân hiên', 'Thuận tiện cho người khuyết tật', 'Phòng tắm phù hợp cho người khuyết tật', 'Trang bị phòng phù hợp với người khuyết tật', 'Đưa đón sân bay (thu phí)', 'Đưa đón sân bay', 'Khu ẩm thực', 'Đưa đón sân bay', 'Wifi (miễn phí)']
#
# id: 952 - name: Cindy Vinhomes Skylake Apartments - style: Luxury
#  - district: Nam Từ Liêm - amenities: ['Hồ bơi ngoài trời', 'Hồ bơi trong nhà', 'Vườn hoa', 'Cửa hàng', 'Dịch vụ spa', 'Ghế dài tắm nắng hồ bơi', 'Bãi gửi xe', 'Hồ bơi', 'Bãi gửi xe (thu phí)', 'Sân thượng/sân hiên', 'OTHER', 'Khu vực không hút thuốc', 'Tiệm cà phê', 'Thang máy', 'Dịch vụ trả phòng cấp tốc', 'Quầy lễ tân', 'Dịch vụ giặt ủi', 'Trò chơi trẻ em', 'Hồ bơi trẻ em', 'Đưa đón sân bay (thu phí)', 'Trung tâm thể dục thể hình']
#
# id: 565 - name: Hanoi Lion Boutique Hotel - style: Luxury
#  - district: Hoàn Kiếm - amenities: ['Nhân viên xách hành lý', 'Thức uống chào mừng miễn phí', 'Dịch vụ concierge/hỗ trợ khách', 'Dịch vụ thu đổi ngoại tệ', 'Người gác cửa', 'EARLY_CHECK_IN', 'Dịch vụ nhận phòng cấp tốc', 'Dịch vụ trả phòng cấp tốc', 'Quầy lễ tân', 'Lễ tân 24h', 'Bảo vệ 24 giờ', 'Dịch vụ trả phòng muộn', 'Dịch vụ giặt ủi', 'Dịch vụ lưu trữ/bảo quản hành lý', 'Nhân viên gác cổng', 'Dịch vụ hỗ trợ đặt Tour', 'Nhận phòng sớm', 'Thang máy', 'Trả phòng muộn', 'Nhà hàng', 'Nhà hàng phục vụ bữa sáng', 'Nhà hàng phục vụ bữa tối', 'Nhà hàng phục vụ bữa trưa', 'Két an toàn', 'WiFi tại khu vực chung', 'Áo choàng tắm', 'Truyền hình cáp', 'Bàn làm việc', 'Máy sấy tóc', 'Két an toàn trong phòng', 'Minibar', 'Phòng tắm vòi sen', 'TV', 'Máy lạnh', 'Phòng giữ đồ', 'Phòng gia đình', 'Phòng không hút thuốc', 'Khu vực hút thuốc', 'Không khói thuốc', 'Trung tâm thể dục thể hình', 'Mát-xa', 'Xông hơi ướt', 'Dịch vụ spa', 'Phòng xông hơi', 'Quầy bar', 'Bữa sáng', 'Tiệm cà phê', 'Đồ ăn nhẹ', 'Dịch vụ văn phòng', 'Máy photocopy', 'Máy in', 'Đưa đón sân bay', 'Cho thuê xe hơi', 'Đưa đón sân bay (thu phí)', 'Đưa đón sân bay', 'Wifi (miễn phí)', 'Cửa hàng thực phẩm']
#
# id: 352 - name: 20 October Homestay - R103 Vinhomes Ocean Park - style: Luxury
#  - district: Gia Lâm - amenities: ['Áo choàng tắm', 'Bàn làm việc', 'Máy sấy tóc', 'Nhà bếp mini', 'Tủ lạnh', 'Phòng tắm đứng và bồn tắm riêng', 'Phòng tắm vòi sen', 'TV', 'Máy ATM/Ngân hàng', 'Thẩm mỹ viện', 'Cửa hàng quà tặng', 'Cửa hàng thực phẩm', 'Hiệu làm tóc', 'Giặt ủi', 'Cửa hàng', 'Siêu thị', 'Máy lạnh', 'Phòng không hút thuốc', 'Hồ bơi', 'Sân thượng/sân hiên', 'Bãi đậu xe', 'Thang máy', 'Dịch vụ dọn phòng', 'Cho phép vật nuôi', 'Cho phép vật nuôi nhỏ', 'Bảng chỉ dẫn nổi hoặc chữ nổi', 'Phù hợp cho xe lăn', 'Wifi (miễn phí)', 'Dịch vụ giặt ủi']
#
# id: 1137 - name: Khách sạn Church Boutique Hàng Gai - style: Luxury
#  - district: Hoàn Kiếm - amenities: ['Dịch vụ giặt ủi', 'Nhật báo tại sảnh', 'Dịch vụ nhận phòng cấp tốc', 'Thức uống chào mừng miễn phí', 'Dịch vụ hỗ trợ đặt Tour', 'Dịch vụ lưu trữ/bảo quản hành lý', 'Dịch vụ trả phòng cấp tốc', 'Nhân viên gác cổng', 'Lễ tân 24h', 'Dịch vụ concierge/hỗ trợ khách', 'OTHER', 'Nhà hàng', 'Két an toàn', 'Cà phê/trà tại sảnh', 'Tiệm cà phê', 'Thang máy', 'Gói cầu hôn lãng mạn', 'Dịch vụ spa', 'Nhà tắm kiểu Thổ', 'Tủ khoá', 'Khu vực hút thuốc', 'Bãi gửi xe (thu phí)', 'Quầy bar', 'Bữa sáng', 'Wifi (miễn phí)', 'Đưa đón sân bay (thu phí)', 'TV', 'Cửa hàng lưu niệm']
#
# id: 2636 - name: NYNA GIA NGU - style: Luxury
#  - district: Hoàn Kiếm - amenities: ['Khu vực không hút thuốc', 'OTHER', 'Dịch vụ lưu trữ/bảo quản hành lý', 'Đội ngũ nhân viên đa ngôn ngữ', 'Wifi (miễn phí)']
#
# id: 2139 - name: Vinhomes Skylake Kane Apartment - style: Luxury
#  - district: Nam Từ Liêm - amenities: ['Dịch vụ spa', 'Vườn hoa', 'OTHER', 'Thang máy', 'Gửi xe có người phục vụ (thu phí)', 'Khu vực hút thuốc']
#
# id: 299 - name: Elegant Mansion 88 - style: Luxury
#  - district: Tây Hồ - amenities: []
#
# id: 2585 - name: Suji Hotel - style: Luxury
#  - district: Nam Từ Liêm - amenities: ['Dịch vụ concierge/hỗ trợ khách', 'Đội ngũ nhân viên đa ngôn ngữ', 'Dịch vụ trả phòng cấp tốc', 'Dịch vụ thu đổi ngoại tệ', 'Dịch vụ giặt ủi', 'Thang máy', 'OTHER', 'Dịch vụ dọn phòng', 'Đưa đón sân bay', 'Khu vực hút thuốc', 'Hiệu làm tóc']
#
# id: 68 - name: A25 Hotel - 18 Nguyen Hy Quang - style: Eco-friendly
#  - district: Đống Đa - amenities: ['Nhân viên xách hành lý', 'Thức uống chào mừng miễn phí', 'Dịch vụ concierge/hỗ trợ khách', 'Người gác cửa', 'Quầy lễ tân', 'Lễ tân 24h', 'Bảo vệ 24 giờ', 'Dịch vụ lưu trữ/bảo quản hành lý', 'Nhân viên gác cổng', 'Áo choàng tắm', 'Truyền hình cáp', 'Máy sấy tóc', 'Két an toàn trong phòng', 'Tủ lạnh', 'Phòng tắm vòi sen', 'TV', 'Thang máy', 'Nhà hàng', 'Nhà hàng phục vụ bữa sáng', 'Dịch vụ dọn phòng', 'Két an toàn', 'WiFi tại khu vực chung', 'Bữa sáng', 'Wifi (miễn phí)', 'Máy lạnh']
#
# id: 1690 - name: XanhVillas Resort & Spa - style: Luxury
#  - district: Thạch Thất - amenities: ['Dịch vụ giặt ủi', 'Nhật báo tại sảnh', 'Dịch vụ hỗ trợ đặt Tour', 'Dịch vụ lưu trữ/bảo quản hành lý', 'Nhân viên gác cổng', 'Lễ tân 24h', 'Dịch vụ concierge/hỗ trợ khách', 'Gói cầu hôn lãng mạn', 'Dịch vụ spa', 'Hồ bơi ngoài trời', 'Khu vực dã ngoại', 'Vườn hoa', 'Tiệc nướng ngoài trời', 'OTHER', 'Nhà hàng', 'Két an toàn', 'Hồ bơi trẻ em', 'Câu lạc bộ thiếu nhi (thu phí)', 'Quầy bar bên hồ bơi', 'Bữa sáng', 'Hồ bơi', 'Khu vực hút thuốc', 'Wifi (miễn phí)', 'Phòng họp', 'Sân quần vợt ngoài trời']
#
# id: 30 - name: La Passion Hanoi Hotel & Spa - style: Luxury
#  - district: Hoàn Kiếm - amenities: ['Bữa sáng với thực đơn gọi món', 'Bữa tối với thực đơn gọi món', 'Bữa trưa với thực đơn gọi món', 'Nhà hàng có máy lạnh', 'Quầy bar', 'Bữa sáng', 'Bữa sáng món tự chọn', 'Bữa sáng phục vụ tại bàn', 'Bữa sáng muộn', 'Tiệm cà phê', 'Bữa sáng kiểu Âu', 'Khu ẩm thực', 'Bữa sáng cho người dậy sớm', 'Tiệc liên hoan', 'Bữa sáng phục vụ món nóng', 'Câu lạc bộ đêm', 'Quầy bar', 'Bữa tối với thực đơn chọn sẵn', 'Bữa trưa với thực đơn chọn sẵn', 'Quầy phục vụ đồ ăn nhẹ', 'Đồ ăn nhẹ', 'Thực đơn ăn kiêng', 'Phục vụ món chay', 'Nhân viên xách hành lý', 'Thức uống chào mừng miễn phí', 'Dịch vụ concierge/hỗ trợ khách', 'Dịch vụ thu đổi ngoại tệ', 'Người gác cửa', 'EARLY_CHECK_IN', 'Dịch vụ nhận phòng cấp tốc', 'Dịch vụ trả phòng cấp tốc', 'Lễ tân 24h', 'Bảo vệ 24 giờ', 'Dịch vụ trả phòng muộn', 'Dịch vụ giặt ủi', 'Dịch vụ lưu trữ/bảo quản hành lý', 'Dịch vụ chăm sóc y tế', 'Điện thoại di động', 'Đội ngũ nhân viên đa ngôn ngữ', 'Nhật báo tại sảnh', 'Nhật báo', 'Dịch vụ hỗ trợ đặt Tour', 'Dịch vụ tiệc cưới', 'Cà phê/trà tại sảnh', 'Tiệm cà phê', 'Nhận phòng sớm', 'Thang máy', 'Trả phòng muộn', 'Nhà hàng', 'Nhà hàng phục vụ bữa sáng', 'Nhà hàng phục vụ bữa tối', 'Nhà hàng phục vụ bữa trưa', 'Dịch vụ dọn phòng', 'Két an toàn', 'WiFi tại khu vực chung', 'Máy lạnh', 'Tiệc chiêu đãi', 'Phòng giữ đồ', 'Máy sấy quần áo', 'Phòng gia đình', 'Máy sưởi', 'Phòng không hút thuốc', 'Phòng giải trí', 'Sân thượng/Sân hiên', 'Khu vực hút thuốc', 'Sân thượng/sân hiên', 'Áo choàng tắm', 'Bồn tắm', 'Truyền hình cáp', 'Bàn làm việc', 'Máy sấy tóc', 'Két an toàn trong phòng', 'Minibar', 'Phòng tắm đứng và bồn tắm riêng', 'Phòng tắm vòi sen', 'TV', 'Đưa đón sân bay', 'Dịch vụ cho thuê xe đạp', 'Giữ xe đạp', 'Cho thuê xe hơi', 'Bãi đậu xe (thu phí)', 'Bãi đậu xe an ninh', 'Đưa đón đến trung tâm thương mại', 'Gửi xe có người phục vụ (thu phí)', 'Máy ATM/Ngân hàng', 'Thẩm mỹ viện', 'Cửa hàng quà tặng', 'Cửa hàng thực phẩm', 'Hiệu làm tóc', 'Giặt ủi', 'Cửa hàng', 'Siêu thị', 'Dịch vụ văn phòng', 'Các tiện nghi văn phòng', 'Lễ tân hội nghị', 'Tiện nghi hội họp', 'Máy photocopy', 'Máy in', 'Thuận tiện cho người khuyết tật', 'Lối đi lại cho người khuyết tật', 'Phòng tắm phù hợp với xe lăn', 'Phù hợp cho xe lăn', 'Điện thoại gọi quốc tế', 'Điểm truy cập Internet', 'Wifi (miễn phí)', 'Đưa đón sân bay (thu phí)', 'Đón khách tại ga tàu', 'Đưa đón sân bay', 'Mát-xa', 'Dịch vụ spa', 'Ghế cho trẻ em']
#
# id: 2686 - name: Vinhomes Metropolis Hanoi - CitiHome - style: Luxury
#  - district: Ba Đình - amenities: ['Dịch vụ giặt ủi', 'Dịch vụ hỗ trợ đặt Tour', 'Đội ngũ nhân viên đa ngôn ngữ', 'Quầy lễ tân', 'OTHER', 'Khu vực không hút thuốc', 'Thang máy', 'Cửa hàng thực phẩm', 'Hiệu làm tóc', 'Máy ATM/Ngân hàng', 'Dịch vụ spa', 'Tiệc nướng ngoài trời', 'Bãi gửi xe', 'Lò sưởi tại sảnh', 'Bãi đậu xe có người phục vụ', 'Wifi (miễn phí)', 'Bàn bi-da']
#
# id: 2477 - name: Little Bee House - style: Eco-friendly
#  - district: Quốc Oai - amenities: []
#
# id: 2733 - name: HKG-Vinhomes Green Bay Luxury-Private - style: Luxury
#  - district: Nam Từ Liêm - amenities: ['Cửa hàng lưu niệm', 'Cửa hàng thực phẩm', 'Hiệu làm tóc', 'Máy ATM/Ngân hàng', 'Dịch vụ spa', 'Hồ bơi trong nhà', 'Cửa hàng', 'Bãi gửi xe', 'Tủ khoá', 'Khu vực hút thuốc', 'Gửi xe có người phục vụ (thu phí)', 'Wifi (miễn phí)', 'OTHER', 'TV', 'Dịch vụ giặt ủi']
#
# id: 1368 - name: Căn hộ dịch vụ Bayhomes Lancaster - style: Luxury
#  - district: Ba Đình - amenities: ['Hồ bơi trong nhà', 'Dịch vụ spa', 'Vườn hoa', 'Khu vực hút thuốc', 'Bãi gửi xe', 'Sân thượng/sân hiên', 'OTHER', 'Thang máy', 'Hồ bơi trẻ em', 'Đưa đón sân bay', 'Wifi (miễn phí)', 'Đưa đón sân bay (thu phí)', 'Dịch vụ hỗ trợ đặt Tour', 'Máy ATM/Ngân hàng', 'Trung tâm thể dục thể hình']
#
# id: 510 - name: Royal Holiday Hanoi Hotel - style: Luxury
#  - district: Hoàn Kiếm - amenities: ['Nhân viên xách hành lý', 'Thức uống chào mừng miễn phí', 'Dịch vụ thu đổi ngoại tệ', 'Người gác cửa', 'EARLY_CHECK_IN', 'Quầy lễ tân', 'Lễ tân 24h', 'Bảo vệ 24 giờ', 'Dịch vụ trả phòng muộn', 'Dịch vụ giặt ủi', 'Dịch vụ lưu trữ/bảo quản hành lý', 'Dịch vụ hỗ trợ đặt Tour', 'Truyền hình cáp', 'Bàn làm việc', 'Máy sấy tóc', 'Két an toàn trong phòng', 'Minibar', 'Tủ lạnh', 'Phòng tắm vòi sen', 'TV', 'Máy ATM/Ngân hàng', 'Thẩm mỹ viện', 'Cửa hàng quà tặng', 'Cửa hàng thực phẩm', 'Hiệu làm tóc', 'Cửa hàng', 'Siêu thị', 'Nhận phòng sớm', 'Thang máy', 'Trả phòng muộn', 'Nhà hàng phục vụ bữa sáng', 'Két an toàn', 'WiFi tại khu vực chung', 'Máy lạnh', 'Phòng gia đình', 'Máy sưởi', 'Phòng không hút thuốc', 'Đưa đón sân bay', 'Cho thuê xe hơi', 'Wifi (miễn phí)', 'Đưa đón sân bay (thu phí)']
#
# id: 326 - name: Khách sạn Sheraton Hà Nội - style: Luxury
#  - district: Tây Hồ - amenities: ['Dịch vụ hỗ trợ đặt Tour', 'Đội ngũ nhân viên đa ngôn ngữ', 'Dịch vụ giặt ủi', 'Dịch vụ nhận phòng cấp tốc', 'Nhật báo tại sảnh', 'Dịch vụ tiệc cưới', 'Dịch vụ lưu trữ/bảo quản hành lý', 'Dịch vụ trả phòng cấp tốc', 'Nhân viên gác cổng', 'Lễ tân 24h', 'Dịch vụ concierge/hỗ trợ khách', 'Hồ bơi ngoài trời', 'Vườn hoa', 'Cửa hàng', 'Dù (ô) trên bãi biển', 'Dịch vụ spa', 'Câu lạc bộ sức khoẻ', 'Xông hơi ướt', 'Phòng xông hơi', 'Ghế dài tắm nắng hồ bơi', 'Bãi gửi xe', 'Tiệc chiêu đãi', 'Hội trường đa chức năng', 'Sân thượng/sân hiên', 'Hồ bơi', 'Khu vực hút thuốc', 'OTHER', 'Tiệm cà phê', 'Thang máy', 'Cà phê/trà tại sảnh', 'Nhà hàng', 'Két an toàn', 'Trung tâm Hội nghị', 'Tiện nghi hội họp', 'Phòng hội nghị', 'Phòng họp', 'Phòng hội nghị', 'Máy tính', 'Sân quần vợt ngoài trời', 'Trung tâm thể dục thể hình', 'Sân tennis', 'Bàn bi-da', 'Quầy bar bên hồ bơi', 'Bữa sáng', 'Quầy phục vụ đồ ăn nhẹ', 'Máy ATM/Ngân hàng', 'Cửa hàng lưu niệm', 'Hồ bơi trẻ em', 'Dịch vụ xe limo/xe đưa đón hạng sang', 'Wifi (miễn phí)', 'Đưa đón sân bay (thu phí)']
#
# id: 1635 - name: Dream Premium Hotel & Spa - style: Luxury
#  - district: Hoàn Kiếm - amenities: ['Quầy lễ tân', 'Dịch vụ concierge/hỗ trợ khách', 'Dịch vụ giặt ủi', 'Dịch vụ hỗ trợ đặt Tour', 'Lễ tân 24h', 'Dịch vụ lưu trữ/bảo quản hành lý', 'Nhân viên gác cổng', 'Nhật báo tại sảnh', 'Dịch vụ nhận phòng cấp tốc', 'Dịch vụ trả phòng cấp tốc', 'Thức uống chào mừng miễn phí', 'EARLY_CHECK_IN', 'Dịch vụ trả phòng muộn', 'Dịch vụ thu đổi ngoại tệ', 'Người gác cửa', 'Điện thoại di động', 'Dịch vụ chăm sóc y tế', 'Bảo vệ 24 giờ', 'Nhân viên xách hành lý', 'Phòng gia đình', 'Khu vực hút thuốc', 'Máy lạnh', 'Phòng không hút thuốc', 'Sân thượng/sân hiên', 'Lò sưởi tại sảnh', 'Hội trường đa chức năng', 'Máy sấy quần áo', 'Máy sưởi', 'Két an toàn', 'WiFi tại khu vực chung', 'Tiệm cà phê', 'Nhà hàng', 'Cà phê/trà tại sảnh', 'Thang máy', 'Nhà hàng phục vụ bữa sáng', 'Trả phòng muộn', 'Nhận phòng sớm', 'Bàn làm việc', 'Tủ lạnh', 'Máy sấy tóc', 'Két an toàn trong phòng', 'TV', 'Phòng tắm vòi sen', 'Phòng tắm đứng và bồn tắm riêng', 'Minibar', 'Truyền hình cáp', 'Cửa hàng quà tặng', 'Cửa hàng', 'Máy ATM/Ngân hàng', 'Hiệu làm tóc', 'Siêu thị', 'Thẩm mỹ viện', 'Nhà máy rượu vang', 'Quầy bar', 'Bữa sáng', 'Tiệm cà phê', 'Bữa sáng món tự chọn', 'Wifi (miễn phí)', 'Mạng Internet cục bộ', 'WiFi tại khu vực chung (thu phí)', 'Điểm truy cập Internet', 'Phòng tắm phù hợp cho người khuyết tật', 'Lối đi lại cho người khuyết tật', 'Trang bị phòng phù hợp với người khuyết tật', 'Thuận tiện cho người khuyết tật', 'Đưa đón sân bay (thu phí)', 'Đón khách tại ga tàu', 'Đưa đón sân bay', 'Mát-xa', 'Dịch vụ spa', 'Dịch vụ xe limo/xe đưa đón hạng sang', 'Cho thuê xe hơi', 'Dịch vụ văn phòng', 'Máy in']
#
# id: 500 - name: FTE Ba Dinh Hotel - style: Luxury
#  - district: Ba Đình - amenities: ['Bữa sáng với thực đơn gọi món', 'Bữa tối với thực đơn gọi món', 'Bữa trưa với thực đơn gọi món', 'Nhà hàng có máy lạnh', 'Quầy bar', 'Bữa sáng', 'Bữa sáng và bữa tối', 'Bữa sáng và bữa trưa', 'Bữa sáng món tự chọn', 'Tiệm cà phê', 'Phục vụ bữa sáng/trưa/tối kèm thức uống không cồn', 'Phục vụ bữa sáng/trưa/tối không kèm thức uống', 'Bữa sáng miễn phí', 'Phục vụ bữa sáng/tối kèm đồ uống không cồn', 'Phục vụ bữa sáng/tối không kèm đồ uống', 'Bữa sáng phục vụ món nóng', 'Quầy bar bên hồ bơi', 'Quầy bar', 'Phục vụ món chay', 'Nhân viên xách hành lý', 'Thức uống chào mừng miễn phí', 'Dịch vụ concierge/hỗ trợ khách', 'Dịch vụ thu đổi ngoại tệ', 'Người gác cửa', 'Dịch vụ nhận phòng cấp tốc', 'Dịch vụ trả phòng cấp tốc', 'Quầy lễ tân', 'Lễ tân 24h', 'Bảo vệ 24 giờ', 'Dịch vụ giặt ủi', 'Dịch vụ lưu trữ/bảo quản hành lý', 'Đội ngũ nhân viên đa ngôn ngữ', 'Nhật báo tại sảnh', 'Nhật báo', 'Nhân viên gác cổng', 'Dịch vụ hỗ trợ đặt Tour', 'Dịch vụ tiệc cưới', 'Máy lạnh', 'Hội trường đa chức năng', 'Tiệc chiêu đãi', 'Phòng giữ đồ', 'Phòng gia đình', 'Máy sưởi', 'Phòng không hút thuốc', 'Hồ bơi', 'Phòng giải trí', 'Sân thượng/Sân hiên', 'Khu vực hút thuốc', 'Không khói thuốc', 'Sân thượng/sân hiên', 'Bãi đậu xe', 'Cà phê/trà tại sảnh', 'Tiệm cà phê', 'Thang máy', 'Dịch vụ phòng 24 giờ', 'Nhà hàng', 'Nhà hàng phục vụ bữa sáng', 'Nhà hàng phục vụ bữa tối', 'Nhà hàng phục vụ bữa trưa', 'Dịch vụ dọn phòng', 'Két an toàn', 'WiFi tại khu vực chung', 'Áo choàng tắm', 'Bồn tắm', 'Truyền hình cáp', 'Bàn làm việc', 'Máy sấy tóc', 'Két an toàn trong phòng', 'Minibar', 'Tủ lạnh', 'Phòng tắm đứng và bồn tắm riêng', 'Phòng tắm vòi sen', 'TV', 'Dịch vụ văn phòng', 'Lễ tân hội nghị', 'Phòng hội nghị', 'Tiện nghi hội họp', 'Máy photocopy', 'Máy in', 'Máy chiếu', 'Máy ATM/Ngân hàng', 'Thẩm mỹ viện', 'Cửa hàng quà tặng', 'Cửa hàng thực phẩm', 'Hiệu làm tóc', 'Cửa hàng', 'Siêu thị', 'Điện thoại gọi quốc tế', 'Điểm truy cập Internet', 'Mạng Internet cục bộ', 'Wifi (miễn phí)', 'Đưa đón sân bay (thu phí)', 'Đón khách tại ga tàu', 'Đưa đón sân bay', 'Câu lạc bộ sức khoẻ', 'Hồ bơi ngoài trời', 'Trung tâm thể dục thể hình', 'Bàn bi-da', 'Đưa đón sân bay']
#
# id: 828 - name: Angel Palace Apartment Nguyen Khac Hieu - style: Luxury
#  - district: Ba Đình - amenities: ['OTHER', 'Thang máy']
#
# id: 134 - name: Khách sạn Elegant Suites Westlake - style: Luxury
#  - district: Tây Hồ - amenities: ['Bãi đậu xe', 'Cà phê/trà tại sảnh', 'Tiệm cà phê', 'Thang máy', 'Nhà hàng', 'Nhà hàng phục vụ bữa sáng', 'Nhà hàng phục vụ bữa tối', 'Nhà hàng phục vụ bữa trưa', 'Dịch vụ dọn phòng', 'WiFi tại khu vực chung', 'Máy lạnh', 'Hội trường đa chức năng', 'Tiệc chiêu đãi', 'Phòng giữ đồ', 'Phòng gia đình', 'Lò sưởi tại sảnh', 'Phòng không hút thuốc', 'Hồ bơi', 'Khu vực hút thuốc', 'Khu vui chơi trẻ em', 'Trung tâm thể dục thể hình', 'Vườn hoa', 'Mát-xa', 'Hồ bơi ngoài trời', 'Xông hơi ướt', 'Dịch vụ spa', 'Truyền hình cáp', 'Bàn làm việc', 'Máy sấy tóc', 'Két an toàn trong phòng', 'Minibar', 'Phòng tắm vòi sen', 'TV', 'Người gác cửa', 'Lễ tân 24h', 'Bảo vệ 24 giờ', 'Dịch vụ giặt ủi', 'Dịch vụ lưu trữ/bảo quản hành lý', 'Dịch vụ tiệc cưới', 'Dịch vụ văn phòng', 'Phòng hội nghị', 'Tiện nghi hội họp', 'Máy photocopy', 'Máy chiếu', 'Quầy bar', 'Tiệm cà phê', 'Tiệc liên hoan', 'Quầy bar', 'Cửa hàng thực phẩm', 'Giặt ủi', 'Siêu thị', 'Điểm truy cập Internet', 'Mạng Internet cục bộ', 'Đưa đón sân bay (thu phí)', 'Đưa đón sân bay', 'Trung tâm thể dục thể hình']
#
# id: 1412 - name: Vinhomes Skylake Apartment City View - style: Luxury
#  - district: Cầu Giấy - amenities: ['Khu vực không hút thuốc', 'OTHER', 'Gửi xe có người phục vụ (thu phí)', 'Sân thượng/sân hiên', 'Dịch vụ giặt ủi']
#
# id: 976 - name: Cindy Vinhomes Skylake Apartments - style: Luxury
#  - district: Nam Từ Liêm - amenities: ['Hồ bơi ngoài trời', 'Hồ bơi trong nhà', 'Vườn hoa', 'Cửa hàng', 'Dịch vụ spa', 'Ghế dài tắm nắng hồ bơi', 'Bãi gửi xe', 'Hồ bơi', 'Bãi gửi xe (thu phí)', 'Sân thượng/sân hiên', 'OTHER', 'Khu vực không hút thuốc', 'Tiệm cà phê', 'Thang máy', 'Dịch vụ trả phòng cấp tốc', 'Quầy lễ tân', 'Dịch vụ giặt ủi', 'Trò chơi trẻ em', 'Hồ bơi trẻ em', 'Đưa đón sân bay (thu phí)', 'Trung tâm thể dục thể hình']
#
# id: 2136 - name: Royal Hotel Van Khe by Bay Luxury - style: Luxury
#  - district: Hà Đông - amenities: ['Wifi (miễn phí)', 'OTHER', 'Lễ tân 24h']
#
# id: 262 - name: Anatole Hotel Hanoi - style: Luxury
#  - district: Hoàn Kiếm - amenities: ['Nhân viên xách hành lý', 'Thức uống chào mừng miễn phí', 'Dịch vụ thu đổi ngoại tệ', 'Người gác cửa', 'Dịch vụ nhận phòng cấp tốc', 'Dịch vụ trả phòng cấp tốc', 'Lễ tân 24h', 'Bảo vệ 24 giờ', 'Dịch vụ giặt ủi', 'Dịch vụ phòng (có giới hạn thời gian)', 'Dịch vụ lưu trữ/bảo quản hành lý', 'Đội ngũ nhân viên đa ngôn ngữ', 'Nhân viên gác cổng', 'Dịch vụ hỗ trợ đặt Tour', 'Bữa tối với thực đơn gọi món', 'Bữa trưa với thực đơn gọi món', 'Nhà hàng có máy lạnh', 'Bữa sáng món tự chọn', 'Tiệm cà phê', 'Bữa sáng phục vụ món nóng', 'Quầy bar bên hồ bơi', 'Bữa tối với thực đơn chọn sẵn', 'Bữa trưa với thực đơn chọn sẵn', 'Đồ ăn nhẹ', 'Thực đơn ăn kiêng', 'Phục vụ món chay', 'Áo choàng tắm', 'Bồn tắm', 'Truyền hình cáp', 'Bàn làm việc', 'Máy sấy tóc', 'Két an toàn trong phòng', 'Minibar', 'Tủ lạnh', 'Phòng tắm đứng và bồn tắm riêng', 'Phòng tắm vòi sen', 'TV', 'Cà phê/trà tại sảnh', 'Tiệm cà phê', 'Thang máy', 'Nhà hàng', 'Nhà hàng phục vụ bữa sáng', 'Nhà hàng phục vụ bữa tối', 'Nhà hàng phục vụ bữa trưa', 'Dịch vụ dọn phòng', 'Két an toàn', 'WiFi tại khu vực chung', 'Máy lạnh', 'Phòng liên thông', 'Phòng gia đình', 'Phòng không hút thuốc', 'Hồ bơi', 'Sân thượng/Sân hiên', 'Khu vực hút thuốc', 'Không khói thuốc', 'Sân thượng/sân hiên', 'Hồ nước nóng Jacuzzi', 'Hồ bơi ngoài trời', 'Ghế dài tắm nắng hồ bơi', 'Xông hơi ướt', 'Phòng xông hơi', 'Quầy bar cạnh hồ bơi', 'Dịch vụ văn phòng', 'Phòng hội nghị', 'Tiện nghi hội họp', 'Máy photocopy', 'Máy in', 'Máy chiếu', 'Máy ATM/Ngân hàng', 'Thẩm mỹ viện', 'Cửa hàng quà tặng', 'Hiệu làm tóc', 'Cửa hàng', 'Siêu thị', 'Đưa đón sân bay', 'Gửi xe có người phục vụ (thu phí)', 'Mạng Internet cục bộ', 'Wifi (miễn phí)', 'Đưa đón sân bay (thu phí)']
#
# id: 1781 - name: LT.Housing Vinhomes Skylake - style: Luxury
#  - district: Nam Từ Liêm - amenities: ['Bãi gửi xe (thu phí)', 'Bãi gửi xe', 'Tủ khoá', 'Khu vực hút thuốc', 'OTHER', 'Thang máy', 'Bãi đậu xe có người phục vụ', 'Dịch vụ hỗ trợ đặt Tour', 'Máy ATM/Ngân hàng']
#
# id: 252 - name: Royal Dương Nội Hotel - style: Luxury
#  - district: Quận Hoài Đức - amenities: []
#
# id: 2242 - name: Calidas Royal Serviced Residence Ha Noi - style: Luxury
#  - district: Nam Từ Liêm - amenities: []
#
# id: 2643 - name: Grand Hanoi Hotel - style: Luxury
#  - district: Hoài Đức - amenities: []
#
# id: 1239 - name: Davidduc's Apartment Dang Thai Mai - style: Luxury
#  - district: Tây Hồ - amenities: ['Bàn làm việc', 'Tủ lạnh', 'Phòng tắm vòi sen', 'TV', 'Dịch vụ giặt ủi', 'Dịch vụ lưu trữ/bảo quản hành lý', 'Dịch vụ hỗ trợ đặt Tour', 'Bãi đậu xe', 'WiFi tại khu vực chung', 'Cửa hàng']
#
# id: 698 - name: Canvas Cau Giay Apartment - style: Luxury
#  - district: Cầu Giấy - amenities: ['Truyền hình cáp', 'Bàn làm việc', 'Phòng tắm vòi sen', 'TV', 'Máy lạnh', 'Khu vực hút thuốc', 'Bãi đậu xe', 'Thang máy', 'Lễ tân 24h']
#
# id: 398 - name: Vinhomes D'Capitale Serviced Apartment - style: Luxury
#  - district: Cầu Giấy - amenities: ['OTHER', 'Khu vực không hút thuốc', 'Thang máy', 'Phòng họp', 'Dịch vụ văn phòng', 'Trung tâm Hội nghị', 'Dịch vụ spa', 'Cửa hàng', 'Bãi gửi xe', 'Bãi gửi xe (thu phí)', 'Câu lạc bộ thiếu nhi']
#
# id: 796 - name: Vistay - style: Luxury
#  - district: Thanh Xuân - amenities: ['Khu vực hút thuốc', 'Bãi gửi xe (thu phí)', 'OTHER', 'Thang máy', 'Đưa đón sân bay (thu phí)', 'Dịch vụ giặt ủi', 'Máy ATM/Ngân hàng']
#
# id: 528 - name: Nesta Hotel - West Lake - style: Luxury
#  - district: Tây Hồ - amenities: ['Lễ tân 24h']
#
# id: 2535 - name: HKG - Vinhome GreenBay - Green apartment in Hanoi - style: Luxury
#  - district: Nam Từ Liêm - amenities: ['Thư viện', 'Vườn hoa', 'Phòng không hút thuốc', 'Lò sưởi tại sảnh', 'Thang máy', 'Cà phê/trà tại sảnh', 'Hiệu làm tóc', 'Máy ATM/Ngân hàng', 'Đường chơi bowling', 'Quần vợt', 'Giữ trẻ', 'Tiệm cà phê', 'Dịch vụ thu đổi ngoại tệ']
#
# id: 1129 - name: Vinhome Metropolis Lieu Giai Apartment - style: Luxury
#  - district: Ba Đình - amenities: ['Dù (ô) trên bãi biển', 'Bồn tắm nước nóng', 'Dịch vụ spa', 'Hồ bơi trong nhà', 'Cửa hàng', 'Hồ bơi ngoài trời', 'Ghế dài tắm nắng hồ bơi', 'OTHER', 'Khu vực không hút thuốc', 'Bãi gửi xe (thu phí)', 'Đưa đón sân bay (thu phí)', 'Dịch vụ giặt ủi']
#
# id: 1595 - name: Khách sạn Hovi Universal - style: Luxury
#  - district: Hoàn Kiếm - amenities: ['Thức uống chào mừng miễn phí', 'EARLY_CHECK_IN', 'Dịch vụ nhận phòng cấp tốc', 'Dịch vụ trả phòng cấp tốc', 'Quầy lễ tân', 'Lễ tân 24h', 'Bảo vệ 24 giờ', 'Dịch vụ trả phòng muộn', 'Dịch vụ giặt ủi', 'Dịch vụ lưu trữ/bảo quản hành lý', 'Dịch vụ hỗ trợ đặt Tour', 'Áo choàng tắm', 'Truyền hình cáp', 'Bàn làm việc', 'Máy sấy tóc', 'Minibar', 'Tủ lạnh', 'Phòng tắm vòi sen', 'TV', 'Máy ATM/Ngân hàng', 'Thẩm mỹ viện', 'Cửa hàng quà tặng', 'Cửa hàng thực phẩm', 'Hiệu làm tóc', 'Giặt ủi', 'Cửa hàng', 'Siêu thị', 'Nhận phòng sớm', 'Thang máy', 'Trả phòng muộn', 'Dịch vụ dọn phòng', 'WiFi tại khu vực chung', 'Máy lạnh', 'Phòng gia đình', 'Phòng không hút thuốc', 'Khu vực hút thuốc', 'Đưa đón sân bay', 'Dịch vụ cho thuê xe đạp', 'Cho thuê xe hơi', 'Nhà hàng có máy lạnh', 'Tiệm cà phê', 'Mạng Internet cục bộ', 'Wifi (miễn phí)', 'Đưa đón sân bay (thu phí)', 'Đưa đón sân bay', 'Dịch vụ văn phòng', 'Máy photocopy']
#
# id: 615 - name: Property Plus Luxury Apartment - Vinhomes Metropolis - style: Luxury
#  - district: Ba Đình - amenities: ['Dịch vụ concierge/hỗ trợ khách', 'Người gác cửa', 'EARLY_CHECK_IN', 'Dịch vụ nhận phòng cấp tốc', 'Dịch vụ trả phòng cấp tốc', 'Quầy lễ tân', 'Lễ tân 24h', 'Bảo vệ 24 giờ', 'Dịch vụ trả phòng muộn', 'Dịch vụ giặt ủi', 'Dịch vụ phòng (có giới hạn thời gian)', 'Điện thoại di động', 'Đội ngũ nhân viên đa ngôn ngữ', 'Bãi đậu xe', 'Cà phê/trà tại sảnh', 'Tiệm cà phê', 'Nhận phòng sớm', 'Thang máy', 'Trả phòng muộn', 'Nhà hàng', 'Nhà hàng phục vụ bữa tối', 'Nhà hàng phục vụ bữa trưa', 'Dịch vụ dọn phòng', 'Két an toàn', 'WiFi tại khu vực chung', 'Bồn tắm', 'Truyền hình cáp', 'Bàn làm việc', 'Máy sấy tóc', 'Két an toàn trong phòng', 'Nhà bếp mini', 'Lò vi sóng', 'Minibar', 'Tủ lạnh', 'Phòng tắm đứng và bồn tắm riêng', 'Phòng tắm vòi sen', 'TV', 'Phòng được trang bị phù hợp cho người khuyết tật', 'Phòng tắm phù hợp cho người khuyết tật', 'Chỗ đậu xe cho người khuyết tật', 'Lối đi lại cho người khuyết tật', 'Thuận tiện cho người khuyết tật', 'Trang bị phòng phù hợp với người khuyết tật', 'Phòng tắm phù hợp với xe lăn', 'Phù hợp cho xe lăn', 'Máy ATM/Ngân hàng', 'Thẩm mỹ viện', 'Cửa hàng quà tặng', 'Cửa hàng thực phẩm', 'Hiệu làm tóc', 'Giặt ủi', 'Cửa hàng', 'Siêu thị', 'Máy lạnh', 'Máy sấy quần áo', 'Phòng gia đình', 'Phòng không hút thuốc', 'Hồ bơi', 'Sân thượng/sân hiên', 'Khu vui chơi trẻ em', 'Vườn hoa', 'Các tiện nghi ngoài trời', 'Dịch vụ spa', 'Phòng xem TV', 'Nhà hàng có máy lạnh', 'Tiệm cà phê', 'Khu ẩm thực', 'Bãi đậu xe (thu phí)', 'Nhà chứa xe', 'Bãi đậu xe an ninh', 'Điểm truy cập Internet', 'Mạng Internet cục bộ', 'Wifi (miễn phí)', 'Dịch vụ văn phòng', 'Các tiện nghi văn phòng', 'Đưa đón sân bay (thu phí)']
#
# id: 40 - name: Dal Vostro Hotel & Spa - style: Luxury
#  - district: Hoàn Kiếm - amenities: ['Bữa sáng với thực đơn gọi món', 'Bữa tối với thực đơn gọi món', 'Nhà hàng có máy lạnh', 'Quầy bar', 'Bữa sáng', 'Bữa sáng và bữa tối', 'Bữa sáng món tự chọn', 'Bữa sáng phục vụ tại bàn', 'Bữa tối món tự chọn', 'Bữa trưa món tự chọn', 'Tiệm cà phê', 'Khu ẩm thực', 'Bữa sáng cho người dậy sớm', 'Bữa sáng phục vụ món nóng', 'Quầy bar', 'Quầy phục vụ đồ ăn nhẹ', 'Đồ ăn nhẹ', 'Phục vụ món chay', 'Nhân viên xách hành lý', 'Thức uống chào mừng miễn phí', 'Dịch vụ concierge/hỗ trợ khách', 'Dịch vụ thu đổi ngoại tệ', 'EARLY_CHECK_IN', 'Dịch vụ nhận phòng cấp tốc', 'Dịch vụ trả phòng cấp tốc', 'Quầy lễ tân', 'Lễ tân 24h', 'Bảo vệ 24 giờ', 'Dịch vụ trả phòng muộn', 'Dịch vụ giặt ủi', 'Dịch vụ lưu trữ/bảo quản hành lý', 'Đội ngũ nhân viên đa ngôn ngữ', 'Nhật báo tại sảnh', 'Nhật báo', 'Nhân viên gác cổng', 'Dịch vụ hỗ trợ đặt Tour', 'Cà phê/trà tại sảnh', 'Tiệm cà phê', 'Nhận phòng sớm', 'Thang máy', 'Dịch vụ phòng 24 giờ', 'Trả phòng muộn', 'Nhà hàng', 'Nhà hàng phục vụ bữa sáng', 'Nhà hàng phục vụ bữa tối', 'Dịch vụ dọn phòng', 'Két an toàn', 'WiFi tại khu vực chung', 'Máy lạnh', 'Tiệc chiêu đãi', 'Phòng giữ đồ', 'Phòng liên thông', 'Phòng gia đình', 'Máy sưởi', 'Phòng không hút thuốc', 'Sân thượng/Sân hiên', 'Khu vực hút thuốc', 'Sân thượng/sân hiên', 'Dịch vụ văn phòng', 'Các tiện nghi văn phòng', 'Máy tính', 'Lễ tân hội nghị', 'Phòng hội nghị', 'Tiện nghi hội họp', 'Máy photocopy', 'Máy in', 'Máy chiếu', 'Áo choàng tắm', 'Truyền hình cáp', 'Bàn làm việc', 'Máy sấy tóc', 'Két an toàn trong phòng', 'Minibar', 'Tủ lạnh', 'Phòng tắm vòi sen', 'TV', 'Máy ATM/Ngân hàng', 'Thẩm mỹ viện', 'Cửa hàng quà tặng', 'Cửa hàng thực phẩm', 'Hiệu làm tóc', 'Giặt ủi', 'Cửa hàng', 'Siêu thị', 'Đưa đón sân bay', 'Dịch vụ cho thuê xe đạp', 'Giữ xe đạp', 'Cho thuê xe hơi', 'Bãi đậu xe (thu phí)', 'Điện thoại gọi quốc tế', 'Điểm truy cập Internet', 'Mạng Internet cục bộ', 'Wifi (miễn phí)', 'Đưa đón sân bay (thu phí)', 'Đón khách tại ga tàu', 'Đưa đón sân bay', 'CRIBS', 'Ghế cho trẻ em', 'Phù hợp cho xe lăn', 'Mát-xa']
#
# id: 948 - name: Somerset West Point Hanoi - style: Luxury
#  - district: Tây Hồ - amenities: ['Áo choàng tắm', 'Bồn tắm', 'Truyền hình cáp', 'Bàn làm việc', 'Máy sấy tóc', 'Két an toàn trong phòng', 'Nhà bếp mini', 'Lò vi sóng', 'Minibar', 'Tủ lạnh', 'Phòng tắm vòi sen', 'TV', 'Nhân viên xách hành lý', 'Thức uống chào mừng miễn phí', 'Dịch vụ thu đổi ngoại tệ', 'Người gác cửa', 'Quầy lễ tân', 'Lễ tân 24h', 'Bảo vệ 24 giờ', 'Dịch vụ giặt ủi', 'Dịch vụ lưu trữ/bảo quản hành lý', 'Đội ngũ nhân viên đa ngôn ngữ', 'Bãi đậu xe', 'Tiệm cà phê', 'Thang máy', 'Nhà hàng', 'Nhà hàng phục vụ bữa sáng', 'Dịch vụ dọn phòng', 'Két an toàn', 'WiFi tại khu vực chung', 'Máy ATM/Ngân hàng', 'Thẩm mỹ viện', 'Cửa hàng thực phẩm', 'Hiệu làm tóc', 'Giặt ủi', 'Cửa hàng', 'Siêu thị', 'Máy lạnh', 'Phòng liên thông', 'Lò sưởi tại sảnh', 'Phòng không hút thuốc', 'Hồ bơi', 'Khu vực hút thuốc', 'Đưa đón sân bay', 'Đưa đón trong khu vực', 'Bãi đậu xe hạn chế', 'Đưa đón đến trung tâm thương mại', 'Hồ bơi ngoài trời', 'Xông hơi ướt', 'Phòng xông hơi', 'Phòng xem TV', 'Bữa sáng món tự chọn', 'Tiệm cà phê', 'Bữa trưa với thực đơn chọn sẵn', 'Dịch vụ văn phòng', 'Máy photocopy', 'Máy in', 'Điện thoại gọi quốc tế', 'Wifi (miễn phí)', 'Câu lạc bộ thiếu nhi', 'Thuận tiện cho người khuyết tật', 'Đưa đón sân bay (thu phí)']
#
# id: 580 - name: Royal Văn Phú Hotel - style: Luxury
#  - district: Hà Đông - amenities: ['Dịch vụ giặt ủi', 'Dịch vụ lưu trữ/bảo quản hành lý', 'Lễ tân 24h', 'Bãi gửi xe', 'Khu vực hút thuốc', 'Wifi (miễn phí)', 'OTHER']
#
# id: 1028 - name: Gemma Housing - Nice Apartment Vincom D'Capitale Cau Giay - style: Luxury
#  - district: Cầu Giấy - amenities: ['Bàn bi-da', 'Đường chơi bowling', 'Quần vợt', 'Bóng quần', 'Phòng trò chơi', 'Trung tâm thể dục thể hình', 'Dịch vụ concierge/hỗ trợ khách', 'Dịch vụ trả phòng cấp tốc', 'Dịch vụ thu đổi ngoại tệ', 'Dịch vụ giặt ủi', 'Tiệm cà phê', 'Câu lạc bộ đêm', 'Quầy bar bên hồ bơi', 'Bồn tắm nước nóng', 'Thư viện', 'Vườn hoa', 'Thang máy', 'Nhà hàng', 'Dịch vụ dọn phòng', 'Phòng không hút thuốc', 'Khu vực hút thuốc', 'Hiệu làm tóc', 'Máy ATM/Ngân hàng', 'TV']
#
# id: 259 - name: The Oriental Jade Hotel - style: Luxury
#  - district: Hoàn Kiếm - amenities: ['Bữa tối với thực đơn gọi món', 'Bữa trưa với thực đơn gọi món', 'Nhà hàng có máy lạnh', 'Quầy bar', 'Bữa sáng', 'Bữa sáng món tự chọn', 'Bữa sáng (thu phí)', 'Tiệm cà phê', 'Bữa sáng kiểu Âu', 'Phục vụ bữa sáng/trưa/tối không kèm thức uống', 'Tiệc liên hoan', 'Bữa ăn không chứa gluten', 'Bữa sáng phục vụ món nóng', 'Quầy bar bên hồ bơi', 'Bữa tối với thực đơn chọn sẵn', 'Bữa trưa với thực đơn chọn sẵn', 'Nhà hàng có trình diễn nấu ăn', 'Nhà máy rượu vang', 'Nhân viên xách hành lý', 'Thức uống chào mừng miễn phí', 'Dịch vụ concierge/hỗ trợ khách', 'Dịch vụ thu đổi ngoại tệ', 'Người gác cửa', 'EARLY_CHECK_IN', 'Quầy lễ tân', 'Lễ tân 24h', 'Bảo vệ 24 giờ', 'Dịch vụ trả phòng muộn', 'Dịch vụ giặt ủi', 'Dịch vụ phòng (có giới hạn thời gian)', 'Dịch vụ lưu trữ/bảo quản hành lý', 'Nhật báo tại sảnh', 'Nhật báo', 'Nhân viên gác cổng', 'Dịch vụ hỗ trợ đặt Tour', 'Cà phê/trà tại sảnh', 'Tiệm cà phê', 'Nhận phòng sớm', 'Thang máy', 'Trả phòng muộn', 'Nhà hàng', 'Nhà hàng phục vụ bữa sáng', 'Nhà hàng phục vụ bữa tối', 'Nhà hàng phục vụ bữa trưa', 'Dịch vụ dọn phòng', 'Két an toàn', 'WiFi tại khu vực chung', 'Máy lạnh', 'Phòng liên thông', 'Phòng gia đình', 'Lò sưởi tại sảnh', 'Phòng không hút thuốc', 'Hồ bơi', 'Khu vực hút thuốc', 'Không khói thuốc', 'Sân thượng/sân hiên', 'Áo choàng tắm', 'Truyền hình cáp', 'Bàn làm việc', 'Máy sấy tóc', 'Két an toàn trong phòng', 'Minibar', 'Tủ lạnh', 'Phòng tắm vòi sen', 'TV', 'Phòng hội nghị', 'Tiện nghi hội họp', 'Máy photocopy', 'Máy in', 'Máy chiếu', 'Đưa đón sân bay', 'Dịch vụ cho thuê xe đạp', 'Cho thuê xe hơi', 'Dịch vụ xe limo/xe đưa đón hạng sang', 'Điện thoại gọi quốc tế', 'Điểm truy cập Internet', 'Mạng Internet cục bộ', 'Wifi (miễn phí)', 'Máy ATM/Ngân hàng', 'Cửa hàng thực phẩm', 'Cửa hàng', 'Trung tâm thể dục thể hình', 'Mát-xa', 'Hồ bơi ngoài trời', 'Đưa đón sân bay (thu phí)', 'Đón khách tại ga tàu', 'Đưa đón sân bay', 'Phòng tắm phù hợp cho người khuyết tật', 'Phù hợp cho xe lăn', 'CRIBS']
#
# id: 1780 - name: Vinhomes Skylake Service Apartment - Ha Noi - style: Luxury
#  - district: Nam Từ Liêm - amenities: ['Trung tâm thể dục thể hình', 'Bàn bi-da', 'Quần vợt', 'Bóng quần', 'Phòng trò chơi', 'Dịch vụ giặt ủi', 'Dịch vụ concierge/hỗ trợ khách', 'Dịch vụ trả phòng cấp tốc', 'Khu vực hút thuốc', 'Lò sưởi tại sảnh', 'Thang máy', 'Nhà hàng', 'Hiệu làm tóc', 'Máy ATM/Ngân hàng', 'Tiệm cà phê', 'Điện thoại gọi quốc tế', 'TV']
#
# id: 1355 - name: Ritz Boutique Hotel - style: Luxury
#  - district: Hoàn Kiếm - amenities: ['Dịch vụ phòng 24 giờ', 'Dịch vụ dọn phòng', 'Két an toàn', 'WiFi tại khu vực chung', 'Nhà hàng', 'Cà phê/trà tại sảnh', 'Thang máy', 'Lễ tân 24h']
#
# id: 2659 - name: Granda Serviced Apartment 5 - style: Luxury
#  - district: Cầu Giấy - amenities: ['Thức uống chào mừng miễn phí', 'Dịch vụ concierge/hỗ trợ khách', 'Dịch vụ thu đổi ngoại tệ', 'EARLY_CHECK_IN', 'Dịch vụ nhận phòng cấp tốc', 'Dịch vụ trả phòng cấp tốc', 'Quầy lễ tân', 'Lễ tân 24h', 'Bảo vệ 24 giờ', 'Dịch vụ trả phòng muộn', 'Dịch vụ giặt ủi', 'Dịch vụ lưu trữ/bảo quản hành lý', 'Đội ngũ nhân viên đa ngôn ngữ', 'Bồn tắm', 'Truyền hình cáp', 'Bàn làm việc', 'Máy sấy tóc', 'Két an toàn trong phòng', 'Nhà bếp mini', 'Lò vi sóng', 'Tủ lạnh', 'Phòng tắm đứng và bồn tắm riêng', 'Phòng tắm vòi sen', 'TV', 'Bãi đậu xe', 'Nhận phòng sớm', 'Thang máy', 'Dịch vụ phòng 24 giờ', 'Trả phòng muộn', 'Dịch vụ dọn phòng', 'Két an toàn', 'WiFi tại khu vực chung', 'Máy ATM/Ngân hàng', 'Thẩm mỹ viện', 'Cửa hàng thực phẩm', 'Hiệu làm tóc', 'Cửa hàng', 'Siêu thị', 'Máy lạnh', 'Máy sưởi', 'Phòng không hút thuốc', 'Khu vực hút thuốc', 'Sân thượng/sân hiên', 'Điểm truy cập Internet', 'Mạng Internet cục bộ', 'Wifi (miễn phí)', 'Đưa đón sân bay', 'Nhà chứa xe', 'Đưa đón sân bay (thu phí)', 'Đưa đón sân bay']
#
# id: 128 - name: Zephyr Suites Boutique Hotel - style: Luxury
#  - district: Hoàn Kiếm - amenities: ['Bồn tắm', 'Truyền hình cáp', 'Bàn làm việc', 'Máy sấy tóc', 'Két an toàn trong phòng', 'Minibar', 'Tủ lạnh', 'Phòng tắm vòi sen', 'TV', 'Nhân viên xách hành lý', 'Dịch vụ thu đổi ngoại tệ', 'Người gác cửa', 'Quầy lễ tân', 'Lễ tân 24h', 'Dịch vụ giặt ủi', 'Dịch vụ phòng (có giới hạn thời gian)', 'Dịch vụ lưu trữ/bảo quản hành lý', 'Dịch vụ hỗ trợ đặt Tour', 'Cà phê/trà tại sảnh', 'Thang máy', 'Nhà hàng', 'Nhà hàng phục vụ bữa sáng', 'Két an toàn', 'WiFi tại khu vực chung', 'Chỗ đậu xe cho người khuyết tật', 'Thuận tiện cho người khuyết tật', 'Trang bị phòng phù hợp với người khuyết tật', 'Phòng tắm phù hợp với xe lăn', 'Phù hợp cho xe lăn', 'Máy lạnh', 'Phòng liên thông', 'Phòng gia đình', 'Phòng không hút thuốc', 'Nhà hàng có máy lạnh', 'Bữa sáng', 'Tiệm cà phê', 'Wifi (miễn phí)', 'WiFi tại khu vực chung (thu phí)', 'Cửa hàng thực phẩm']
#
# id: 312 - name: Roygent Parks Hanoi - style: Luxury
#  - district: Cầu Giấy - amenities: ['Áo choàng tắm', 'Bồn tắm', 'Truyền hình cáp', 'Bàn làm việc', 'Máy sấy tóc', 'Két an toàn trong phòng', 'Nhà bếp mini', 'Lò vi sóng', 'Tủ lạnh', 'Phòng tắm vòi sen', 'TV', 'Nhân viên xách hành lý', 'Dịch vụ concierge/hỗ trợ khách', 'Người gác cửa', 'Dịch vụ nhận phòng cấp tốc', 'Dịch vụ trả phòng cấp tốc', 'Lễ tân 24h', 'Bảo vệ 24 giờ', 'Dịch vụ giặt ủi', 'Dịch vụ lưu trữ/bảo quản hành lý', 'Đội ngũ nhân viên đa ngôn ngữ', 'Nhà hàng có máy lạnh', 'Quầy bar', 'Bữa sáng', 'Bữa sáng món tự chọn', 'Bữa sáng (thu phí)', 'Tiệm cà phê', 'Bữa sáng kiểu Âu', 'Khu ẩm thực', 'Quầy phục vụ đồ ăn nhẹ', 'Tiệc nướng ngoài trời', 'Khu vui chơi trẻ em', 'Trung tâm thể dục thể hình', 'Hồ nước nóng Jacuzzi', 'Hồ bơi ngoài trời', 'Xông hơi ướt', 'Xông hơi khô/ướt', 'Phòng xông hơi', 'Đưa đón sân bay', 'Đưa đón trong khu vực', 'Cho thuê xe hơi', 'Nhà chứa xe', 'Bãi đậu xe an ninh', 'Đưa đón đến trung tâm thương mại', 'Bãi đậu xe có người phục vụ', 'Máy lạnh', 'Tiệc chiêu đãi', 'Máy sấy quần áo', 'Phòng gia đình', 'Phòng không hút thuốc', 'Hồ bơi', 'Khu vực hút thuốc', 'Bãi đậu xe', 'Tiệm cà phê', 'Thang máy', 'Nhà hàng', 'Dịch vụ dọn phòng', 'Két an toàn', 'WiFi tại khu vực chung', 'Máy ATM/Ngân hàng', 'Cửa hàng', 'Siêu thị', 'Thuận tiện cho người khuyết tật', 'Phù hợp cho xe lăn', 'Đưa đón sân bay (thu phí)', 'Đưa đón sân bay', 'Câu lạc bộ thiếu nhi', 'Trung tâm thể dục thể hình', 'Wifi (miễn phí)']
#
# id: 2566 - name: Grand Hotel Trinh Van Bo-by BayLuxury - style: Luxury
#  - district: Nam Từ Liêm - amenities: ['Wifi (miễn phí)', 'OTHER', 'Lễ tân 24h']
#
# id: 2560 - name: Vinhomes Skylake Residence - CitiHome - style: Luxury
#  - district: Nam Từ Liêm - amenities: ['Cửa hàng lưu niệm', 'Cửa hàng thực phẩm', 'Hiệu làm tóc', 'Máy ATM/Ngân hàng', 'Dịch vụ giặt ủi', 'Dịch vụ lưu trữ/bảo quản hành lý', 'Quầy lễ tân', 'OTHER', 'Khu vực không hút thuốc', 'Gửi xe có người phục vụ (thu phí)', 'Cửa hàng', 'Đưa đón sân bay (thu phí)']
#
# id: 2142 - name: Daisy Homestay - Vinhomes Sky Lake - style: Luxury
#  - district: Nam Từ Liêm - amenities: ['Hồ bơi ngoài trời', 'Cửa hàng', 'OTHER', 'Khu vực không hút thuốc', 'Gửi xe có người phục vụ (thu phí)', 'Wifi (miễn phí)', 'Đưa đón sân bay (thu phí)', 'Lễ tân 24h']
#
# id: 2174 - name: Tom‘s House - style: Luxury
#  - district: Nam Từ Liêm - amenities: ['Khu vực dã ngoại', 'Thư viện', 'Vườn hoa', 'Khu vực hút thuốc', 'Thang máy', 'TV', 'Máy ATM/Ngân hàng']
#
# id: 506 - name: Vinhome Time City Full Service Apartment - style: Luxury
#  - district: Hai Bà Trưng - amenities: ['Wifi (miễn phí)', 'OTHER']
#
# id: 2707 - name: Dolphin Plaza - style: Luxury
#  - district: Nam Từ Liêm - amenities: ['Truyền hình cáp', 'Bàn làm việc', 'Máy sấy tóc', 'Két an toàn trong phòng', 'Nhà bếp mini', 'Lò vi sóng', 'Minibar', 'Tủ lạnh', 'Phòng tắm đứng và bồn tắm riêng', 'Phòng tắm vòi sen', 'TV', 'EARLY_CHECK_IN', 'Dịch vụ nhận phòng cấp tốc', 'Dịch vụ trả phòng cấp tốc', 'Bảo vệ 24 giờ', 'Dịch vụ trả phòng muộn', 'Dịch vụ giặt ủi', 'Dịch vụ phòng (có giới hạn thời gian)', 'Dịch vụ lưu trữ/bảo quản hành lý', 'Máy ATM/Ngân hàng', 'Thẩm mỹ viện', 'Cửa hàng quà tặng', 'Cửa hàng thực phẩm', 'Hiệu làm tóc', 'Giặt ủi', 'Cửa hàng', 'Siêu thị', 'Bãi đậu xe', 'Nhận phòng sớm', 'Thang máy', 'Trả phòng muộn', 'Nhà hàng', 'Dịch vụ dọn phòng', 'WiFi tại khu vực chung', 'Máy lạnh', 'Máy sưởi', 'Phòng không hút thuốc', 'Đưa đón sân bay', 'Nhà chứa xe', 'Wifi (miễn phí)']
#
# id: 847 - name: Vinhome Skylake Luxury Apartment - style: Luxury
#  - district: Nam Từ Liêm - amenities: ['Mạng Internet cục bộ', 'Wifi (miễn phí)', 'Bãi gửi xe (thu phí)']
#
# id: 2128 - name: Gem Apartment - Vinhomes Green Bay Ha Noi - style: Luxury
#  - district: Nam Từ Liêm - amenities: ['Khu vực dã ngoại', 'Thư viện', 'Vườn hoa', 'Dịch vụ concierge/hỗ trợ khách', 'Dịch vụ trả phòng cấp tốc', 'Dịch vụ thu đổi ngoại tệ', 'Bóng bàn', 'Quần vợt', 'Bóng quần', 'Khu vực hút thuốc', 'Lò sưởi tại sảnh', 'Thang máy', 'OTHER', 'Hiệu làm tóc', 'Máy ATM/Ngân hàng', 'TV']
#
# id: 1843 - name: Ficus Suites Apartment - style: Luxury
#  - district: Hoàn Kiếm - amenities: ['Dịch vụ giặt ủi', 'Nhật báo tại sảnh', 'Dịch vụ lưu trữ/bảo quản hành lý', 'Lễ tân 24h', 'Dịch vụ hỗ trợ đặt Tour', 'Dịch vụ concierge/hỗ trợ khách', 'Bãi gửi xe', 'Khu vực hút thuốc', 'Sân thượng/sân hiên', 'Sân thượng/Sân hiên', 'OTHER', 'Két an toàn', 'Thang máy', 'Khu vực dã ngoại', 'Vườn hoa', 'Wifi (miễn phí)', 'Đưa đón sân bay (thu phí)', 'Dịch vụ văn phòng', 'TV']
#
# id: 350 - name: Hanoi Fiesta Grand Hotel and Spa - style: Luxury
#  - district: Hoàn Kiếm - amenities: ['Lễ tân 24h']
#
# id: 177 - name: Authentic Hanoi Boutique Hotel - style: Luxury
#  - district: Hoàn Kiếm - amenities: ['Nhân viên xách hành lý', 'Thức uống chào mừng miễn phí', 'Dịch vụ concierge/hỗ trợ khách', 'Dịch vụ thu đổi ngoại tệ', 'Người gác cửa', 'EARLY_CHECK_IN', 'Dịch vụ nhận phòng cấp tốc', 'Dịch vụ trả phòng cấp tốc', 'Quầy lễ tân', 'Lễ tân 24h', 'Bảo vệ 24 giờ', 'Dịch vụ giặt ủi', 'Dịch vụ lưu trữ/bảo quản hành lý', 'Điện thoại di động', 'Đội ngũ nhân viên đa ngôn ngữ', 'Nhật báo', 'Nhân viên gác cổng', 'Dịch vụ hỗ trợ đặt Tour', 'Cà phê/trà tại sảnh', 'Tiệm cà phê', 'Thang máy', 'Nhà hàng', 'Nhà hàng phục vụ bữa sáng', 'Nhà hàng phục vụ bữa tối', 'Nhà hàng phục vụ bữa trưa', 'Dịch vụ dọn phòng', 'Két an toàn', 'WiFi tại khu vực chung', 'Áo choàng tắm', 'Bồn tắm', 'Bàn làm việc', 'Máy sấy tóc', 'Két an toàn trong phòng', 'Minibar', 'Phòng tắm vòi sen', 'TV', 'Máy lạnh', 'Hội trường đa chức năng', 'Phòng giữ đồ', 'Phòng gia đình', 'Phòng không hút thuốc', 'Khu vực hút thuốc', 'Sân thượng/sân hiên', 'Dịch vụ văn phòng', 'Máy tính', 'Lễ tân hội nghị', 'Phòng hội nghị', 'Tiện nghi hội họp', 'Máy photocopy', 'Máy chiếu', 'Máy ATM/Ngân hàng', 'Thẩm mỹ viện', 'Cửa hàng thực phẩm', 'Hiệu làm tóc', 'Giặt ủi', 'Cửa hàng', 'Siêu thị', 'Bữa sáng với thực đơn gọi món', 'Nhà hàng có máy lạnh', 'Quầy bar', 'Bữa sáng', 'Tiệm cà phê', 'Quầy bar', 'Đưa đón sân bay (thu phí)', 'Xe đưa đón bến du thuyền (thu phí)', 'Đón khách tại ga tàu', 'Đưa đón sân bay', 'Đưa đón sân bay', 'Cho thuê xe hơi', 'Dịch vụ xe limo/xe đưa đón hạng sang', 'Thuận tiện cho người khuyết tật', 'Lối đi lại cho người khuyết tật', 'Phù hợp cho xe lăn', 'Điểm truy cập Internet', 'Mạng Internet cục bộ', 'Wifi (miễn phí)', 'Mát-xa', 'Dịch vụ spa', 'Trung tâm thể dục thể hình']
#
# id: 488 - name: Peridot Gallery Classic Hotel - style: Luxury
# ...
#
# id: 1619 - name: Hanoi Must-stay Apartment - style: Luxury
#  - district: Hoàn Kiếm - amenities: []
#
# id: 609 - name: Khách sạn Pullman Hà Nội - style: Luxury
#  - district: Đống Đa - amenities: ['Dịch vụ concierge/hỗ trợ khách', 'Dịch vụ nhận phòng cấp tốc', 'Dịch vụ trả phòng cấp tốc', 'Lễ tân 24h', 'Bãi đậu xe', 'WiFi tại khu vực chung', 'Giữ trẻ', 'Hồ bơi ngoài trời', 'Bãi đậu xe buýt/xe tải', 'Hồ bơi', 'TV', 'Máy ATM/Ngân hàng']
#
# id: 943 - name: Reyna Luxury Hotel - style: Luxury
#  - district: Nam Từ Liêm - amenities: ['Nhân viên xách hành lý', 'Thức uống chào mừng miễn phí', 'Dịch vụ concierge/hỗ trợ khách', 'Dịch vụ thu đổi ngoại tệ', 'Người gác cửa', 'EARLY_CHECK_IN', 'Quầy lễ tân', 'Lễ tân 24h', 'Bảo vệ 24 giờ', 'Dịch vụ trả phòng muộn', 'Dịch vụ giặt ủi', 'Dịch vụ phòng (có giới hạn thời gian)', 'Dịch vụ lưu trữ/bảo quản hành lý', 'Dịch vụ hỗ trợ đặt Tour', 'Áo choàng tắm', 'Bồn tắm', 'Truyền hình cáp', 'Bàn làm việc', 'Máy sấy tóc', 'Két an toàn trong phòng', 'Minibar', 'Phòng tắm đứng và bồn tắm riêng', 'Phòng tắm vòi sen', 'TV', 'Nhận phòng sớm', 'Thang máy', 'Trả phòng muộn', 'Nhà hàng phục vụ bữa sáng', 'Nhà hàng phục vụ bữa tối', 'Nhà hàng phục vụ bữa trưa', 'Dịch vụ dọn phòng', 'Két an toàn', 'WiFi tại khu vực chung', 'Máy ATM/Ngân hàng', 'Cửa hàng quà tặng', 'Cửa hàng thực phẩm', 'Hiệu làm tóc', 'Cửa hàng', 'Siêu thị', 'Nhà hàng có máy lạnh', 'Quầy bar', 'Bữa sáng', 'Bữa sáng món tự chọn', 'Máy lạnh', 'Phòng không hút thuốc', 'Khu vực hút thuốc', 'Không khói thuốc', 'Trung tâm thể dục thể hình', 'Mát-xa', 'Các tiện nghi ngoài trời', 'Máy photocopy', 'Máy in', 'Đưa đón sân bay', 'Wifi (miễn phí)', 'Đưa đón sân bay (thu phí)', 'Trung tâm thể dục thể hình']
#
# id: 2614 - name: Jenny's Splendid Home - style: Eco-friendly
#  - district: Hai Bà Trưng - amenities: ['Cửa hàng', 'Dù (ô) trên bãi biển', 'Hồ bơi ngoài trời', 'Vườn hoa', 'Ghế dài tắm nắng hồ bơi', 'Hồ bơi', 'Khu vực hút thuốc', 'Bãi gửi xe (thu phí)', 'Sân thượng/sân hiên', 'OTHER', 'Nhà hàng', 'Thang máy', 'Đồ chơi', 'Hồ bơi trẻ em', 'Wifi (miễn phí)', 'Đưa đón sân bay (thu phí)', 'Cửa hàng thực phẩm']
#
# id: 1277 - name: Asean Resort - Shiki Onsen & Spa - style: Luxury
#  - district: Sơn Tây - amenities: ['Quầy bar', 'Bữa sáng', 'Bữa sáng (thu phí)', 'Nhà hàng có máy lạnh', 'Tiệm cà phê', 'Bữa tối với thực đơn chọn sẵn', 'Bữa sáng món tự chọn', 'Bữa sáng với thực đơn gọi món', 'Bữa trưa với thực đơn chọn sẵn', 'Bữa tối món tự chọn', 'Bữa tối với thực đơn gọi món', 'Tiệc liên hoan', 'Khu ẩm thực', 'Áo choàng tắm', 'Bồn tắm', 'Bàn làm việc', 'Tủ lạnh', 'Máy sấy tóc', 'Két an toàn trong phòng', 'TV', 'Phòng tắm vòi sen', 'Phòng tắm đứng và bồn tắm riêng', 'Minibar', 'Phòng gia đình', 'Khu vực hút thuốc', 'Máy lạnh', 'Phòng không hút thuốc', 'Sân thượng/sân hiên', 'Tiệc chiêu đãi', 'Phòng liên thông', 'Hồ bơi', 'Mát-xa', 'Hồ nước nóng Jacuzzi', 'Trung tâm thể dục thể hình', 'Dịch vụ spa', 'Xông hơi ướt', 'Bồn tắm nước nóng', 'Hồ bơi trong nhà', 'WiFi tại khu vực chung', 'Tiệm cà phê', 'Nhà hàng', 'Thang máy', 'Nhà hàng phục vụ bữa sáng', 'Nhà hàng phục vụ bữa trưa', 'Nhà hàng phục vụ bữa tối', 'Quần vợt', 'Sân golf', 'Trung tâm thể dục thể hình', 'Sân golf mini', 'Golf', 'Tiện nghi hội họp', 'Trung tâm dịch vụ hành chánh/văn phòng', 'Phòng hội nghị', 'Máy chiếu', 'Quầy lễ tân', 'Lễ tân 24h', 'Dịch vụ tiệc cưới', 'Người gác cửa', 'Hồ bơi trẻ em', 'Câu lạc bộ thiếu nhi', 'Phòng tắm phù hợp với xe lăn', 'Thuận tiện cho người khuyết tật', 'Wifi (miễn phí)']
#
# id: 2386 - name: Mira Housing- Vinhome Skylake Luxury Apartment - style: Luxury
#  - district: Cầu Giấy - amenities: ['Cửa hàng', 'Hồ bơi ngoài trời', 'Hồ bơi trong nhà', 'Dịch vụ spa', 'Cửa hàng', 'Dịch vụ giặt ủi', 'Dịch vụ hỗ trợ đặt Tour', 'Lễ tân 24h', 'Dịch vụ concierge/hỗ trợ khách', 'Cửa hàng lưu niệm', 'Cửa hàng thực phẩm', 'Hiệu làm tóc', 'Máy ATM/Ngân hàng', 'OTHER', 'Khu vực không hút thuốc', 'Thang máy', 'Bãi gửi xe', 'Tủ khoá', 'Gửi xe có người phục vụ (thu phí)', 'Đưa đón sân bay (thu phí)']
#
# id: 866 - name: Park Hill No.1 Apartment - style: Luxury
#  - district: Hoàng Mai - amenities: ['Bãi đậu xe', 'Tiệm cà phê', 'Thang máy', 'WiFi tại khu vực chung']
#
# id: 89 - name: Peridot Grand Luxury Boutique Hotel - style: Luxury
#  - district: Hoàn Kiếm - amenities: ['Nhân viên xách hành lý', 'Thức uống chào mừng miễn phí', 'Dịch vụ concierge/hỗ trợ khách', 'Dịch vụ thu đổi ngoại tệ', 'Người gác cửa', 'EARLY_CHECK_IN', 'Dịch vụ nhận phòng cấp tốc', 'Dịch vụ trả phòng cấp tốc', 'Quầy lễ tân', 'Lễ tân 24h', 'Bảo vệ 24 giờ', 'Dịch vụ trả phòng muộn', 'Dịch vụ giặt ủi', 'Dịch vụ phòng (có giới hạn thời gian)', 'Dịch vụ lưu trữ/bảo quản hành lý', 'Dịch vụ chăm sóc y tế', 'Điện thoại di động', 'Nhật báo tại sảnh', 'Nhật báo', 'Nhân viên gác cổng', 'Dịch vụ hỗ trợ đặt Tour', 'Dịch vụ tiệc cưới', 'Nhà hàng có máy lạnh', 'Quầy bar', 'Bữa sáng', 'Bữa sáng và bữa tối', 'Bữa sáng và bữa trưa', 'Bữa sáng món tự chọn', 'Bữa sáng (thu phí)', 'Tiệm cà phê', 'Bữa sáng kiểu Âu', 'Khu ẩm thực', 'Tiệc liên hoan', 'Bữa ăn không chứa gluten', 'Bữa sáng phục vụ món nóng', 'Câu lạc bộ đêm', 'Quầy bar bên hồ bơi', 'Bữa tối với thực đơn chọn sẵn', 'Quầy phục vụ đồ ăn nhẹ', 'Đồ ăn nhẹ', 'Thực đơn ăn kiêng', 'Phục vụ món chay', 'Trung tâm thể dục thể hình', 'Vườn hoa', 'Hồ nước nóng Jacuzzi', 'Hồ bơi trong nhà', 'Thư viện', 'Mát-xa', 'Các tiện nghi ngoài trời', 'Hồ bơi ngoài trời', 'Xông hơi ướt', 'Dịch vụ spa', 'Bồn tắm nước nóng', 'Xông hơi khô/ướt', 'Phòng xông hơi', 'Cà phê/trà tại sảnh', 'Tiệm cà phê', 'Nhận phòng sớm', 'Thang máy', 'Trả phòng muộn', 'Nhà hàng', 'Nhà hàng phục vụ bữa sáng', 'Nhà hàng phục vụ bữa tối', 'Nhà hàng phục vụ bữa trưa', 'Dịch vụ dọn phòng', 'Két an toàn', 'WiFi tại khu vực chung', 'Áo choàng tắm', 'Bồn tắm', 'Truyền hình cáp', 'Bàn làm việc', 'Đầu đĩa DVD', 'Máy sấy tóc', 'Két an toàn trong phòng', 'Minibar', 'Tủ lạnh', 'Phòng tắm đứng và bồn tắm riêng', 'Phòng tắm vòi sen', 'TV', 'Máy lạnh', 'Tiệc chiêu đãi', 'Phòng liên thông', 'Phòng gia đình', 'Lò sưởi tại sảnh', 'Máy sưởi', 'Phòng không hút thuốc', 'Hồ bơi', 'Sân thượng/Sân hiên', 'Khu vực hút thuốc', 'Sân thượng/sân hiên', 'Dịch vụ văn phòng', 'Các tiện nghi văn phòng', 'Máy tính', 'Lễ tân hội nghị', 'Phòng hội nghị', 'Tiện nghi hội họp', 'Máy photocopy', 'Máy in', 'Máy chiếu', 'Máy ATM/Ngân hàng', 'Thẩm mỹ viện', 'Cửa hàng quà tặng', 'Cửa hàng thực phẩm', 'Hiệu làm tóc', 'Giặt ủi', 'Cửa hàng', 'Siêu thị', 'Thuận tiện cho người khuyết tật', 'Phòng tắm phù hợp cho người khuyết tật', 'Chỗ đậu xe cho người khuyết tật', 'Lối đi lại cho người khuyết tật', 'Trang bị phòng phù hợp với người khuyết tật', 'Phòng tắm phù hợp với xe lăn', 'Phù hợp cho xe lăn', 'Dịch vụ cho thuê xe đạp', 'Giữ xe đạp', 'Cho thuê xe hơi', 'Nhà chứa xe', 'Bãi đậu xe an ninh', 'Điện thoại gọi quốc tế', 'Wifi (miễn phí)', 'Đưa đón sân bay (thu phí)', 'Đưa đón sân bay', 'Trung tâm thể dục thể hình', 'Giữ trẻ']
#
# id: 995 - name: Vinhomes D'Capitale Luxury Apartment 1 - style: Luxury
#  - district: Cầu Giấy - amenities: ['Dịch vụ thu đổi ngoại tệ', 'Người gác cửa', 'EARLY_CHECK_IN', 'Dịch vụ trả phòng cấp tốc', 'Dịch vụ trả phòng muộn', 'Dịch vụ giặt ủi', 'Dịch vụ phòng (có giới hạn thời gian)', 'Dịch vụ lưu trữ/bảo quản hành lý', 'Nhân viên gác cổng', 'Dịch vụ hỗ trợ đặt Tour', 'Trung tâm thể dục thể hình', 'Vườn hoa', 'Câu lạc bộ sức khoẻ', 'Hồ nước nóng Jacuzzi', 'Mát-xa', 'Các tiện nghi ngoài trời', 'Xông hơi ướt', 'Dịch vụ spa', 'Phòng xông hơi', 'Máy lạnh', 'Hội trường đa chức năng', 'Phòng gia đình', 'Lò sưởi tại sảnh', 'Phòng không hút thuốc', 'Hồ bơi', 'Khu vực hút thuốc', 'Sân thượng/sân hiên', 'Thuận tiện cho người khuyết tật', 'Phòng được trang bị phù hợp cho người khuyết tật', 'Phòng tắm phù hợp cho người khuyết tật', 'Chỗ đậu xe cho người khuyết tật', 'Trang bị phòng phù hợp với người khuyết tật', 'Phòng tắm phù hợp với xe lăn', 'Phù hợp cho xe lăn', 'Máy ATM/Ngân hàng', 'Thẩm mỹ viện', 'Cửa hàng thực phẩm', 'Hiệu làm tóc', 'Giặt ủi', 'Cửa hàng', 'Siêu thị', 'Bữa sáng', 'Tiệm cà phê', 'Bữa sáng cho người dậy sớm', 'Quầy phục vụ đồ ăn nhẹ', 'Đồ ăn nhẹ', 'Tiệm cà phê', 'Nhận phòng sớm', 'Thang máy', 'Trả phòng muộn', 'WiFi tại khu vực chung', 'Dịch vụ văn phòng', 'Máy tính', 'Phòng hội nghị', 'Tiện nghi hội họp', 'Trung tâm dịch vụ hành chánh/văn phòng', 'Trung tâm thể dục thể hình', 'Phòng trò chơi', 'Sân quần vợt ngoài trời', 'Quần vợt', 'Giữ trẻ', 'Cho phép vật nuôi', 'WiFi tại khu vực chung (thu phí)', 'Đưa đón sân bay']
#
# id: 867 - name: Armin Homes 2BR  Vinhomes Ocean Park - style: Luxury
#  - district: Quận Gia Lâm - amenities: ['Cửa hàng', 'Khu vực dã ngoại', 'Cửa hàng', 'Tiệc nướng ngoài trời', 'Hồ bơi ngoài trời', 'Cửa hàng thực phẩm', 'Hiệu làm tóc', 'Máy ATM/Ngân hàng', 'Lò sưởi tại sảnh', 'Bãi gửi xe (thu phí)', 'OTHER', 'Khu vực không hút thuốc', 'Dịch vụ hỗ trợ đặt Tour', 'Đội ngũ nhân viên đa ngôn ngữ', 'Wifi (miễn phí)', 'Đưa đón sân bay (thu phí)', 'TV']
#
# id: 681 - name: Paradise Home Xuân La - style: Luxury
#  - district: Tây Hồ - amenities: []
#
# id: 254 - name: La Passion Premium Cầu Gỗ - style: Luxury
#  - district: Hoàn Kiếm - amenities: []
#
# id: 823 - name: Flower's House - style: Luxury
#  - district: Nam Từ Liêm - amenities: ['Bữa sáng với thực đơn gọi món', 'Bữa tối với thực đơn gọi món', 'Bữa trưa với thực đơn gọi món', 'Nhà hàng có máy lạnh', 'Quầy bar', 'Bữa sáng', 'Bữa sáng và bữa tối', 'Bữa sáng và bữa trưa', 'Bữa sáng món tự chọn', 'Bữa sáng phục vụ tại bàn', 'Bữa sáng muộn', 'Bữa tối món tự chọn', 'Bữa trưa món tự chọn', 'Tiệm cà phê', 'Bữa sáng kiểu Âu', 'Khu ẩm thực', 'Bữa sáng cho người dậy sớm', 'Phục vụ bữa sáng/trưa/tối kèm thức uống', 'Phục vụ bữa sáng/trưa/tối kèm thức uống không cồn', 'Phục vụ bữa sáng/trưa/tối không kèm thức uống', 'Bữa ăn không chứa gluten', 'Bữa sáng miễn phí', 'Phục vụ bữa sáng/tối kèm đồ uống không cồn', 'Phục vụ bữa sáng/tối không kèm đồ uống', 'Bữa sáng phục vụ món nóng', 'Phục vụ bữa sáng cho người dậy muộn', 'Bữa tối với thực đơn chọn sẵn', 'Bữa trưa với thực đơn chọn sẵn', 'Quầy phục vụ đồ ăn nhẹ', 'Đồ ăn nhẹ', 'Tiệc nướng ngoài trời', 'Khu vui chơi trẻ em', 'Trung tâm thể dục thể hình', 'Vườn hoa', 'Hồ bơi nước nóng trong nhà', 'Hồ bơi trong nhà', 'Mát-xa', 'Hồ bơi ngoài trời', 'Hồ bơi ngoài trời', 'Dù (ô) che nắng', 'Ghế dài tắm nắng hồ bơi', 'Dịch vụ spa', 'Bồn tắm nước nóng', 'Xông hơi khô/ướt', 'Phòng xông hơi', 'Ghế dài tắm nắng', 'Bãi đậu xe', 'Tiệm cà phê', 'Nhận phòng sớm', 'Thang máy', 'Trả phòng muộn', 'Nhà hàng', 'Nhà hàng phục vụ bữa sáng', 'Nhà hàng phục vụ bữa tối', 'Nhà hàng phục vụ bữa trưa', 'Truyền hình cáp', 'Bàn làm việc', 'Máy sấy tóc', 'Nhà bếp mini', 'Lò vi sóng', 'Tủ lạnh', 'Phòng tắm đứng và bồn tắm riêng', 'Phòng tắm vòi sen', 'TV', 'Máy ATM/Ngân hàng', 'Thẩm mỹ viện', 'Cửa hàng quà tặng', 'Cửa hàng thực phẩm', 'Hiệu làm tóc', 'Giặt ủi', 'Cửa hàng', 'Siêu thị', 'Đưa đón sân bay', 'Cho thuê xe hơi', 'Bãi đậu xe hạn chế', 'Bãi đậu xe (thu phí)', 'Nhà chứa xe', 'Dịch vụ xe limo/xe đưa đón hạng sang', 'Bãi đậu xe an ninh', 'Máy lạnh', 'Máy sấy quần áo', 'Phòng không hút thuốc', 'Hồ bơi', 'Khu vực hút thuốc', 'Không khói thuốc', 'Sân thượng/sân hiên', 'Bóng rổ', 'Trung tâm thể dục thể hình', 'Sân quần vợt ngoài trời', 'Quần vợt lồng', 'Sân thể thao', 'Quần vợt', 'Các môn thể thao dưới nước', 'EARLY_CHECK_IN', 'Dịch vụ nhận phòng cấp tốc', 'Dịch vụ trả phòng cấp tốc', 'Bảo vệ 24 giờ', 'Dịch vụ trả phòng muộn', 'Dịch vụ giặt ủi', 'Thuận tiện cho người khuyết tật', 'Chỗ đậu xe cho người khuyết tật', 'Lối đi lại cho người khuyết tật', 'Phù hợp cho xe lăn', 'Mạng Internet cục bộ', 'Wifi (miễn phí)', 'Đưa đón sân bay (thu phí)', 'Đưa đón sân bay', 'Hồ bơi trẻ em']
#
# id: 1369 - name: Luxhome Vinhomes Skylake - style: Luxury
#  - district: Nam Từ Liêm - amenities: ['Cửa hàng', 'Dù (ô) trên bãi biển', 'Hồ bơi trong nhà', 'Vườn hoa', 'Cửa hàng', 'Thư viện', 'Hồ bơi ngoài trời', 'Dịch vụ spa', 'Trung tâm thể dục thể hình (giá ưu đãi)', 'Ghế dài tắm nắng hồ bơi', 'Sảnh lễ tân', 'Tủ khoá', 'Lò vi sóng (dùng chung)', 'Hồ bơi', 'Tủ lạnh (dùng chung)', 'Khu vực hút thuốc', 'Bãi gửi xe (thu phí)', 'Dịch vụ giặt ủi', 'Dịch vụ hỗ trợ đặt Tour', 'Dịch vụ lưu trữ/bảo quản hành lý', 'Dịch vụ trả phòng cấp tốc', 'Nhân viên gác cổng', 'Quầy lễ tân', 'OTHER', 'Nhà hàng', 'Tiệm cà phê', 'Thang máy', 'Cửa hàng lưu niệm', 'Cửa hàng thực phẩm', 'Hiệu làm tóc', 'Máy ATM/Ngân hàng', 'Dịch vụ giữ trẻ (thu phí)', 'Hồ bơi trẻ em', 'Đưa đón sân bay (thu phí)', 'TV']
#
# id: 430 - name: Căn hộ Homefromhome Metropolis - style: Luxury
#  - district: Ba Đình - amenities: ['Vườn hoa', 'Cửa hàng', 'Khu vực hút thuốc', 'Bãi gửi xe (thu phí)', 'OTHER', 'Thang máy', 'Dịch vụ giặt ủi', 'Máy ATM/Ngân hàng', 'Trung tâm thể dục thể hình']
#
# id: 2069 - name: Căn hộ Park Hill Times City - style: Luxury
#  - district: Hai Bà Trưng - amenities: ['Dịch vụ giặt ủi', 'Dịch vụ lưu trữ/bảo quản hành lý', 'Đội ngũ nhân viên đa ngôn ngữ', 'Quầy lễ tân', 'OTHER', 'Khu vực không hút thuốc', 'Thang máy', 'Vườn hoa', 'Bãi gửi xe']
#
# id: 1534 - name: Davidduc's Apartment Au Co - style: Luxury
#  - district: Tây Hồ - amenities: ['Truyền hình cáp', 'Bàn làm việc', 'Minibar', 'Phòng tắm vòi sen', 'TV', 'Bãi đậu xe', 'Dịch vụ dọn phòng', 'Wifi (miễn phí)', 'Máy lạnh', 'Dịch vụ giặt ủi']
#
# id: 11 - name: SOJO Ga Hanoi - style: Luxury
#  - district: Hoàn Kiếm - amenities: ['Áo choàng tắm', 'Truyền hình cáp', 'Bàn làm việc', 'Máy sấy tóc', 'Két an toàn trong phòng', 'Minibar', 'Phòng tắm vòi sen', 'Cà phê/trà tại sảnh', 'Nhận phòng sớm', 'Thang máy', 'Trả phòng muộn', 'Két an toàn', 'Máy lạnh', 'Phòng liên thông', 'Phòng không hút thuốc', 'Khu vực hút thuốc', 'Quầy lễ tân', 'Lễ tân 24h', 'Dịch vụ trả phòng muộn', 'Máy ATM/Ngân hàng', 'Cửa hàng', 'Quầy bar', 'Trung tâm thể dục thể hình', 'Wifi (miễn phí)', 'Trung tâm thể dục thể hình']
#
# id: 589 - name: Cara Rustic Apartment - style: Luxury
#  - district: Tây Hồ - amenities: ['Dịch vụ thu đổi ngoại tệ', 'Dịch vụ nhận phòng cấp tốc', 'Dịch vụ trả phòng cấp tốc', 'Quầy lễ tân', 'Lễ tân 24h', 'Dịch vụ giặt ủi', 'Dịch vụ lưu trữ/bảo quản hành lý', 'Dịch vụ hỗ trợ đặt Tour', 'Máy lạnh', 'Máy sấy quần áo', 'Phòng gia đình', 'Máy sưởi', 'Phòng không hút thuốc', 'Không khói thuốc', 'Sân thượng/sân hiên', 'Bàn làm việc', 'Máy sấy tóc', 'Nhà bếp mini', 'Tủ lạnh', 'Phòng tắm vòi sen', 'TV', 'Thang máy', 'WiFi tại khu vực chung', 'Cửa hàng thực phẩm', 'Cửa hàng', 'Bãi đậu xe (thu phí)', 'Đưa đón sân bay (thu phí)']
#
# id: 1566 - name: Ngoc Khanh Apartment - style: Luxury
#  - district: Ba Đình - amenities: ['Phòng tắm đứng và bồn tắm riêng', 'Phòng tắm vòi sen', 'TV', 'Wifi (miễn phí)', 'WiFi tại khu vực chung (thu phí)', 'Máy lạnh', 'Phòng không hút thuốc', 'Dịch vụ dọn phòng', 'Két an toàn']
#
# id: 2440 - name: Army - style: Luxury
#  - district: Hoàn Kiếm - amenities: ['Cho phép vật nuôi nhỏ', 'Cho phép vật nuôi lớn', 'Nhà chứa xe', 'Phòng liên thông', 'Phù hợp cho xe lăn', 'Bãi đậu xe']
#
# id: 2599 - name: Kingdom Hotel Hanoi - style: Luxury
#  - district: Hoàn Kiếm - amenities: ['Dịch vụ giặt ủi', 'Dịch vụ lưu trữ/bảo quản hành lý', 'Nhân viên gác cổng', 'Lễ tân 24h', 'Dịch vụ hỗ trợ đặt Tour', 'Sảnh lễ tân', 'Tủ khoá', 'Khu vực hút thuốc', 'Bãi gửi xe máy', 'OTHER', 'Két an toàn', 'Thang máy', 'Dịch vụ spa', 'Cửa hàng', 'Wifi (miễn phí)', 'Đưa đón sân bay (thu phí)']
#
# id: 2378 - name: Hanoi EcoStay 2 hostel - style: Eco-friendly
#  - district: Hoàn Kiếm - amenities: ['Khu vực hút thuốc', 'Sảnh lễ tân', 'Tủ khoá', 'Lò vi sóng (dùng chung)', 'Tủ lạnh (dùng chung)', 'Dịch vụ giặt ủi', 'Dịch vụ lưu trữ/bảo quản hành lý', 'Dịch vụ hỗ trợ đặt Tour', 'Wifi (miễn phí)', 'OTHER']

# %%
conn = psycopg2.connect(postgres_url)
cur = conn.cursor()

cur.execute("CREATE EXTENSION IF NOT EXISTS unaccent;")

# Set the search_path
cur.execute("""SET search_path TO travel_database, public;""")

# Tạo câu truy vấn SQL
sql= """
    SELECT DISTINCT travel_database.hotel.hotel_id, travel_database.hotel.name, travel_database.hotel.style, (travel_database.hotel.address).district AS district
    FROM travel_database.hotel
    WHERE unaccent(lower((travel_database.hotel.address).district)) ILIKE unaccent('%hai ba trung%');
"""

# Thực thi câu truy vấn
cur.execute(sql)

# Lấy tất cả các kết quả
attractions = cur.fetchall()

# In ra tên các attraction
for attraction in attractions:
    print(f"id: {attraction[0]} - name: {attraction[1]} - style: {attraction[2]} - district: {attraction[3]}\n")
# Đóng kết nối
cur.close()
conn.close()
# Out:
# id: 1 - name: Khách Sạn Ha Noi Le Grand - style: Boutique
#  - district: Hai Bà Trưng
#
# id: 36 - name: A25 Luxury Hotel - style: Luxury
#  - district: Hai Bà Trưng
#
# id: 54 - name: Chariot Hotel - style: Boutique
#  - district: Hai Bà Trưng
#
# id: 82 - name: Ohana Hotel - style: Boutique
#  - district: Hai Bà Trưng
#
# id: 113 - name: Nesta Hotel Hanoi - style: Business
#  - district: Hai Bà Trưng
#
# id: 125 - name: Midori Boutique Hotel - style: Boutique
#  - district: Hai Bà Trưng
#
# id: 136 - name: Canary Hanoi Hotel - style: Luxury
#  - district: Hai Bà Trưng
#
# id: 139 - name: The Ann Hanoi Hotel & Spa - style: Business
#  - district: Hai Bà Trưng
#
# id: 154 - name: Night Hotel - style: Business
#  - district: Hai Bà Trưng
#
# id: 158 - name: Khách Sạn Riverside Boutique - style: Luxury
#  - district: Hai Bà Trưng
#
# id: 171 - name: An Tuong Hotel - style: Boutique
#  - district: Hai Bà Trưng
#
# id: 172 - name: Halais Hotel - style: Boutique
#  - district: Hai Bà Trưng
#
# id: 180 - name: My Linh Hotel - style: Boutique
#  - district: Hai Bà Trưng
#
# id: 189 - name: Bom Homes - Vinhomes Times City - style: Business
#  - district: Hai Bà Trưng
#
# id: 194 - name: Blue Hanoi Hotel - style: Boutique
#  - district: Hai Bà Trưng
#
# id: 202 - name: The Poppy Villa & Hotel - style: Boutique
#  - district: Hai Bà Trưng
#
# id: 205 - name: Hôtel du Parc Hanoï - style: Luxury
#  - district: Hai Bà Trưng
#
# id: 251 - name: Camellia Residence Hanoi - style: Boutique
#  - district: Hai Bà Trưng
#
# id: 269 - name: Emerald Boutique Hotel - style: Boutique
#  - district: Hai Bà Trưng
#
# id: 270 - name: Sunrise Hanoi Hotel - style: Boutique
#  - district: Hai Bà Trưng
#
# id: 301 - name: Hanoi Gallant Hotel - style: Boutique
#  - district: Hai Bà Trưng
#
# id: 318 - name: Full House Times City - style: Boutique
#  - district: Hai Bà Trưng
#
# id: 340 - name: La Casa Hanoi Hotel - style: Business
#  - district: Hai Bà Trưng
#
# id: 400 - name: Parkside Sunline Hotel - style: Boutique
#  - district: Hai Bà Trưng
#
# id: 447 - name: A25 Hotel - 57 Quang Trung - style: Boutique
#  - district: Hai Bà Trưng
#
# id: 478 - name: My Hotel 23 - style: Boutique
#  - district: Hai Bà Trưng
#
# id: 504 - name: A25 Hotel - 80 Mai Hac De - style: Boutique
#  - district: Hai Bà Trưng
#
# id: 506 - name: Vinhome Time City Full Service Apartment - style: Luxury
#  - district: Hai Bà Trưng
#
# id: 527 - name: A25 Hotel - 197 Thanh Nhan - style: Adventure
#  - district: Hai Bà Trưng
#
# id: 543 - name: Eden Hanoi Hotel - style: Luxury
#  - district: Hai Bà Trưng
#
# id: 547 - name: Mercy Hotel - style: Boutique
#  - district: Hai Bà Trưng
#
# id: 548 - name: A25 Hotel - 53 Tue Tinh - style: Boutique
#  - district: Hai Bà Trưng
#
# id: 549 - name: Mia Sen Vong Hotel - style: Cultural
#  - district: Hai Bà Trưng
#
# id: 550 - name: A25 Hotel - 221 Bach Mai - style: Business
#  - district: Hai Bà Trưng
#
# id: 598 - name: Muse Hanoi Boutique Apartment - style: Boutique
#  - district: Hai Bà Trưng
#
# id: 611 - name: Nesta Boutique Hotel Ha Noi - style: Business
#  - district: Hai Bà Trưng
#
# id: 629 - name: MY House Hotel Hanoi - style: Boutique
#  - district: Hai Bà Trưng
#
# id: 700 - name: A25 Hotel - 185 Lo Duc - style: Boutique
#  - district: Hai Bà Trưng
#
# id: 726 - name: Binh Anh Hotel Hanoi - style: Boutique
#  - district: Hai Bà Trưng
#
# id: 742 - name: Bảo Ngọc Hotel Pháp Vân - style: Boutique
#  - district: Hai Bà Trưng
#
# id: 750 - name: The Gallery Homestay - By Pegasy Group - style: Boutique
#  - district: Hai Bà Trưng
#
# id: 761 - name: Hovi De Villa Trang An - style: Luxury
#  - district: Hai Bà Trưng
#
# id: 763 - name: NYNA House - Big Group - Rooftop Garden - style: Boutique
#  - district: Hai Bà Trưng
#
# id: 772 - name: Giao Thong Hotel - style: Boutique
#  - district: Hai Bà Trưng
#
# id: 802 - name: Khách sạn Vọng Xưa - style: Boutique
#  - district: Hai Bà Trưng
#
# id: 803 - name: Paradise Home Nguyễn Du - style: Luxury
#  - district: Hai Bà Trưng
#
# id: 832 - name: The Gallery Homestay - By Pegasy Group - style: Boutique
#  - district: Hai Bà Trưng
#
# id: 834 - name: Casa Amarilla Boutique Apartment - style: Boutique
#  - district: Hai Bà Trưng
#
# id: 876 - name: Bayhomes Times City Serviced Apartment - style: Luxury
#  - district: Hai Bà Trưng
#
# id: 884 - name: Grand Spring Suite - Mai Hắc Đế - style: Business
#  - district: Hai Bà Trưng
#
# id: 897 - name: Khách sạn Mỹ Lan Hà Nội - style: Business
#  - district: Hai Bà Trưng
#
# id: 929 - name: Khách sạn Adonis - style: Luxury
#  - district: Hai Bà Trưng
#
# id: 940 - name: Khách sạn Sunway - style: Luxury
#  - district: Hai Bà Trưng
#
# id: 960 - name: Cukoo House - style: Boutique
#  - district: Hai Bà Trưng
#
# id: 966 - name: Khách sạn Linh Anh - style: Boutique
#  - district: Hai Bà Trưng
#
# id: 1021 - name: The New Century- City Center- Vincom Ba Trieu - style: Boutique
#  - district: Hai Bà Trưng
#
# id: 1022 - name: My Linh Hotel - style: Boutique
#  - district: Hai Bà Trưng
#
# id: 1039 - name: T Boutique Hotel Hanoi - style: Boutique
#  - district: Hai Bà Trưng
#
# id: 1112 - name: NYNA House-Wooden Design-Rooftop Jacuzzi - style: Wellness
#  - district: Hai Bà Trưng
#
# id: 1138 - name: Khách sạn Azumaya Hai Bà Trưng 1 - style: Boutique
#  - district: Hai Bà Trưng
#
# id: 1152 - name: Cozy Homestay Hanoi - style: Boutique
#  - district: Hai Bà Trưng
#
# id: 1181 - name: Phori House Hanoi - Vinh Tuy - style: Boutique
#  - district: Hai Bà Trưng
#
# id: 1182 - name: JB Serviced Apartment - style: Luxury
#  - district: Hai Bà Trưng
#
# id: 1198 - name: Khách sạn Azumaya Hai Bà Trưng 1 - style: Boutique
#  - district: Hai Bà Trưng
#
# id: 1208 - name: Alisa Hotel - style: Boutique
#  - district: Hai Bà Trưng
#
# id: 1230 - name: JB Serviced Apartment - style: Luxury
#  - district: Hai Bà Trưng
#
# id: 1237 - name: Phori House Hanoi - Vinh Tuy - style: Boutique
#  - district: Hai Bà Trưng
#
# id: 1278 - name: NVT Housing - Vinhomes Times City Apartment Hanoi - style: Business
#  - district: Hai Bà Trưng
#
# id: 1292 - name: Full House Times City - style: Family-friendly
#  - district: Hai Bà Trưng
#
# id: 1300 - name: NYNA House SKY View Egg Coffee Class - style: Boutique
#  - district: Hai Bà Trưng
#
# id: 1327 - name: H&H Building - style: Business
#  - district: Hai Bà Trưng
#
# id: 1343 - name: May De Ville Trendy Hotel & Spa - style: Boutique
#  - district: Hai Bà Trưng
#
# id: 1377 - name: Khách sạn Calvin - style: Business
#  - district: Hai Bà Trưng
#
# id: 1453 - name: Khách sạn Á Châu - style: Boutique
#  - district: Hai Bà Trưng
#
# id: 1463 - name: May De Ville Trendy Hotel & Spa - style: Boutique
#  - district: Hai Bà Trưng
#
# id: 1471 - name: Tran Gia - Tay Ket Hotel - style: Romantic
#  - district: Hai Bà Trưng
#
# id: 1474 - name: Khách sạn Calvin - style: Business
#  - district: Hai Bà Trưng
#
# id: 1502 - name: Lavender Hotel & Apartment - style: Boutique
#  - district: Hai Bà Trưng
#
# id: 1562 - name: Hoang Gia Hotel - style: Family-friendly
#  - district: Hai Bà Trưng
#
# id: 1567 - name: Lai Minh Khai Apartment - style: Boutique
#  - district: Hai Bà Trưng
#
# id: 1602 - name: Hoang Ngoc Hotel 2 - style: Boutique
#  - district: Hai Bà Trưng
#
# id: 1626 - name: HKG - Vinhomes Time City - Park Hill - Modern apartment - style: Adventure
#  - district: Hai Bà Trưng
#
# id: 1643 - name: Vinhomes Times City Delicate Residence - style: Luxury
#  - district: Hai Bà Trưng
#
# id: 1653 - name: Vinhomes Times City 2 Bedrooms Apartment - style: Business
#  - district: Hai Bà Trưng
#
# id: 1670 - name: Viet Vuong Building Ha Noi Capital - style: Business
#  - district: Hai Bà Trưng
#
# id: 1709 - name: Scandinavian City view SunGrand City - style: Boutique
#  - district: Hai Bà Trưng
#
# id: 1728 - name: Santa Hotel I - style: None - district: Hai Bà Trưng
#
# id: 1741 - name: Scandinavian City view SunGrand City - style: Boutique
#  - district: Hai Bà Trưng
#
# id: 1766 - name: Nws Ha Noi Homes - style: Boutique
#  - district: Hai Bà Trưng
#
# id: 1806 - name: Khách sạn Green Park - style: Luxury
#  - district: Hai Bà Trưng
#
# id: 1841 - name: Hanvet Hotel Hà Nội - style: Boutique
#  - district: Hai Bà Trưng
#
# id: 1845 - name: Annie Resident - style: Boutique
#  - district: Hai Bà Trưng
#
# id: 1872 - name: Hoang Hung Hotel - style: Cultural
#  - district: Hai Bà Trưng
#
# id: 1891 - name: Apartment In Hoan Kiem - style: Boutique
#  - district: Hai Bà Trưng
#
# id: 1892 - name: Chichan House - style: Boutique
#  - district: Hai Bà Trưng
#
# id: 1961 - name: Home Fantasy No 1 - style: Boutique
#  - district: Hai Bà Trưng
#
# id: 1965 - name: Hanpro - Serviced Apartment in Park Hill - style: Business
#  - district: Hai Bà Trưng
#
# id: 1975 - name: Morning Rooms Pho Hue - style: Business
#  - district: Hai Bà Trưng
#
# id: 2004 - name: Le Grand Hotel - by Bay Luxury - style: Boutique
#  - district: Hai Bà Trưng
#
# id: 2012 - name: Le Grand Hanoi Hotel - The Central Park - style: Luxury
#  - district: Hai Bà Trưng
#
# id: 2025 - name: Le Grand Hotel - by Bay Luxury - style: Boutique
#  - district: Hai Bà Trưng
#
# id: 2031 - name: Le Grand Hanoi Hotel - The Central Park - style: Luxury
#  - district: Hai Bà Trưng
#
# id: 2043 - name: SOL Urban Villa Rooftop POOL and GYM - style: Boutique
#  - district: Hai Bà Trưng
#
# id: 2069 - name: Căn hộ Park Hill Times City - style: Luxury
#  - district: Hai Bà Trưng
#
# id: 2102 - name: Minasi Hotel & Spa - style: Boutique
#  - district: Hai Bà Trưng
#
# id: 2105 - name: Royal House - style: Boutique
#  - district: Hai Bà Trưng
#
# id: 2161 - name: Vong Xua Hotel Hanoi - style: Cultural
#  - district: Hai Bà Trưng
#
# id: 2165 - name: HKG - Vinhomes Park Hill - Luxurious - Spacious apartment in Hanoi - style: Boutique
#  - district: Hai Bà Trưng
#
# id: 2172 - name: Ilota Urban Villas Rooftop Pool - style: Boutique
#  - district: Hai Bà Trưng
#
# id: 2173 - name: 139 P. Lò Đúc - style: Boutique
#  - district: Hai Bà Trưng
#
# id: 2190 - name: Khách sạn Cherry 1 - style: Boutique
#  - district: Hai Bà Trưng
#
# id: 2193 - name: Bayhomes D'Capitale Serviced Apartment - style: Luxury
#  - district: Hai Bà Trưng
#
# id: 2212 - name: Atlanta Residences - style: Luxury
#  - district: Hai Bà Trưng
#
# id: 2220 - name: Atlanta Residences - style: Luxury
#  - district: Hai Bà Trưng
#
# id: 2223 - name: 7S Hotel Phuong Ngoc Hanoi - style: Romantic
#  - district: Hai Bà Trưng
#
# id: 2235 - name: Hoa Lu Apartment - style: Boutique
#  - district: Hai Bà Trưng
#
# id: 2255 - name: Aritex Serviced Apartment Building - style: Luxury
#  - district: Hai Bà Trưng
#
# id: 2288 - name: Le Petit Hanoi Hotel - Hang Chuoi - style: Boutique
#  - district: Hai Bà Trưng
#
# id: 2291 - name: Aloha Hanoi Homestay - style: Business
#  - district: Hai Bà Trưng
#
# id: 2293 - name: Khách sạn Thế Kỷ Mới - style: Luxury
#  - district: Hai Bà Trưng
#
# id: 2299 - name: Golden Hotel Hanoi - style: Boutique
#  - district: Hai Bà Trưng
#
# id: 2304 - name: Căn Hộ Luxury Apartment - Vinhomes Times City - style: Business
#  - district: Hai Bà Trưng
#
# id: 2335 - name: My Hotel 07 - style: Luxury
#  - district: Hai Bà Trưng
#
# id: 2405 - name: Confetti Apartment - style: Boutique
#  - district: Hai Bà Trưng
#
# id: 2411 - name: Nvt Housing - Vinhomes Time City Apartment Hanoi - style: Luxury
#  - district: Hai Bà Trưng
#
# id: 2424 - name: Nvt Housing - Vinhomes Time City Apartment Hanoi - style: Luxury
#  - district: Hai Bà Trưng
#
# id: 2427 - name: Confetti Apartment - style: Boutique
#  - district: Hai Bà Trưng
#
# id: 2453 - name: Michelle's Inn - style: Boutique
#  - district: Hai Bà Trưng
#
# id: 2469 - name: Nhà của Bu - Studio - style: Boutique
#  - district: Hai Bà Trưng
#
# id: 2539 - name: Nguyen Quyen Hotel - style: Business
#  - district: Hai Bà Trưng
#
# id: 2614 - name: Jenny's Splendid Home - style: Eco-friendly
#  - district: Hai Bà Trưng
#
# id: 2649 - name: Duy Anh - style: Boutique
#  - district: Hai Bà Trưng
#
# id: 2651 - name: Serviced Apartment in Times Center - style: Romantic
#  - district: Hai Bà Trưng
#
# id: 2657 - name: Lenid Hanoi Hotel - style: Business
#  - district: Hai Bà Trưng
#
# id: 2735 - name: A25 Hotel Bach Mai - style: Romantic
#  - district: Hai Bà Trưng
#
# id: 2745 - name: Hera Building - style: Business
#  - district: Hai Bà Trưng
#
# id: 2762 - name: Hera Building - style: Business
#  - district: Hai Bà Trưng

# %%
conn = psycopg2.connect(postgres_url)
cur = conn.cursor()

# Thiết lập search_path
cur.execute("""SET search_path TO travel_database, public;""")

# Tạo câu truy vấn SQL
sql = """
    SELECT DISTINCT travel_database.touristattraction.attraction_id, travel_database.touristattraction.name, travel_database.touristattraction.attraction_type
    FROM travel_database.touristattraction  
    JOIN travel_database.attractionprice 
        ON travel_database.touristattraction.attraction_id = travel_database.attractionprice.attraction_id 
    WHERE (travel_database.attractionprice.price > 0 OR travel_database.attractionprice.price = 0)
        AND 'Viện bảo tàng lịch sử' = ANY(travel_database.touristattraction.attraction_type);
"""

# Thực thi câu truy vấn
cur.execute(sql)

# Lấy tất cả các kết quả
attractions = cur.fetchall()

# In ra tên các attraction
for attraction in attractions:
    print(f"id: {attraction[0]} - name: {attraction[1]} - type: {attraction[2]}")

# Đóng kết nối
cur.close()
conn.close()
# Out:
# id: 2 - name: Bảo tàng Dân tộc học - type: ['Viện bảo tàng lịch sử']
# id: 7 - name: Bảo Tàng Hồ Chí Minh - type: ['Viện bảo tàng lịch sử']
# id: 9 - name: Bảo Tàng Lịch Sử Quốc Gia - type: ['Viện bảo tàng lịch sử']
# id: 10 - name: Ngôi Nhà Di Sản - type: ['Viện bảo tàng lịch sử']
# id: 19 - name: Bảo Tàng Công An Nhân Dân Việt Nam - type: ['Viện bảo tàng lịch sử']
# id: 21 - name: Bảo tàng Cách mạng Việt Nam - type: ['Viện bảo tàng lịch sử']
# id: 22 - name: Bảo tàng Nguyễn Văn Huyên - type: ['Viện bảo tàng lịch sử']
# id: 25 - name: Trung Tâm Giao Lưu Văn Hoá Phố Cổ - type: ['Viện bảo tàng lịch sử']
# id: 27 - name: Bảo Tàng Đường Hồ Chí Minh - type: ['Viện bảo tàng lịch sử']

# %%
conn = psycopg2.connect(postgres_url)
cur = conn.cursor()

# Thiết lập search_path
cur.execute("""SET search_path TO travel_database, public;""")

# Tạo câu truy vấn SQL
sql = """
    SELECT DISTINCT travel_database.touristattraction.attraction_id, travel_database.touristattraction.name, travel_database.touristattraction.attraction_type
    FROM travel_database.touristattraction  
    JOIN travel_database.attractionprice 
        ON travel_database.touristattraction.attraction_id = travel_database.attractionprice.attraction_id 
    WHERE (travel_database.attractionprice.price > 0 OR travel_database.attractionprice.price = 0)
        AND 'Viện bảo tàng lịch sử' = ANY(travel_database.touristattraction.attraction_type);
"""

# Thực thi câu truy vấn
cur.execute(sql)

# Lấy tất cả các kết quả
attractions = cur.fetchall()

# In ra tên các attraction
for attraction in attractions:
    print(f"id: {attraction[0]} - name: {attraction[1]} - type: {attraction[2]}")

# Đóng kết nối
cur.close()
conn.close()
# Out:
# id: 2 - name: Bảo tàng Dân tộc học - type: ['Viện bảo tàng lịch sử']
# id: 7 - name: Bảo Tàng Hồ Chí Minh - type: ['Viện bảo tàng lịch sử']
# id: 9 - name: Bảo Tàng Lịch Sử Quốc Gia - type: ['Viện bảo tàng lịch sử']
# id: 10 - name: Ngôi Nhà Di Sản - type: ['Viện bảo tàng lịch sử']
# id: 19 - name: Bảo Tàng Công An Nhân Dân Việt Nam - type: ['Viện bảo tàng lịch sử']
# id: 21 - name: Bảo tàng Cách mạng Việt Nam - type: ['Viện bảo tàng lịch sử']
# id: 22 - name: Bảo tàng Nguyễn Văn Huyên - type: ['Viện bảo tàng lịch sử']
# id: 25 - name: Trung Tâm Giao Lưu Văn Hoá Phố Cổ - type: ['Viện bảo tàng lịch sử']
# id: 27 - name: Bảo Tàng Đường Hồ Chí Minh - type: ['Viện bảo tàng lịch sử']

# %%
conn = psycopg2.connect(postgres_url)
cur = conn.cursor()

# Thiết lập search_path
cur.execute("""SET search_path TO travel_database, public;""")

# Tạo câu truy vấn SQL
sql = """
    SELECT DISTINCT travel_database.restaurant.res_id, travel_database.restaurant.name, travel_database.restaurant.restaurant_type, travel_database.restaurant.suitable_for, CAST(travel_database.restaurant.price_range->>'min_price' AS INTEGER), travel_database.restaurant.parking_available
    FROM travel_database.restaurant  
    WHERE CAST(travel_database.restaurant.price_range->>'min_price' AS INTEGER) >= 0 
    AND travel_database.restaurant.parking_available = TRUE
    AND 'Nhà hàng' = ANY(travel_database.restaurant.restaurant_type) 
    AND 'Ăn gia đình' = ANY(travel_database.restaurant.suitable_for);
    """

# Thực thi câu truy vấn
cur.execute(sql)

# Lấy tất cả các kết quả
attractions = cur.fetchall()

# In ra tên các attraction
for attraction in attractions:
    print(f"id: {attraction[0]} - name: {attraction[1]} - type: {attraction[2]} - suitable: {attraction[3]} - price: {attraction[4]} - parking: {attraction[5]}")

# Đóng kết nối
cur.close()
conn.close()
# Out:
# id: 2 - name: Buffet Sen - Khu Văn Hoá Ẩm Thực Sen Tây Hồ - type: ['Nhà hàng'] - suitable: ['Đãi tiệc', 'Ăn gia đình', 'Hẹn hò', 'Họp nhóm', 'Tiếp khách', 'Ăn chay', 'Buffet', 'Tiệc ngoài trời', 'Ngắm cảnh', 'Nghe nhạc'] - price: 38000 - parking: True
# id: 6 - name: Maison Vie - Nhà Hàng Kiểu Pháp - type: ['Nhà hàng'] - suitable: ['Ăn gia đình', 'Hẹn hò', 'Uống bia - Nhậu', 'Họp nhóm', 'Tiếp khách'] - price: 250000 - parking: True
# id: 8 - name: Jacksons Steakhouse Hanoi - type: ['Nhà hàng'] - suitable: ['Đãi tiệc', 'Ăn gia đình', 'Hẹn hò', 'Họp nhóm', 'Tiếp khách'] - price: 300000 - parking: True
# id: 14 - name: Salmonoid - Món Âu - Cao Bá Quát - type: ['Nhà hàng'] - suitable: ['Ăn gia đình', 'Hẹn hò', 'Họp nhóm', 'Tiếp khách'] - price: 200000 - parking: True
# id: 15 - name: Jacksons Steakhouse Hanoi - type: ['Nhà hàng'] - suitable: ['Đãi tiệc', 'Ăn gia đình', 'Hẹn hò', 'Họp nhóm', 'Tiếp khách'] - price: 300000 - parking: True
# id: 16 - name: Grille6 - Salad, Steak & Pasta - Hào Nam - type: ['Nhà hàng'] - suitable: ['Ăn gia đình', 'Hẹn hò', 'Họp nhóm'] - price: 50000 - parking: True
# id: 20 - name: Domino's Pizza - AEON Mall Long Biên - type: ['Nhà hàng'] - suitable: ['Ăn gia đình', 'Họp nhóm', 'Ăn Fastfood'] - price: 49000 - parking: True
# id: 23 - name: Sio Sushi - Lê Đại Hành - type: ['Nhà hàng'] - suitable: ['Đãi tiệc', 'Ăn gia đình', 'Hẹn hò', 'Họp nhóm'] - price: 100000 - parking: True
# id: 26 - name: KOMBO - Cơm Niêu Singapore - Lê Văn Thiêm - type: ['Nhà hàng'] - suitable: ['Đãi tiệc', 'Ăn gia đình', 'Họp nhóm'] - price: 20000 - parking: True
# id: 28 - name: KOMBO - Cơm Niêu Singapore - Nguyễn Phong Sắc - type: ['Nhà hàng'] - suitable: ['Ăn gia đình', 'Hẹn hò', 'Họp nhóm'] - price: 30000 - parking: True
# id: 31 - name: Lotteria - Cầu Giấy - type: ['Nhà hàng'] - suitable: ['Đãi tiệc', 'Ăn gia đình', 'Hẹn hò', 'Họp nhóm', 'Ăn Fastfood'] - price: 30000 - parking: True
# id: 32 - name: Lotteria - Trần Duy Hưng - type: ['Nhà hàng'] - suitable: ['Đãi tiệc', 'Ăn gia đình', 'Hẹn hò', 'Họp nhóm', 'Ăn Fastfood'] - price: 30000 - parking: True
# id: 33 - name: Lotteria - Kim Mã - type: ['Nhà hàng'] - suitable: ['Đãi tiệc', 'Ăn gia đình', 'Hẹn hò', 'Họp nhóm', 'Ăn Fastfood'] - price: 30000 - parking: True
# id: 43 - name: Daikon Foods - Restaurant & Café - type: ['Nhà hàng'] - suitable: ['Ăn gia đình', 'Hẹn hò', 'Họp nhóm', 'Tiếp khách'] - price: 17000 - parking: True
# id: 47 - name: Bánh Mỳ Bít Tết Cutisun - Long Biên - type: ['Nhà hàng'] - suitable: ['Ăn gia đình', 'Hẹn hò', 'Họp nhóm', 'Ngắm cảnh'] - price: 50000 - parking: True
# id: 49 - name: Habit BBQ - Lẩu Nướng Không Khói - type: ['Nhà hàng'] - suitable: ['Đãi tiệc', 'Ăn gia đình', 'Hẹn hò', 'Uống bia - Nhậu', 'Họp nhóm', 'Tiếp khách', 'BBQ - Món Nướng'] - price: 150000 - parking: True
# id: 58 - name: Don Chicken - Chicken & Pub - Hàng Bông - type: ['Nhà hàng'] - suitable: ['Ăn gia đình', 'Hẹn hò', 'Uống bia - Nhậu', 'Họp nhóm', 'Ăn Fastfood'] - price: 50000 - parking: True
# id: 70 - name: GoGi House - Nướng Hàn Quốc - Trung Hòa - type: ['Nhà hàng'] - suitable: ['Đãi tiệc', 'Ăn gia đình', 'Hẹn hò', 'Họp nhóm', 'Tiếp khách', 'BBQ - Món Nướng'] - price: 299000 - parking: True
# id: 76 - name: Gogi House - Nướng Hàn Quốc - Tô Hiệu - type: ['Nhà hàng'] - suitable: ['Ăn gia đình', 'Hẹn hò', 'Họp nhóm', 'BBQ - Món Nướng'] - price: 300000 - parking: True
# id: 77 - name: Moo Beef Steak II - type: ['Nhà hàng'] - suitable: ['Đãi tiệc', 'Ăn gia đình', 'Hẹn hò', 'Họp nhóm', 'Tiếp khách'] - price: 80000 - parking: True
# id: 79 - name: Yu Tang - Trà Sữa & Mỳ Đài Loan - Thái Phiên - type: ['Nhà hàng'] - suitable: ['Ăn gia đình', 'Hẹn hò', 'Họp nhóm', 'Tiếp khách', 'Ngắm cảnh'] - price: 200000 - parking: True
# id: 82 - name: Nhà Hàng 123 - Kim Mã - type: ['Nhà hàng'] - suitable: ['Ăn gia đình', 'Họp nhóm', 'Tiếp khách'] - price: 30000 - parking: True
# id: 84 - name: Khazaana 1992 - Ẩm Thực Ấn Độ - type: ['Nhà hàng'] - suitable: ['Đãi tiệc', 'Ăn gia đình', 'Hẹn hò', 'Họp nhóm', 'Tiếp khách'] - price: 80000 - parking: True
# id: 85 - name: Gà Rán KFC - Bạch Mai - type: ['Nhà hàng'] - suitable: ['Đãi tiệc', 'Ăn gia đình', 'Hẹn hò', 'Họp nhóm', 'Ăn Fastfood'] - price: 50000 - parking: True
# id: 86 - name: Gà Rán KFC - BigC Hà Nội - type: ['Nhà hàng'] - suitable: ['Ăn gia đình', 'Hẹn hò', 'Họp nhóm', 'Ăn Fastfood'] - price: 30000 - parking: True
# id: 88 - name: Gà Rán KFC - Nguyễn Thái Học - VMQ - type: ['Nhà hàng'] - suitable: ['Đãi tiệc', 'Ăn gia đình', 'Hẹn hò', 'Họp nhóm', 'Ăn Fastfood'] - price: 50000 - parking: True
# id: 91 - name: Gà Rán KFC - Hoàn Kiếm - type: ['Nhà hàng'] - suitable: ['Đãi tiệc', 'Ăn gia đình', 'Hẹn hò', 'Họp nhóm', 'Ăn Fastfood'] - price: 50000 - parking: True
# id: 92 - name: Gà Rán KFC - Nguyễn Văn Cừ - type: ['Nhà hàng'] - suitable: ['Đãi tiệc', 'Ăn gia đình', 'Hẹn hò', 'Họp nhóm', 'Ăn Fastfood'] - price: 50000 - parking: True
# id: 93 - name: Gà Rán KFC - Yên Phụ - type: ['Nhà hàng'] - suitable: ['Đãi tiệc', 'Ăn gia đình', 'Hẹn hò', 'Uống bia - Nhậu', 'Tiếp khách', 'Ăn Fastfood'] - price: 50000 - parking: True
# id: 94 - name: Gà Rán KFC - Tây Sơn - type: ['Nhà hàng'] - suitable: ['Ăn gia đình', 'Hẹn hò', 'Họp nhóm', 'Ăn Fastfood'] - price: 30000 - parking: True
# id: 102 - name: Paris Deli - Phan Chu Trinh - type: ['Nhà hàng'] - suitable: ['Đãi tiệc', 'Ăn gia đình', 'Họp nhóm', 'Tiếp khách'] - price: 100000 - parking: True
# id: 104 - name: Pizza Hut - Kim Mã - type: ['Nhà hàng'] - suitable: ['Đãi tiệc', 'Ăn gia đình', 'Hẹn hò', 'Họp nhóm', 'Ăn Fastfood'] - price: 40000 - parking: True
# id: 105 - name: Pizza Hut - Xuân Thủy - type: ['Nhà hàng'] - suitable: ['Đãi tiệc', 'Ăn gia đình', 'Hẹn hò', 'Họp nhóm', 'Ăn Fastfood'] - price: 40000 - parking: True
# id: 109 - name: Pizza Hut - Xuân La - type: ['Nhà hàng'] - suitable: ['Đãi tiệc', 'Ăn gia đình', 'Hẹn hò', 'Họp nhóm', 'Ăn Fastfood'] - price: 40000 - parking: True
# id: 113 - name: Skyline Hanoi - Gia Ngư - type: ['Nhà hàng'] - suitable: ['Đãi tiệc', 'Ăn gia đình', 'Hẹn hò', 'Họp nhóm', 'Tiếp khách', 'Ăn chay', 'Tiệc ngoài trời', 'Thư giãn', 'BBQ - Món Nướng', 'Nghe nhạc', 'Chụp hình - Quay phim'] - price: 100000 - parking: True
# id: 117 - name: Namaste Hanoi - Ẩm Thực Ấn Độ - type: ['Nhà hàng'] - suitable: ['Ăn gia đình', 'Hẹn hò', 'Họp nhóm', 'Tiếp khách'] - price: 100000 - parking: True
# id: 122 - name: Yakimono - Nướng Nhật Bản - Nguyên Hồng - type: ['Nhà hàng'] - suitable: ['Ăn gia đình', 'Hẹn hò', 'Uống bia - Nhậu', 'Họp nhóm', 'Buffet'] - price: 150000 - parking: True
# id: 128 - name: Maison Vie - Nhà Hàng Kiểu Pháp - type: ['Nhà hàng'] - suitable: ['Ăn gia đình', 'Hẹn hò', 'Uống bia - Nhậu', 'Họp nhóm', 'Tiếp khách'] - price: 250000 - parking: True
# id: 129 - name: Angelina Restaurant & Lounge - Sofitel Legend Metropole Hanoi - type: ['Nhà hàng'] - suitable: ['Đãi tiệc', 'Ăn gia đình', 'Hẹn hò', 'Họp nhóm', 'Tiếp khách'] - price: 100000 - parking: True
# id: 131 - name: Chả Cá Hà Thành - Nguyễn Văn Huyên - type: ['Nhà hàng'] - suitable: ['Ăn gia đình', 'Hẹn hò', 'Uống bia - Nhậu', 'Họp nhóm', 'Tiếp khách'] - price: 50000 - parking: True
# id: 132 - name: Bánh Tôm Hồ Tây - type: ['Nhà hàng'] - suitable: ['Đãi tiệc', 'Ăn gia đình', 'Hẹn hò', 'Uống bia - Nhậu', 'Họp nhóm', 'Tiếp khách', 'Tiệc ngoài trời', 'Ngắm cảnh', 'Du lịch', 'Nghe nhạc'] - price: 80000 - parking: True
# id: 135 - name: La Badiane - Nam Ngư - type: ['Nhà hàng'] - suitable: ['Ăn gia đình', 'Hẹn hò', 'Họp nhóm', 'Tiếp khách'] - price: 75000 - parking: True
# id: 136 - name: Hoa Viên Brauhaus - Tăng Bạt Hổ - type: ['Nhà hàng'] - suitable: ['Đãi tiệc', 'Ăn gia đình', 'Hẹn hò', 'Uống bia - Nhậu', 'Họp nhóm', 'Tiếp khách', 'Ngắm cảnh'] - price: 150000 - parking: True
# id: 138 - name: Manwah Taiwanese Hotpot - Thái Hà - type: ['Nhà hàng'] - suitable: ['Ăn gia đình', 'Hẹn hò', 'Họp nhóm', 'Tiếp khách'] - price: 390000 - parking: True
# id: 140 - name: Gumiho - Quán Nhậu Cho Các Nàng - type: ['Nhà hàng'] - suitable: ['Đãi tiệc', 'Ăn gia đình', 'Hẹn hò'] - price: 50000 - parking: True
# id: 148 - name: Al Fresco's - Pizza, Mỳ Ý, Sườn, Steak Bò Bít Tết - Trần Thái Tông - type: ['Nhà hàng'] - suitable: ['Đãi tiệc', 'Ăn gia đình', 'Hẹn hò', 'Họp nhóm', 'Ăn vặt', 'Ăn Fastfood'] - price: 150000 - parking: True
# id: 149 - name: Al Fresco's - Pizza, Mỳ Ý, Sườn, Steak Bò Bít Tết - Hoàng Ngân - type: ['Nhà hàng'] - suitable: ['Đãi tiệc', 'Ăn gia đình', 'Hẹn hò', 'Họp nhóm', 'Tiếp khách', 'Ăn Fastfood'] - price: 150000 - parking: True
# id: 157 - name: Gà Rán & Burger McDonald's - Hoàng Đạo Thúy - type: ['Nhà hàng'] - suitable: ['Ăn gia đình', 'Ăn vặt', 'Ăn Fastfood'] - price: 50000 - parking: True
# id: 168 - name: Phở 10 Lý Quốc Sư - type: ['Nhà hàng'] - suitable: ['Ăn gia đình', 'Hẹn hò', 'Họp nhóm'] - price: 50000 - parking: True
# id: 169 - name: Eureka Coffee & Fastfood - type: ['Nhà hàng'] - suitable: ['Đãi tiệc', 'Ăn gia đình', 'Hẹn hò', 'Họp nhóm', 'Tiếp khách'] - price: 40000 - parking: True
# id: 178 - name: New York Sport Bar - Món Ăn Âu & Á - Bà Triệu - type: ['Nhà hàng'] - suitable: ['Đãi tiệc', 'Ăn gia đình', 'Hẹn hò', 'Uống bia - Nhậu', 'Họp nhóm', 'Tiếp khách', 'Nghe nhạc'] - price: 50000 - parking: True
# id: 184 - name: Hutong - Hot Pot Paradise - Trần Duy Hưng - type: ['Nhà hàng'] - suitable: ['Ăn gia đình', 'Họp nhóm', 'Tiếp khách'] - price: 439000 - parking: True
# id: 192 - name: Nhà hàng 1946 - Cửa Bắc - type: ['Nhà hàng'] - suitable: ['Đãi tiệc', 'Ăn gia đình', 'Hẹn hò', 'Họp nhóm', 'Tiếp khách'] - price: 50000 - parking: True
# id: 194 - name: Season BBQ - Bà Triệu - type: ['Nhà hàng'] - suitable: ['Đãi tiệc', 'Ăn gia đình', 'Hẹn hò', 'Họp nhóm', 'Tiếp khách', 'BBQ - Món Nướng'] - price: 100000 - parking: True
# id: 195 - name: Luk Chew - Ẩm Thực HongKong - type: ['Nhà hàng'] - suitable: ['Đãi tiệc', 'Ăn gia đình', 'Hẹn hò', 'Họp nhóm', 'Tiếp khách'] - price: 50000 - parking: True
# id: 203 - name: Thái Pattaya - Phố Nướng Lẩu Thái Lan - type: ['Nhà hàng'] - suitable: ['Đãi tiệc', 'Ăn gia đình', 'Họp nhóm', 'Tiếp khách'] - price: 30000 - parking: True
# id: 204 - name: Thái Pattaya - Phố Nướng Lẩu Thái Lan - type: ['Nhà hàng'] - suitable: ['Đãi tiệc', 'Ăn gia đình', 'Họp nhóm', 'Tiếp khách'] - price: 30000 - parking: True
# id: 207 - name: Măm Măm Steak - Giảng Võ - type: ['Nhà hàng'] - suitable: ['Đãi tiệc', 'Ăn gia đình', 'Hẹn hò', 'Họp nhóm', 'Tiếp khách'] - price: 50000 - parking: True
# id: 208 - name: La Salsa - Món Âu - Xuân Diệu - type: ['Nhà hàng'] - suitable: ['Ăn gia đình', 'Hẹn hò', 'Uống bia - Nhậu', 'Họp nhóm', 'Tiếp khách'] - price: 100000 - parking: True
# id: 213 - name: Nướng Nhà Mắm - Lẩu & Nướng - type: ['Nhà hàng'] - suitable: ['Ăn gia đình', 'Hẹn hò', 'Uống bia - Nhậu', 'Họp nhóm', 'Tiếp khách'] - price: 50000 - parking: True
# id: 214 - name: La Cheminée Restaurant - Pullman Hanoi Hotel - type: ['Nhà hàng'] - suitable: ['Đãi tiệc', 'Ăn gia đình', 'Hẹn hò', 'Họp nhóm', 'Tiếp khách'] - price: 200000 - parking: True
# id: 215 - name: Voyage - Hotel Du Parc Hanoi - type: ['Nhà hàng'] - suitable: ['Đãi tiệc', 'Ăn gia đình', 'Hẹn hò', 'Tiếp khách', 'Ngắm cảnh'] - price: 200000 - parking: True
# id: 221 - name: Meat Plus - No.1 Korea Bbq - Trung Yên - type: ['Nhà hàng'] - suitable: ['Đãi tiệc', 'Ăn gia đình', 'Hẹn hò', 'BBQ - Món Nướng'] - price: 50000 - parking: True
# id: 222 - name: Meat Plus - No.1 Korea Bbq - Hồ Tây - type: ['Nhà hàng'] - suitable: ['Đãi tiệc', 'Ăn gia đình', 'Hẹn hò', 'Uống bia - Nhậu', 'Họp nhóm', 'Tiếp khách'] - price: 50000 - parking: True
# id: 223 - name: Nhà Hàng Hải Sản Lã Vọng - type: ['Nhà hàng'] - suitable: ['Đãi tiệc', 'Ăn gia đình', 'Hẹn hò', 'Họp nhóm', 'Tiếp khách', 'Buffet'] - price: 245000 - parking: True
# id: 225 - name: Tomato - Hải Sản Tươi Sống - Nguyễn Thị Định - type: ['Nhà hàng'] - suitable: ['Đãi tiệc', 'Ăn gia đình', 'Hẹn hò', 'Uống bia - Nhậu', 'Họp nhóm', 'Tiếp khách'] - price: 50000 - parking: True
# id: 226 - name: Tomato - Hải Sản Tươi Sống - Lê Văn Hưu - type: ['Nhà hàng'] - suitable: ['Ăn gia đình', 'Hẹn hò', 'Uống bia - Nhậu', 'Họp nhóm', 'Tiếp khách'] - price: 50000 - parking: True
# id: 227 - name: Lương Sơn Quán - Quan Nhân - type: ['Nhà hàng'] - suitable: ['Đãi tiệc', 'Ăn gia đình', 'Hẹn hò', 'Uống bia - Nhậu', 'Họp nhóm', 'Tiếp khách', 'Buffet', 'Ngắm cảnh', 'Du lịch', 'Chụp hình - Quay phim'] - price: 100000 - parking: True
# id: 229 - name: Khana Khazana - India Restaurant - type: ['Nhà hàng'] - suitable: ['Đãi tiệc', 'Ăn gia đình', 'Hẹn hò', 'Uống bia - Nhậu', 'Họp nhóm', 'Tiếp khách', 'Ăn chay', 'Tiệc ngoài trời', 'Ngắm cảnh'] - price: 105000 - parking: True
# id: 231 - name: The Vin Steak - Xuân Diệu - type: ['Nhà hàng'] - suitable: ['Ăn gia đình', 'Hẹn hò', 'Họp nhóm', 'Tiếp khách'] - price: 200000 - parking: True
# id: 232 - name: S&L's Diner - Ẩm Thực Mỹ - Bảo Khánh - type: ['Nhà hàng'] - suitable: ['Ăn gia đình', 'Hẹn hò', 'Họp nhóm'] - price: 70000 - parking: True
# id: 242 - name: Nhà Sàn 141 - Lẩu, Đồ Nướng & Nhậu - type: ['Nhà hàng'] - suitable: ['Đãi tiệc', 'Ăn gia đình', 'Uống bia - Nhậu', 'Họp nhóm'] - price: 100000 - parking: True
# id: 243 - name: Nhà Sàn 141 - Lẩu, Đồ Nướng & Nhậu - type: ['Nhà hàng'] - suitable: ['Đãi tiệc', 'Ăn gia đình', 'Uống bia - Nhậu', 'Họp nhóm'] - price: 100000 - parking: True
# id: 258 - name: Nhà Hàng Chay Aummee - Đồ Ăn Chay - Châu Long - type: ['Nhà hàng'] - suitable: ['Ăn chay', 'Ăn chay', 'Đãi tiệc', 'Ăn gia đình', 'Hẹn hò', 'Họp nhóm', 'Tiếp khách', 'Ăn chay', 'Du lịch'] - price: 50000 - parking: True
# id: 265 - name: Takumi-Ya Hanoi - Ẩm Thực Nhật Bản - type: ['Nhà hàng'] - suitable: ['Đãi tiệc', 'Ăn gia đình', 'Họp nhóm', 'Tiếp khách', 'BBQ - Món Nướng'] - price: 300000 - parking: True
# id: 266 - name: Highway4 - Trần Thái Tông - type: ['Nhà hàng'] - suitable: ['Đãi tiệc', 'Ăn gia đình', 'Hẹn hò', 'Họp nhóm', 'Tiếp khách'] - price: 100000 - parking: True
# id: 282 - name: Highway4 - Trần Thái Tông - type: ['Nhà hàng'] - suitable: ['Đãi tiệc', 'Ăn gia đình', 'Hẹn hò', 'Họp nhóm', 'Tiếp khách'] - price: 100000 - parking: True
# id: 290 - name: Nhà Hàng Chay Aummee - Đồ Ăn Chay - Châu Long - type: ['Nhà hàng'] - suitable: ['Ăn chay', 'Ăn chay', 'Đãi tiệc', 'Ăn gia đình', 'Hẹn hò', 'Họp nhóm', 'Tiếp khách', 'Ăn chay', 'Du lịch'] - price: 50000 - parking: True
# id: 293 - name: MiShaGi - Lẩu Nướng Nhật Bản - type: ['Nhà hàng'] - suitable: ['Đãi tiệc', 'Ăn gia đình', 'Hẹn hò', 'Họp nhóm', 'Tiếp khách', 'BBQ - Món Nướng'] - price: 50000 - parking: True
# id: 295 - name: Góc Hà Nội - Ẩm Thực Hà Thành - type: ['Nhà hàng'] - suitable: ['Ăn gia đình', 'Uống bia - Nhậu', 'Họp nhóm', 'Tiếp khách'] - price: 35000 - parking: True
# id: 299 - name: Shamoji Robata Yaki - Xuân Diệu - type: ['Nhà hàng'] - suitable: ['Ăn gia đình', 'Hẹn hò', 'Họp nhóm', 'Tiếp khách'] - price: 50000 - parking: True
# id: 302 - name: San Hô - Hải Sản Tươi Sống - type: ['Nhà hàng'] - suitable: ['Đãi tiệc', 'Ăn gia đình', 'Hẹn hò', 'Họp nhóm', 'Tiếp khách'] - price: 500000 - parking: True
# id: 304 - name: Gimbap Shochu - Ẩm Thực Hàn Quốc - type: ['Nhà hàng'] - suitable: ['Ăn gia đình', 'Hẹn hò', 'Họp nhóm', 'Tiếp khách'] - price: 80000 - parking: True
# id: 309 - name: Mirai - Sushi & Sake - type: ['Nhà hàng'] - suitable: ['Đãi tiệc', 'Ăn gia đình', 'Hẹn hò', 'Họp nhóm', 'Tiếp khách'] - price: 100000 - parking: True
# id: 310 - name: Vua Chả Cá - Nguyễn Thị Định - type: ['Nhà hàng'] - suitable: ['Đãi tiệc', 'Ăn gia đình', 'Hẹn hò', 'Họp nhóm', 'Tiếp khách', 'Ngắm cảnh', 'Du lịch'] - price: 100000 - parking: True
# id: 311 - name: Vua Chả Cá - Trần Hưng Đạo - type: ['Nhà hàng'] - suitable: ['Ăn gia đình', 'Họp nhóm', 'Tiếp khách'] - price: 129000 - parking: True
# id: 312 - name: Vua Chả Cá - Mai Hắc Đế - type: ['Nhà hàng'] - suitable: ['Ăn gia đình', 'Uống bia - Nhậu', 'Họp nhóm', 'Tiếp khách'] - price: 129000 - parking: True
# id: 315 - name: Nhà Hàng Ngon - Trần Hưng Đạo - type: ['Nhà hàng'] - suitable: ['Ăn gia đình', 'Hẹn hò', 'Họp nhóm', 'Tiếp khách'] - price: 80000 - parking: True
# id: 316 - name: Paku Paku - Japanese Restaurant - type: ['Nhà hàng'] - suitable: ['Ăn gia đình', 'Tiếp khách'] - price: 20000 - parking: True
# id: 326 - name: De Chang Kưm - Ẩm thực Hàn Quốc - type: ['Nhà hàng'] - suitable: ['Ăn gia đình', 'Hẹn hò', 'Họp nhóm', 'Tiếp khách'] - price: 100000 - parking: True
# id: 520 - name: Joma Bakery Cafe - Liễu Giai - type: ['Café/Dessert', 'Tiệm bánh', 'Nhà hàng'] - suitable: ['Ăn gia đình', 'Hẹn hò', 'Họp nhóm', 'Tiếp khách', 'Thư giãn', 'Ăn vặt', 'Ngắm cảnh', 'Ăn Fastfood'] - price: 30000 - parking: True

# %%
def get_embedding(text):
    """Trả về embedding của văn bản sử dụng mô hình SentenceTransformer."""
    embedding = model.encode(text)
    return embedding.tolist()

# %% [markdown]
# #### Others way to query (not finish yet)

# %%
# def build_sql_query(table, requirements, schema="travel_database"):
#     conditions = []
#     joins = ""
    
#     # Define the ID column based on the table
#     id_column = "id"
#     if table == "hotel":
#         id_column = "hotel_id"
#     elif table == "restaurant":
#         id_column = "res_id"
#     elif table == "touristattraction":
#         id_column = "attraction_id"
    
#     # Correctly access Price_range
#     price_range = requirements.get("General", {}).get("Price_range")
    
#     # Apply Price_range filters with JOIN if applicable
#     if price_range:
#         if table == "hotel":
#             joins += f" JOIN {schema}.hotelprice ON {schema}.hotel.hotel_id = {schema}.hotelprice.hotel_id"
#             if price_range == "low":
#                 conditions.append(f"{schema}.hotelprice.price < 500000")
#             elif price_range == "medium":
#                 conditions.append(f"{schema}.hotelprice.price BETWEEN 500000 AND 2000000")
#             elif price_range == "high":
#                 conditions.append(f"{schema}.hotelprice.price > 2000000")
#         elif table == "restaurant":
#             if price_range == "low":
#                 conditions.append(f"CAST({schema}.restaurant.price_range->>'max' AS INTEGER) < 200000")
#             elif price_range == "medium":
#                 conditions.append(f"CAST({schema}.restaurant.price_range->>'min' AS INTEGER) >= 200000 AND CAST({schema}.restaurant.price_range->>'max' AS INTEGER) <= 600000")
#             elif price_range == "high":
#                 conditions.append(f"CAST({schema}.restaurant.price_range->>'min' AS INTEGER) > 600000")
#         elif table == "touristattraction":
#             joins += f" JOIN {schema}.attractionprice ON {schema}.touristattraction.attraction_id = {schema}.attractionprice.attraction_id"
#             if price_range == "low":
#                 conditions.append(f"{schema}.attractionprice.price < 500000")
#             elif price_range == "medium":
#                 conditions.append(f"{schema}.attractionprice.price BETWEEN 500000 AND 1500000")
#             elif price_range == "high":
#                 conditions.append(f"{schema}.attractionprice.price > 1500000")

#     # Process specific requirements for each table
#     table_requirements = requirements.get(table.capitalize(), {})
    
#     if table == "hotel":
#         if table_requirements.get("Amenities"):
#             amenities_condition = " OR ".join([f"'{amenity}' = ANY({schema}.hotel.amenities)" for amenity in table_requirements["Amenities"]])
#             conditions.append(f"({amenities_condition})")
#         if table_requirements.get("Style") and table_requirements["Style"] != "none":
#             conditions.append(f"{schema}.hotel.style = '{table_requirements['Style']}'")
#     elif table == "restaurant":
#         if table_requirements.get("Restaurant_Type"):
#             conditions.append(f"'{table_requirements['Restaurant_Type']}' = ANY({schema}.restaurant.restaurant_type)")
#         if table_requirements.get("Suitable_For"):
#             conditions.append(f"'{table_requirements['Suitable_For']}' = ANY({schema}.restaurant.suitable_for)")
#     elif table == "touristattraction":
#         if table_requirements.get("Attraction_Type"):
#             conditions.append(f"'{table_requirements['Attraction_Type']}' = ANY({schema}.touristattraction.attraction_type)")

#     # Debugging output for conditions
#     # print("Conditions:", conditions)  # This can be commented out or logged

#     # Build the WHERE clause and complete query
#     where_clause = " AND ".join(conditions)
#     query = (
#         f"SELECT {schema}.{table}.{id_column}, {schema}.{table}.name "
#         f"FROM {schema}.{table} {joins} WHERE {where_clause};"
#         if conditions else
#         f"SELECT {schema}.{table}.{id_column}, {schema}.{table}.name FROM {schema}.{table};"
#     )

#     return query

# %%
# hotel_query = build_sql_query("hotel", update_requires_respond)
# restaurant_query = build_sql_query("restaurant", update_requires_respond)
# attraction_query = build_sql_query("touristattraction", update_requires_respond)

# hotel_locations = fetch_locations(hotel_query)
# restaurant_locations = fetch_locations(restaurant_query)
# attraction_locations = fetch_locations(attraction_query)

# # In ra danh sách các địa điểm để kiểm tra
# print("Hotel Locations:", hotel_locations)
# print("Restaurant Locations:", restaurant_locations)
# print("Tourist Attraction Locations:", attraction_locations)
