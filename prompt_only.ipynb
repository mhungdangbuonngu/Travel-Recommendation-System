# %% [markdown]
# ### Set up

# %%
# !pip install -q langchain
# !pip install -q langchain_community
# !pip install -q sentence-transformers
# !pip install -qU langchain-google-genai
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.6/50.6 kB 479.1 kB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 13.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 407.7/407.7 kB 9.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 296.7/296.7 kB 8.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 76.4/76.4 kB 3.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.0/78.0 kB 3.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 144.5/144.5 kB 5.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.5/54.5 kB 1.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 1.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.4/2.4 MB 26.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.5/49.5 kB 2.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 255.2/255.2 kB 3.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40.4/40.4 kB 1.5 MB/s eta 0:00:00

# %%
from langchain_core.prompts import ChatPromptTemplate
from sentence_transformers import SentenceTransformer
from langchain_google_genai import ChatGoogleGenerativeAI
import re
import json
import subprocess
import time
import threading
import psycopg2
import pandas as pd
import numpy as np
from sklearn.preprocessing import MultiLabelBinarizer
from sklearn.metrics.pairwise import cosine_similarity
from sklearn.preprocessing import MinMaxScaler
# Out:
# /usr/local/lib/python3.10/dist-packages/sentence_transformers/cross_encoder/CrossEncoder.py:13: TqdmExperimentalWarning: Using `tqdm.autonotebook.tqdm` in notebook mode. Use `tqdm.tqdm` instead to force console mode (e.g. in jupyter console)
#   from tqdm.autonotebook import tqdm, trange

# %%
import getpass
import os

postgres_url = "postgresql://public_owner:7CBm0fdOPkgz@ep-sweet-field-a1urmrzw.ap-southeast-1.aws.neon.tech/public?sslmode=require"

# %%
model = SentenceTransformer('bkai-foundation-models/vietnamese-bi-encoder')
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:89: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# modules.json:   0%|          | 0.00/229 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/123 [00:00<?, ?B/s]
# README.md:   0%|          | 0.00/6.46k [00:00<?, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/777 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/540M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/1.17k [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/895k [00:00<?, ?B/s]
# bpe.codes:   0%|          | 0.00/1.14M [00:00<?, ?B/s]
# added_tokens.json:   0%|          | 0.00/22.0 [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/167 [00:00<?, ?B/s]
# 1_Pooling/config.json:   0%|          | 0.00/270 [00:00<?, ?B/s]

# %% [markdown]
# ### Gemini

# %%
os.environ["GOOGLE_API_KEY"] = "AIzaSyB1rDWcTNFLJG83QEnI4_2ghFrKr-gjx2g"

# %%
llm = ChatGoogleGenerativeAI(
    model="gemini-1.5-flash",
    temperature=0,
    max_tokens=None,
    timeout=None,
    max_retries=2,
)

# %% [markdown]
# ### Query

# %% [markdown]
# #### Get features

# %% [markdown]
# ##### Hotels

# %%
# amenities
conn = psycopg2.connect(postgres_url)
cur = conn.cursor()

cur.execute("SET search_path TO travel_database, public;")

cur.execute("""
    SELECT DISTINCT unnest(amenities) AS unique_amenities
    FROM hotel;
""")

rows = cur.fetchall()

cur.close()
conn.close()

amenities_list = [row[0] for row in rows]
amenities_list_str = "\n    ".join(f'"{amenities_type}"' for amenities_type in amenities_list)
print(amenities_list_str)
# Out:
# "WiFi tại khu vực chung"
#     "Money changer"
#     "Bathtub"
#     "Tiện nghi cho trẻ"
#     "Quầy bar bên hồ bơi"
#     "Heater"
#     "Dù (ô) che nắng"
#     "Đưa đón đến khu trượt tuyết (thu phí)"
#     "Tiện nghi hội họp"
#     "Sân quần vợt ngoài trời"
#     "Trung tâm chăm sóc trẻ em"
#     "Roll-in shower"
#     "Vegetarian meal"
#     "Hồ bơi"
#     "Tủ lạnh (dùng chung)"
#     "Máy photocopy"
#     "Giữ trẻ"
#     "Porter"
#     "Bicycle storage"
#     "Dịch vụ cho thuê xe đạp"
#     "Conference room"
#     "Dịch vụ trông trẻ có người giám hộ"
#     "Grocery"
#     "Giặt ủi"
#     "Dịch vụ phòng 24 giờ"
#     "Lò vi sóng"
#     "Express check-out"
#     "Đưa đón sân bay"
#     "AC"
#     "Dịch vụ phòng (có giới hạn thời gian)"
#     "Bóng quần"
#     "TV lounge"
#     "A la carte lunch"
#     "Bồn tắm nước nóng"
#     "Gói cầu hôn lãng mạn"
#     "Safety deposit box"
#     "Vườn thú bán hoang dã"
#     "Hồ bơi trẻ em"
#     "Ghế dài tắm nắng"
#     "Đưa đón đến trạm xe buýt (thu phí)"
#     "Wifi (miễn phí)"
#     "Thẩm mỹ viện"
#     "Bữa trưa món tự chọn"
#     "Đồ chơi"
#     "Phòng tắm vòi sen"
#     "Khu thể thao dưới nước"
#     "Nhà hàng có trình diễn nấu ăn"
#     "Breakfast and lunch"
#     "Bàn tập golf"
#     "Bóng ném"
#     "Lò sưởi tại sảnh"
#     "Beauty salon"
#     "Airport transfer"
#     "Ghế cho trẻ em"
#     "Phòng hội nghị"
#     "Cửa hàng quà tặng"
#     "Quầy lễ tân"
#     "Tiệm cà phê"
#     "Nhà hàng phục vụ bữa sáng"
#     "Buffet breakfast"
#     "Các tiện nghi văn phòng"
#     "Nhật báo tại sảnh"
#     "Dịch vụ lưu trữ/bảo quản hành lý"
#     "Connecting rooms"
#     "Tủ lạnh"
#     "Sân golf"
#     "Câu cá"
#     "Shower"
#     "Trò chơi trẻ em"
#     "Sân tennis"
#     "Máy sưởi"
#     "Phòng tắm phù hợp với xe lăn"
#     "Snack bar"
#     "Trung tâm thể dục thể hình"
#     "Bãi đậu xe"
#     "Bóng chuyền"
#     "Nhận phòng sớm"
#     "Winery"
#     "Ghế dài tắm nắng hồ bơi"
#     "Barbecue"
#     "Bữa sáng"
#     "Bar"
#     "Sân thượng/Sân hiên"
#     "Garage"
#     "Cloakroom"
#     "Chương trình giải trí cho trẻ em"
#     "Bữa sáng phục vụ món nóng"
#     "Minibar"
#     "Đưa đón đến công viên chủ đề"
#     "Tiệc liên hoan"
#     "Nhà máy rượu vang"
#     "Trượt tuyết"
#     "Điểm truy cập Internet"
#     "Microwave"
#     "Bãi gửi xe (thu phí)"
#     "Đưa đón trong khu vực"
#     "Xe đưa đón bến phà (thu phí)"
#     "Trả phòng muộn"
#     "Nhà bếp mini"
#     "Thuyền buồm hai thân"
#     "Room service"
#     "Nhà hàng phục vụ bữa trưa"
#     "Sân thượng/sân hiên"
#     "Lướt ván buồm"
#     "Máy sấy quần áo"
#     "Mát-xa"
#     "Khu vui chơi trẻ em"
#     "Lướt sóng"
#     "Lễ tân 24h"
#     "Mạng Internet cục bộ"
#     "A la carte breakfast"
#     "Access friendly"
#     "Xông hơi ướt"
#     "Breakfast restaurant"
#     "TV"
#     "Cho phép vật nuôi lớn"
#     "Early check-in"
#     "Set menu lunch"
#     "Dịch vụ spa"
#     "Phòng giải trí"
#     "ATM/Banking"
#     "Đường trượt nước"
#     "Dịch vụ giặt ủi"
#     "Parking with surcharge"
#     "Dịch vụ trả phòng cấp tốc"
#     "Khu vực không hút thuốc"
#     "Coffee/tea in lobby"
#     "Thực đơn ăn kiêng"
#     "Đường chơi bowling"
#     "Bảng chỉ dẫn nổi hoặc chữ nổi"
#     "Phòng xông hơi"
#     "Bữa ăn không chứa gluten"
#     "Mô-tô nước"
#     "Late check-out"
#     "Smoking area"
#     "Phòng trò chơi"
#     "Computer station"
#     "Clothes dryer"
#     "Câu lạc bộ đêm"
#     "Lunch restaurant"
#     "Hội trường đa chức năng"
#     "Bãi đậu xe (thu phí)"
#     "Restaurant"
#     "Phục vụ bữa sáng/trưa/tối không kèm thức uống"
#     "Sự kiện giới thiệu rượu"
#     "Spa"
#     "24-hour Receptionist"
#     "Đưa đón sân bay (thu phí)"
#     "Business center"
#     "Két an toàn trong phòng"
#     "Bữa tối với thực đơn gọi món"
#     "Bóng rổ"
#     "Máy chiếu"
#     "Lò vi sóng (dùng chung)"
#     "Breakfast"
#     "Đưa đón đến công viên chủ đề (thu phí)"
#     "Massage"
#     "LAN Internet"
#     "Limited hours room service"
#     "Cho phép vật nuôi"
#     "Front desk"
#     "Separate shower and tub"
#     "Parasol"
#     "Khu vực dã ngoại"
#     "24-hour security"
#     "Khu vực hút thuốc"
#     "Các môn thể thao dưới nước"
#     "Train station pickup"
#     "Wifi (thu phí)"
#     "Nhân viên xách hành lý"
#     "Tủ khoá"
#     "24-hour room service"
#     "Người gác cửa"
#     "WiFi in public area with surcharge"
#     "Hồ nước nóng Jacuzzi"
#     "Câu lạc bộ golf"
#     "Braille or raised signage"
#     "Cửa hàng"
#     "In-room safe"
#     "Concierge"
#     "Xe đưa đón sòng bạc (thu phí)"
#     "Cưỡi ngựa"
#     "Luggage storage"
#     "Máy ATM/Ngân hàng"
#     "Phòng xem TV"
#     "Giữ & chăm sóc trẻ (thu phí)"
#     "Quầy phục vụ đồ ăn nhẹ"
#     "Shops"
#     "Ferry terminal shuttle with surcharge"
#     "Máy tính"
#     "Truyền hình cáp"
#     "In-room accessibility"
#     "Ghế dài tắm nắng bãi biển"
#     "Bồn tắm"
#     "Terrace on rooftop"
#     "Siêu thị"
#     "Lặn biển"
#     "Phòng tắm đứng và bồn tắm riêng"
#     "Cho thuê xe hơi"
#     "Doorman"
#     "Hồ bơi trong nhà"
#     "Multilingual staff"
#     "Newspaper"
#     "Bàn ủi"
#     "Xông hơi khô/ướt"
#     "Sân thể thao"
#     "Đưa đón bãi biển"
#     "Quầy bar cạnh hồ bơi"
#     "Wedding service"
#     "Family room"
#     "Bãi gửi xe máy"
#     "Hair salon"
#     "Đội ngũ nhân viên đa ngôn ngữ"
#     "Đón khách tại ga tàu"
#     "Babysitting"
#     "Kitchenette"
#     "Thuyền buồm"
#     "Đồ ăn nhẹ"
#     "Bữa tối với thực đơn chọn sẵn"
#     "Lều trên bãi biển"
#     "Dịch vụ hỗ trợ đặt Tour"
#     "Điện thoại gọi quốc tế"
#     "Phòng được trang bị phù hợp cho người khuyết tật"
#     "Đưa đón bến phà"
#     "Desk"
#     "Nhà lều bên hồ bơi"
#     "Sân golf mini"
#     "Dinner restaurant"
#     "Thang máy"
#     "Quần vợt lồng"
#     "Library"
#     "Bi gỗ"
#     "Fitness center"
#     "Phục vụ bữa sáng cho người dậy muộn"
#     "Hồ bơi nước nóng ngoài trời"
#     "Nhà hàng có máy lạnh"
#     "Dining area"
#     "Dịch vụ giữ trẻ (thu phí)"
#     "Câu lạc bộ thiếu nhi (thu phí)"
#     "Xe đưa đón bến du thuyền"
#     "Bắn cung"
#     "Sân quần vợt trong nhà"
#     "Welcoming drinks"
#     "Phục vụ bữa sáng/tối không kèm đồ uống"
#     "Cafe"
#     "Nhà hát"
#     "Sân tập golf"
#     "Smoke free"
#     "Dịch vụ thu đổi ngoại tệ"
#     "Babysitting with surcharge"
#     "Thư viện"
#     "Điện thoại di động"
#     "Chèo thuyền"
#     "Chương trình giải trí cho người lớn"
#     "Hiệu làm tóc"
#     "Non-smoking room"
#     "Lướt ván nước"
#     "Nhà hàng"
#     "Thuận tiện cho người khuyết tật"
#     "Bãi đậu xe buýt/xe tải"
#     "Phòng gia đình"
#     "OTHER"
#     "Airport transfer with surcharge"
#     "Fitness"
#     "Phòng họp"
#     "Elevator"
#     "Tiệc nướng ngoài trời"
#     "Bicycle rental"
#     "Free WiFi"
#     "Bãi biển riêng"
#     "Đưa đón đến khu trượt tuyết"
#     "Trung tâm thể dục thể hình (giá ưu đãi)"
#     "Accessible bathroom"
#     "Sảnh lễ tân"
#     "Express check-in"
#     "Thuyền đạp nước"
#     "Nơi bảo quản dụng cụ trượt tuyết"
#     "Phao chuối"
#     "Khu ẩm thực"
#     "Nhật báo"
#     "Vườn hoa"
#     "Công viên nước (thu phí vào cổng)"
#     "Early Check-in"
#     "Breakfast served to the table"
#     "Dịch vụ nhận phòng cấp tốc"
#     "Hairdryer"
#     "Xe đưa đón sòng bạc"
#     "Dịch vụ văn phòng"
#     "Đưa đón trong khu vực (thu phí)"
#     "Phục vụ bữa sáng/trưa/tối kèm thức uống"
#     "Quần vợt"
#     "Hồ bơi nước nóng trong nhà"
#     "Bãi gửi xe"
#     "Dịch vụ tiệc cưới"
#     "PRINTER"
#     "Trang bị phòng phù hợp với người khuyết tật"
#     "Đầu đĩa DVD"
#     "Cà phê/trà tại sảnh"
#     "Breakfast and dinner"
#     "Khăn tắm biển"
#     "Tours"
#     "Máy lạnh"
#     "Photocopier"
#     "Bữa sáng cho người dậy sớm"
#     "Bãi đậu xe có người phục vụ"
#     "Quầy bar"
#     "Parking"
#     "Bữa sáng và bữa trưa"
#     "Dịch vụ chăm sóc y tế"
#     "Tiệc chiêu đãi"
#     "Bữa sáng món tự chọn"
#     "Phù hợp cho xe lăn"
#     "Nhà hàng phục vụ bữa tối"
#     "Bãi đậu xe hạn chế"
#     "Medical service"
#     "Area shuttle with surcharge"
#     "Giữ xe đạp"
#     "Bàn bi-da"
#     "Máy sấy tóc"
#     "Các tiện nghi ngoài trời"
#     "Accessible path of travel"
#     "Câu lạc bộ thiếu nhi"
#     "Car rental"
#     "Nhà tắm kiểu Thổ"
#     "Cruise shuttle with surcharge"
#     "Refrigerator"
#     "Đưa đón đến trung tâm mua sắm (thu phí)"
#     "Phòng liên thông"
#     "Đưa đón đến trung tâm thương mại"
#     "Cable TV"
#     "Laundry service"
#     "Bữa sáng (thu phí)"
#     "Câu lạc bộ sức khoẻ"
#     "Restaurant with AC"
#     "Phòng giữ đồ"
#     "Dịch vụ trả phòng muộn"
#     "WiFi in public area"
#     "Lễ tân hội nghị"
#     "Buồng tắm nắng"
#     "Wheelchair accessible"
#     "Valet parking"
#     "Internet point"
#     "Khu sinh hoạt cộng đồng"
#     "Trung tâm Hội nghị"
#     "Áo choàng tắm"
#     "Xe đạp địa hình"
#     "Early bird breakfast"
#     "Không khói thuốc"
#     "A la carte dinner"
#     "Secure parking"
#     "Bữa sáng và bữa tối"
#     "Bữa sáng phục vụ tại bàn"
#     "Dịch vụ concierge/hỗ trợ khách"
#     "Bữa tối món tự chọn"
#     "Du ngoạn trên thuyền máy"
#     "Golf"
#     "Xe đưa đón bến du thuyền (thu phí)"
#     "Két an toàn"
#     "Trung tâm dịch vụ hành chánh/văn phòng"
#     "Phi tiêu"
#     "Phòng tắm phù hợp cho người khuyết tật"
#     "Mobile"
#     "Supermarket"
#     "Bữa trưa với thực đơn chọn sẵn"
#     "Đưa đón đến ga xe lửa (thu phí)"
#     "Xe golf"
#     "Bữa trưa với thực đơn gọi món"
#     "Limo or town car service"
#     "Gửi xe có người phục vụ (thu phí)"
#     "EARLY_CHECK_IN"
#     "Phục vụ bữa sáng/tối kèm đồ uống không cồn"
#     "Newspaper in lobby"
#     "Cho phép vật nuôi nhỏ"
#     "Karaoke"
#     "Bóng chuyền bãi biển"
#     "Nhà chứa xe"
#     "Phục vụ bữa sáng/trưa/tối kèm thức uống không cồn"
#     "Laundry"
#     "Dù (ô) trên bãi biển"
#     "Bãi đậu xe an ninh"
#     "Cửa hàng thực phẩm"
#     "Business facilities"
#     "Bathrobe"
#     "Bữa sáng muộn"
#     "Bữa sáng miễn phí"
#     "Bóng bàn"
#     "Thức uống chào mừng miễn phí"
#     "Sòng bạc"
#     "Mạng Internet cục bộ (thu phí)"
#     "Nhân viên gác cổng"
#     "Lối đi lại cho người khuyết tật"
#     "Snacks"
#     "Bữa sáng kiểu Âu"
#     "Không phục vụ đồ uống có cồn"
#     "Show cooking restaurant"
#     "Hồ bơi ngoài trời"
#     "Set menu dinner"
#     "Coffee shop"
#     "Bellhop"
#     "Bảo vệ 24 giờ"
#     "Phòng không hút thuốc"
#     "Fireplace in lobby"
#     "Chỗ đậu xe cho người khuyết tật"
#     "Công viên nước"
#     "Phục vụ món chay"
#     "Highchairs"
#     "WiFi tại khu vực chung (thu phí)"
#     "Breakfast with surcharge"
#     "Bữa sáng với thực đơn gọi món"
#     "Trung tâm thể dục thẩm mỹ"
#     "Bàn làm việc"
#     "Gala dinner"
#     "Terrace"
#     "Dịch vụ dọn phòng"
#     "CRIBS"
#     "Accessible parking"
#     "Dịch vụ xe limo/xe đưa đón hạng sang"
#     "Fullboard with drinks"
#     "Máy in"
#     "Motor boat ride"
#     "Gift shop"
#     "Cầu lông"
#     "Cửa hàng lưu niệm"

# %%
# style
conn = psycopg2.connect(postgres_url)
cur = conn.cursor()

cur.execute("SET search_path TO travel_database, public;")

cur.execute("""
    SELECT DISTINCT style
    FROM hotel
    WHERE style IS NOT NULL;
""")

rows = cur.fetchall()

cur.close()
conn.close()
style_list = [row[0] for row in rows]
style_list_str = "\n    ".join(f'"{style}"' for style in style_list)
print(style_list_str)
# Out:
# "Business
# "
#     "Adventure
# "
#     "Romantic
# "
#     "Eco-friendly
# "
#     "Business
# "
#     "Wellness
# "
#     "Family-friendly
# "
#     "Cultural
# "
#     "Romantic
# "
#     "Beachfront
# "
#     "Luxury
# "
#     "Boutique
# "
#     "Eco-friendly
# "
#     "Adventure
# "
#     "Family-friendly
# "
#     "Boutique
# "
#     "Cultural
# "
#     "Wellness
# "
#     "Luxury
# "

# %% [markdown]
# ##### Attractions

# %%
# types
conn = psycopg2.connect(postgres_url)
cur = conn.cursor()

cur.execute("SET search_path TO travel_database, public;")

cur.execute("""
    SELECT DISTINCT unnest(attraction_type) AS unique_attraction_type
    FROM touristattraction;
""")

rows = cur.fetchall()

cur.close()
conn.close()

att_type_list = [row[0] for row in rows]
att_type_list_str = "\n    ".join(f'"{att_type}"' for att_type in att_type_list)
print(att_type_list_str)
# Out:
# "Nhà hát và biểu diễn"
#     "Viện bảo tàng lịch sử"
#     "Thủy cung"
#     "Khu vực đi dạo tham quan di tích lịch sử"
#     "Trường đại học và trường học"
#     "Quán bar và câu lạc bộ"
#     "Khu vực đi dạo ngắm cảnh"
#     "Viện bảo tàng nghệ thuật"
#     "Vườn"
#     "Di tích cổ"
#     "Nhà thờ và nhà thờ lớn"
#     "ATV và xe địa hình"
#     "Đài kỷ niệm và tượng"
#     "Cầu"
#     "Xưởng vẽ và làm đồ gốm"
#     "Chuyến tham quan văn hóa"
#     "Núi"
#     "Địa điểm giáo dục"
#     "Khu liên hợp thể thao"
#     "Buổi học và hội thảo"
#     "Cửa hàng đồ cổ"
#     "Sân gôn"
#     "Triển lãm"
#     "Đấu trường và sân vận động"
#     "Phòng trưng bày nghệ thuật"
#     "Điểm thu hút khách tham quan và thắng cảnh"
#     "Địa điểm tâm linh"
#     "Chợ hoa"
#     "Cửa hàng của nhà máy"
#     "Trung tâm nghệ thuật"
#     "Quán bar rượu vang"
#     "Căn cứ và doanh trại quân đội"
#     "Địa điểm lịch sử"
#     "Công viên nước"
#     "Chuyến tham quan cà phê và trà"
#     "Nhà hát"
#     "Trung tâm trò chơi và giải trí"
#     "Bảo tàng dành cho trẻ em"
#     "Viện bảo tàng quân đội"
#     "Bãi biển"
#     "Chuyến tham quan mua sắm"
#     "Địa điểm tôn giáo"
#     "Trò chơi giải thoát"
#     "Đường đua ô tô"
#     "Chuyến tham quan tư nhân"
#     "Trung tâm hành chính"
#     "Sự kiện văn hóa"
#     "Cửa hàng đặc sản"
#     "Địa điểm tôn giáo"
#     "Đài và tháp quan sát"
#     "Hình thái địa chất"
#     "Chợ trời"
#     "Cửa hàng đồ cổ"
#     "Sở thú"
#     "Vùng nước"
#     "Đài tháp quan sát"
#     "Viện bảo tàng nghệ thuật"
#     "Viện bảo tàng khoa học"
#     "Địa điểm lịch sử"
#     "Chuyến tham quan tự hướng dẫn và cho thuê"
#     "Khu du lịch"
#     "Trung tâm mua sắm"
#     "Quầy bar xì gà"
#     "Nông trại"
#     "Công viên"
#     "Lớp học nấu ăn"
#     "Làng nghề truyền thống"
#     "Câu lạc bộ khiêu vũ và vũ trường"
#     "Sân chơi"
#     "Tòa nhà chính phủ"
#     "Rạp hát"
#     "Sân golf mini"
#     "Viện bảo tàng chuyên ngành"
#     "Chuyến tham quan cưỡi ngựa"
#     "Công viên quốc gia"
#     "Spa nước nóng"
#     "Hệ thống giao thông công cộng"
#     "Rạp hát Nhà hát và biểu diễn"
#     "Lớp nấu ăn"
#     "Cửa hàng bách hóa"
#     "Chợ nông sản"
#     "Khu phố cổ"
#     "Trung tâm và trại thể thao"

# %% [markdown]
# ##### Restaurant

# %%
# Type
# Establish the connection
conn = psycopg2.connect(postgres_url)
cur = conn.cursor()

# Set the search path to use the correct schema
cur.execute("SET search_path TO travel_database, public;")

# Query to extract distinct districts from the address composite type
cur.execute("""
    SELECT DISTINCT unnest(restaurant_type) AS unique_res_type
    FROM restaurant;
""")

# Fetch all rows
rows = cur.fetchall()

# Close the cursor and connection
cur.close()
conn.close()

# Convert the rows into a list and format the output
res_type_list = [row[0] for row in rows]
res_type_list_str = "\n    ".join(f'"{res_type}"' for res_type in res_type_list)
print(res_type_list_str)
# Out:
# "Karaoke"
#     "Café/Dessert"
#     "Buffet"
#     "Ăn vặt/vỉa hè"
#     "Tiệc cưới/Hội nghị"
#     "Quán ăn"
#     "Tiệm bánh"
#     "Ăn chay"
#     "Nhà hàng"

# %%
# Suitable for
# Establish the connection
conn = psycopg2.connect(postgres_url)
cur = conn.cursor()

# Set the search path to use the correct schema
cur.execute("SET search_path TO travel_database, public;")

# Query to extract distinct districts from the address composite type
cur.execute("""
    SELECT DISTINCT unnest(suitable_for) AS unique_res_suit
    FROM restaurant;
""")

# Fetch all rows
rows = cur.fetchall()

# Close the cursor and connection
cur.close()
conn.close()

# Convert the rows into a list and format the output
res_suit_list = [row[0] for row in rows]
res_suit_list_str = "\n    ".join(f'"{res_suit}"' for res_suit in res_suit_list)
print(res_suit_list_str)
# Out:
# "Uống bia - Nhậu"
#     "Ăn gia đình"
#     "Ăn chay"
#     "Ăn Fastfood"
#     "Đãi tiệc"
#     "Tiếp khách"
#     "Takeaway - Mang về"
#     "Họp nhóm"
#     "Ăn vặt"
#     "Nghe nhạc"
#     "Du lịch"
#     "Ngắm cảnh"
#     "Chụp hình - Quay phim"
#     "BBQ - Món Nướng"
#     "Tiệc ngoài trời"
#     "Thư giãn"
#     "Hẹn hò"
#     "Buffet"

# %% [markdown]
# #### Prompt

# %% [markdown]
# Dựa vào câu prompt này để lấy ra các thông tin yêu cầu về hotel, restaurant, TouristAttraction

# %% [markdown]
# ##### Extract first JSON

# %%
travel_type_list = ["Food Tour", "Văn hóa", "Thư giãn", "Trải nghiệm"]
companion_list = ["friends", "family", "colleagues"]
transport_list = ["self-drive car", "motorbike", "bicycle", "public transport"]
city_list = ["Hà Nội"]

# %%
template = """
You are an AI travel suggestion chatbot. Analyze the following travel request:

Request: "{travel_request}"

Extract general and specific requirements for Hotels, Restaurants, and Tourist Attractions, even if some are not explicitly mentioned. For each type, provide the following information:

**General Requirements:**
- Type: From this list: {travel_type_list} based on request or return null if not specified or only ask for one of Hotels, Restaurants, or Tourist Attractions.
- Number_of_people: Extract the number of people or return null if not specified.
- Companions: Extract the companions mentioned and from this list: {companion_list} or return null if not specified.
- Transportation: Identify the transportation method mentioned and from this list: {transport_list} or return null if not specified.
- Time: Any specific dates or time ranges mentioned or return null if not specified.
- City: The mentioned city (without "city" or "province") and from this list: {city_list}.
- Price_range: Specify as "low", "medium", or "high" based on the request.

**For Hotels, also identify:**
- Requirements: A summary text of specific requirements or preferences mentioned.
- Amenities: From this list: {amenities_list}
- Style: From this list: {style_list}

**For Restaurants, also identify:**
- Requirements: A summary text of specific requirements or preferences mentioned.
- Restaurant_Type: From this list: {restaurant_type_list}
- Suitable_For: From this list: {suitable_for_list}

**For Tourist Attractions, also identify:**
- Requirements: A list of specific requirements or preferences mentioned.
- Attraction_Type: From this list: {attraction_type_list}

Return the result using the following JSON format:

```json
{{
  "General": {{
    "Type": "...",
    "Number_of_people": "...",
    "Companion": "...",
    "Transportation": "...",
    "Time": "...",
    "City": "..."
    "Price_range": "...",
    "
  }},
  "Hotel": {{
    "Requirements": ...,
    "Amenities": [...],
    "Style": "..."
  }},
  "Restaurant": {{
    "Requirements": ...,
    "Restaurant_Type": "...",
    "Suitable_For": "..."
  }},
  "TouristAttraction": {{
    "Attraction_Type": "..."
  }}
}}

```

Ensure the JSON is valid. Use null for any unspecified information.
After the JSON output, add a note in Vietnamese:

"Nếu bạn cần thay đổi hoặc bổ sung bất kỳ thông tin nào, vui lòng cho tôi biết."
"""

# %%
prompt = ChatPromptTemplate.from_template(template)
chain = prompt | llm

# %% [markdown]
# ##### Ask again if there's missing infor

# %% [markdown]
# format json due to type

# %% [markdown]
# ưu tiên hỏi time

# %%
ask_template = """
You are an AI travel suggestion chatbot. Analyze the following travel request:

Request: "{travel_output_json}"

If any fields in the JSON are null, generate a question for the missing information. Only ask for fields that are **explicitly null**.

**Check the JSON output for any null values:**
- Type: From this list: {travel_type_list}
- Number_of_people:
- Companions: From this list: {companion_list}
- Transportation: From this list: {transport_list}
- Time:
- City: From this list: {city_list}
- Price_range:

**For Hotels:**
- Requirements:
- Amenities: From this list: {amenities_list}
- Style: From this list: {style_list}

**For Restaurants:**
- Requirements:
- Restaurant_Type: From this list: {restaurant_type_list}
- Suitable_For: From this list: {suitable_for_list}

**For Tourist Attractions:**
- Requirements:
- Attraction_Type: From this list: {attraction_type_list}

---

Analyze the JSON input. **If any field is null, generate the corresponding question**. **Only ask questions for fields that are explicitly null.** Ensure the final output is in **Vietnamese**, containing only the relevant questions in a natural, conversational format.

**Check the JSON output for any null values and generate appropriate questions:**

1. If `"Type"` is null, ask:
   **"Bạn muốn tìm loại hình du lịch nào? (Ví dụ: Food Tour, Văn hóa, Thư giãn, hoặc Trải nghiệm)"**

2. If `"Number_of_people"` is null, ask:
   **"Bạn đi bao nhiêu người? (Ví dụ: 1, 2, hoặc nhóm lớn hơn)"**

3. If `"Companion"` is null, ask:
   **"Bạn đi cùng ai? (Bạn bè, Gia đình, hoặc Đồng nghiệp)"**

4. If `"Transportation"` is null, ask:
   **"Bạn sẽ di chuyển bằng phương tiện gì? (Ví dụ: xe hơi tự lái, xe máy, hoặc phương tiện công cộng)"**

5. If `"Time"` is null, ask:
   **"Bạn có kế hoạch đi vào thời gian nào không? (Ngày cụ thể hoặc khoảng thời gian)"**

6. If `"Price_range"` is null, ask:
   **"Bạn muốn ngân sách cho chuyến đi này là bao nhiêu (thấp, trung bình, cao)?"**

---

### Example Output:
If the provided JSON input has `"Transportation"` and `"Time"` as `null`, the output will be:

```plaintext
Bạn sẽ di chuyển bằng phương tiện gì? (Ví dụ: xe hơi tự lái, xe máy, hoặc phương tiện công cộng)

Bạn có kế hoạch đi vào thời gian nào không? (Ngày cụ thể hoặc khoảng thời gian)

Nếu bạn cần thay đổi hoặc bổ sung bất kỳ thông tin nào, vui lòng cho tôi biết.
"""

# %%
ask_template2 = """
You are an AI travel suggestion chatbot. Analyze the following travel request:

Request: "{travel_output_json}"

If any fields in the JSON are null, ask the user for the missing information to fill those gaps.

Based on the null values found, generate the following comprehensive question for the user:

"Cảm ơn bạn đã cung cấp thông tin! Tuy nhiên, tôi cần thêm một số thông tin để giúp bạn tốt hơn: Bạn muốn tìm loại hình du lịch nào (Khách sạn, Nhà hàng, hay Điểm tham quan)? Bạn đi bao nhiêu người và đi cùng ai (Bạn bè, Gia đình, hay Đồng nghiệp)? Bạn sẽ di chuyển bằng phương tiện gì (xe hơi tự lái, xe máy, hay phương tiện công cộng)? Bạn có kế hoạch đi vào thời gian nào (ngày cụ thể hoặc khoảng thời gian)? Và bạn muốn ngân sách cho chuyến đi này là bao nhiêu (thấp, trung bình, cao)?"

After the question, add a note in Vietnamese:

"Nếu bạn cần thay đổi hoặc bổ sung bất kỳ thông tin nào, vui lòng cho tôi biết."
"""

# %%
ask_prompt = ChatPromptTemplate.from_template(ask_template)
ask_chain = ask_prompt | llm

# %% [markdown]
# ##### Query

# %%
# Your input query
query = """
Gợi ý cho tôi một lộ trình du lịch tại Hà Nội với khách sạn sang trọng, có Bồn tắm, bể bơi và Mát-xa toàn thân, nhà hàng phục vụ món ăn truyền thống và một điểm tham quan nổi tiếng phù hợp cho trẻ em về đề tài lịch sử.
Tôi muốn biết thêm về các tiện nghi của khách sạn và phong cách của nhà hàng.
"""

# %% [markdown]
# first response

# %%
response = chain.invoke({
    "travel_request": query,
    "travel_type_list": travel_type_list,
    "companion_list": companion_list,
    "transport_list": transport_list,
    "city_list": city_list,
    "amenities_list": amenities_list_str,
    "style_list": style_list_str,
    "restaurant_type_list": res_type_list_str,
    "suitable_for_list": res_suit_list_str,
    "attraction_type_list": att_type_list_str
})

# Extract and parse the JSON response
try:
    json_match = re.search(r'\{.*\}', response.content, re.DOTALL)
    if json_match:
        result_dict = json.loads(json_match.group(0))

        # Print the JSON result
        print("Extracted JSON Result:")
        print(json.dumps(result_dict, indent=2, ensure_ascii=False))
    else:
        print("No JSON object found in the response.")
except json.JSONDecodeError as e:
    print("Failed to decode JSON:", e)
    print("Raw response:", response.content)
# Out:
# Extracted JSON Result:
# {
#   "General": {
#     "Type": null,
#     "Number_of_people": null,
#     "Companion": null,
#     "Transportation": null,
#     "Time": null,
#     "City": "Hà Nội",
#     "Price_range": "high"
#   },
#   "Hotel": {
#     "Requirements": "Khách sạn sang trọng, có bồn tắm, bể bơi và mát-xa toàn thân.",
#     "Amenities": [
#       "Bathtub",
#       "Hồ bơi",
#       "Mát-xa"
#     ],
#     "Style": "Luxury"
#   },
#   "Restaurant": {
#     "Requirements": "Phục vụ món ăn truyền thống.",
#     "Restaurant_Type": "Nhà hàng",
#     "Suitable_For": "Ăn gia đình"
#   },
#   "TouristAttraction": {
#     "Requirements": "Điểm tham quan nổi tiếng phù hợp cho trẻ em về đề tài lịch sử",
#     "Attraction_Type": "Địa điểm lịch sử"
#   }
# }

# %% [markdown]
# ask again if missing values

# %%
response1 = ask_chain.invoke({
    "travel_output_json": response,
    "travel_type_list": travel_type_list,
    "companion_list": companion_list,
    "transport_list": transport_list,
    "city_list": city_list,
    "amenities_list": amenities_list_str,
    "style_list": style_list_str,
    "restaurant_type_list": res_type_list_str,
    "suitable_for_list": res_suit_list_str,
    "attraction_type_list": att_type_list_str
})

print(response1.content)
# Out:
# Bạn muốn tìm loại hình du lịch nào? (Ví dụ: Food Tour, Văn hóa, Thư giãn, hoặc Trải nghiệm)
#
# Bạn đi bao nhiêu người? (Ví dụ: 1, 2, hoặc nhóm lớn hơn)
#
# Bạn đi cùng ai? (Bạn bè, Gia đình, hoặc Đồng nghiệp)
#
# Bạn sẽ di chuyển bằng phương tiện gì? (Ví dụ: xe hơi tự lái, xe máy, hoặc phương tiện công cộng)
#
# Bạn có kế hoạch đi vào thời gian nào không? (Ngày cụ thể hoặc khoảng thời gian)
#
# Nếu bạn cần thay đổi hoặc bổ sung bất kỳ thông tin nào, vui lòng cho tôi biết.

# %%
import json

# Template câu hỏi chung
ask_template2 = """
You are an AI travel suggestion chatbot. Analyze the following travel request:

Request: "{travel_output_json}"

If any fields in the JSON are null, ask the user for the missing information to fill those gaps.

Based on the null values found, generate the following comprehensive question for the user:

"Cảm ơn bạn đã cung cấp thông tin! Tuy nhiên, tôi cần thêm một số thông tin để giúp bạn tốt hơn:
{missing_info_questions}
"

After the question, add a note in Vietnamese:

"Nếu bạn cần thay đổi hoặc bổ sung bất kỳ thông tin nào, vui lòng cho tôi biết."
"""

# Mapping giữa các trường JSON và câu hỏi tương ứng
question_mapping = {
    "travel_type": "Bạn muốn tìm loại hình du lịch nào (Khách sạn, Nhà hàng, hay Điểm tham quan)?",
    "number_of_people": "Bạn đi bao nhiêu người?",
    "companion_type": "Bạn đi cùng ai (Bạn bè, Gia đình, hay Đồng nghiệp)?",
    "transport": "Bạn sẽ di chuyển bằng phương tiện gì (xe hơi tự lái, xe máy, hay phương tiện công cộng)?",
    "date": "Bạn có kế hoạch đi vào thời gian nào (ngày cụ thể hoặc khoảng thời gian)?",
    "budget": "Bạn muốn ngân sách cho chuyến đi này là bao nhiêu (thấp, trung bình, cao)?"
}

# Hàm lọc và tạo câu hỏi cho những trường bị null
def generate_missing_info_questions(json_data):
    # Lấy những câu hỏi tương ứng với các trường có giá trị None
    return [question_mapping[key] for key, value in json_data.items() if value is None]

# Hàm lặp việc hiển thị câu hỏi cho đến khi người dùng muốn dừng
def ask_questions(json_data):
    # Lấy danh sách câu hỏi dựa trên các trường bị null
    questions = generate_missing_info_questions(json_data)

    # Duyệt qua từng câu hỏi và yêu cầu người dùng trả lời
    for question in questions:
        print(question)  # Hiển thị câu hỏi

        # Yêu cầu nhập phản hồi cho câu hỏi
        response = input("Nhập câu trả lời của bạn: ")

        # Tìm trường tương ứng trong JSON và cập nhật với giá trị người dùng nhập
        for key, value in json_data.items():
            if value is None and question == question_mapping[key]:
                json_data[key] = response
                break

    return json_data

# Dữ liệu JSON ban đầu với một số trường bị thiếu
json_data = {
    "travel_type": None,
    "number_of_people": 4,
    "companion_type": None,
    "transport": None,
    "date": None,
    "budget": "trung bình"
}

# Lặp và yêu cầu trả lời câu hỏi dựa trên những trường còn thiếu
updated_data = ask_questions(json_data)

# Sau khi thu thập dữ liệu, tạo prompt với thông tin mới
missing_info_questions = " ".join(generate_missing_info_questions(updated_data))

# Tạo câu hỏi tổng hợp và in ra
final_prompt = ask_template2.format(
    travel_output_json=json.dumps(updated_data, ensure_ascii=False, indent=2),
    missing_info_questions=missing_info_questions
)

print(final_prompt)
# Out:
# Bạn muốn tìm loại hình du lịch nào (Khách sạn, Nhà hàng, hay Điểm tham quan)?
# Nhập câu trả lời của bạn: Khách sạn
# Bạn đi cùng ai (Bạn bè, Gia đình, hay Đồng nghiệp)?
# Nhập câu trả lời của bạn: bạn bè
# Bạn sẽ di chuyển bằng phương tiện gì (xe hơi tự lái, xe máy, hay phương tiện công cộng)?
# Nhập câu trả lời của bạn: xe máy
# Bạn có kế hoạch đi vào thời gian nào (ngày cụ thể hoặc khoảng thời gian)?
# Nhập câu trả lời của bạn: 2 ngày
#
# You are an AI travel suggestion chatbot. Analyze the following travel request:
#
# Request: "{
#   "travel_type": "Khách sạn",
#   "number_of_people": 4,
#   "companion_type": "bạn bè",
#   "transport": "xe máy",
#   "date": "2 ngày",
#   "budget": "trung bình"
# }"
#
# If any fields in the JSON are null, ask the user for the missing information to fill those gaps.
#
# Based on the null values found, generate the following comprehensive question for the user:
#
# "Cảm ơn bạn đã cung cấp thông tin! Tuy nhiên, tôi cần thêm một số thông tin để giúp bạn tốt hơn:
#
# "
#
# After the question, add a note in Vietnamese:
#
# "Nếu bạn cần thay đổi hoặc bổ sung bất kỳ thông tin nào, vui lòng cho tôi biết."
